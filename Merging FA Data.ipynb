# %%
import pandas as pd
import os
from tqdm import tqdm
from fuzzywuzzy import process

# 🔹 Set directory where the CSV files are stored
directory_path = '/Users/sreeharsha/Documents/TGH Data Management Cleaning/Translated ES'
output_file = os.path.join(directory_path, "merged_ES_data.csv")

# 🔹 List of desired column names
desired_columns = [
    "state", "creation date", "modified date", "completion time", "submitted date", 
    "first name", "last name", "date of birth", 
    "have you received a tgh device chromebook or ipad in the last two years",
    "primary language", "educational status", "employment status", "household income level",
    "number of people in household", "city", "do you have home internet access i e wifi",
    "home street address including apartment number", "course id", "course type",
    "phone number", "email address", "form name", "course name",
    "i agree to the learner agreement as listed above", "do you receive housing assistance",
    "name of siteschool", "childs date of birth", "primary language.1", "childs last name",
    "childs last name.1", "if you selected other what language", "do you have an existing business",
    "what industry is your business in", "if you selected other what language.1",
    "which if any social media tools do you use for your business", "if you selected other please explain",
    "zip code", "please describe your confidence level using the internet to find information you need",
    "how many tablets do you have at home e g ipad kindle fire samsung galaxy tab",
    "creating and sending emails", "opening and replying to emails",
    "downloading attachments i receive in an email documents or pictures",
    "adding an attachment to an email i am sending like documents or pictures",
    "how many working computers do you have at home",
    "is this the first activity youve participated in at your program site",
    "turning the tablet on and off", "installing applications from the chromebook store",
    "adjusting the tablets settings like the size of the text or the background picture",
    "connecting the tablet to wifi", "saving files to the tablet and finding them later",
    "using a mouse headset andor other accessories", "what is your goal for taking this course",
    "are you aware of the affordable connectivity program acp an fcc federal communications commission program",
    "are you currently enrolled in the acp program", "turning the tablet on and off.1",
    "connecting the tablet to wifi.1", "saving files to the tablet and finding them later.1",
    "adjusting the tablets settings like the size of the text or the background picture.1",
    "installing applications apps", "do you have a website for your business", "name of business",
    "your gender identity", "what is your gender", "are you self employed",
    "how would you describe your raceethnicity select all that apply", "do you have a smartphone e g iphone google pixel samsung galaxy",
    "is your internet reliable", "is your internet reliable.1",
    "how would you describe your raceethnicity select all that apply.1", "what is your gender.1",
    "what are your pronouns.1", "how would you describe your raceethnicity.1",
    "were you born in the united states", "have you ever spent time in a jail prison or juvenile detention centre",
    "because of my money situation i feel like i will never have the things i want in life",
    "i am aware of what my resources are to be employed in a good job",
    "i am able to utilize my skills to move toward career goals", "i am just getting by financially",
    "i am concerned that the money i have or will save wont last",
    "even if i am not able to achieve my financial goals right away i will find a way to get there",
    "what other boston neighborhoods are you connected to",
    "what is the zip code where you work", "i hereby give the unqualified right to the tgh program",
    "race ethnicity", "to which gender identity do you most identify", "childs grade",
    "your race ethnicity", "i am aware of what my skills are to be employed in a good job",
    "how do you describe your sexual orientation select all that apply", "zip",
    "do you have school age children in your household",
    "is this your first activity program at the school or site where you are taking tgh",
    "what is the main reason you decided to participate in tgh",
    "have you ever had to change or cancel your internet subscription because it is too expensive",
    "number of working computers at home", "what do you and other household members use the internet for",
    "which devices do you use at home", "how satisfied are you with your internet service at home",
    "how do you or anyone living in your household access the internet in your home",
    "is your internet access through a discounted program eg internet essentials pcs for people",
    "what financial resources do you use", "occupation", "place of work", "are you a veteran",
    "childs grade.1", "how do you describe your sexual orientation", "do you have a smartphone",
    "what best describes the organization you are starting or running",
    "what are the biggest challenges you are currently facing in running your business",
    "if you selected other what type", "if you selected other please explain.2",
    "i am aware of what my skills are to achieve a good employment",
    "how old is your business", "annual revenue of business", "number of employees",
    "do you accept credit debit cards", "do you know of organizations that help small business owners",
    "what does your business use the internet for", "how often are your business social media pages updated"
]

# 🔹 Automatically find all CSV files in the directory
csv_files = [os.path.join(directory_path, f) for f in os.listdir(directory_path) if f.endswith(".csv")]

if not csv_files:
    print("⚠️ No CSV files found in the specified directory.")
    exit()

print(f"✅ Found {len(csv_files)} CSV files to process.")

# Initialize empty merged dataframe with the desired column names
merged_df = pd.DataFrame(columns=desired_columns)

for file in tqdm(csv_files, desc="Merging files"):
    try:
        df = pd.read_csv(file, encoding="utf-8", dtype=str)

        # Select only columns that exist in both the file and the desired list
        available_cols = [col for col in desired_columns if col in df.columns]
        df = df[available_cols]

        # Add missing columns with NaN values
        for col in desired_columns:
            if col not in df.columns:
                df[col] = pd.NA

        # Reorder columns to match desired order
        df = df[desired_columns]

        # Append to final DataFrame
        merged_df = pd.concat([merged_df, df], ignore_index=True)

    except Exception as e:
        print(f"⚠️ Error processing {file}: {e}")

# Step 3: Save the merged file
merged_df.to_csv(output_file, index=False, encoding="utf-8")

print(f"\n✅ Merged data saved: {output_file}")
print("\n🎉 Merging complete! You can now review the final dataset.")
# Out:
# ✅ Found 6 CSV files to process.
# Merging files: 100%|██████████████████████████████| 6/6 [00:01<00:00,  4.18it/s]
# ✅ Merged data saved: /Users/sreeharsha/Documents/TGH Data Management Cleaning/Translated ES/merged_ES_data.csv
#
# 🎉 Merging complete! You can now review the final dataset.

# %%
pip install fuzzywuzzy
# Out:
# Collecting fuzzywuzzy
#   Downloading fuzzywuzzy-0.18.0-py2.py3-none-any.whl.metadata (4.9 kB)
# Downloading fuzzywuzzy-0.18.0-py2.py3-none-any.whl (18 kB)
# Installing collected packages: fuzzywuzzy
# Successfully installed fuzzywuzzy-0.18.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import pandas as pd

# Set the path to your files
files_path = '/Users/sreeharsha/Documents/TGH Data Management Cleaning/Translated ES'  # Update this path accordingly

# List all CSV files in the directory
all_files = [os.path.join(files_path, f) for f in os.listdir(files_path) if f.endswith('.csv')]

# Step 1: Print the original column names for each file for review
print("=== Original Column Names in Each File ===")
for file in all_files:
    df = pd.read_csv(file)
    print(f"File: {os.path.basename(file)}")
    print("Columns:", df.columns.tolist())
    print("-" * 40)

# Step 2: Define a function to clean the column names
def clean_column_names(columns):
    """
    Cleans column names by stripping whitespace, converting to lowercase,
    and replacing spaces with underscores.
    """
    cleaned_columns = []
    for col in columns:
        # You can add more cleaning steps as needed
        cleaned = col.strip().lower().replace(" ", "_")
        cleaned_columns.append(cleaned)
    return cleaned_columns

# Optional: Apply cleaning and print the cleaned column names for review
print("=== Cleaned Column Names in Each File ===")
for file in all_files:
    df = pd.read_csv(file)
    cleaned_cols = clean_column_names(df.columns.tolist())
    print(f"File: {os.path.basename(file)}")
    print("Cleaned Columns:", cleaned_cols)
    print("-" * 40)

# Next steps (once you're satisfied with the cleaned names):
# - You can re-read each file, assign the cleaned column names,
# - And then merge the data based on your required columns,
# - Ensuring no duplicate data is introduced.
# Out:
# === Original Column Names in Each File ===
# File: cleaned_translated_ES_spanish.csv
# Columns: ['course name', 'name of siteschool', 'course type', 'first name', 'last name', 'what are your pronouns', 'have you received a tgh device chromebook or ipad in the last two years', 'date of birth', 'what is your gender', 'your gender identity', 'how would you describe your raceethnicity', 'how would you describe your raceethnicity select all that apply', 'primary language', 'if you selected other what language', 'home street address including apartment number', 'city', 'state', 'zip code', 'phone number', 'email address', 'number of people in household', 'educational status', 'employment status', 'what is the zip code where you work', 'are you self employed', 'household income level', 'do you receive housing assistance', 'what other boston neighborhoods are you connected to for example do you receive services visit family or friends go to school or places of worship in any of the following neighborhoods select all that apply', 'were you born in the united states', 'have you ever spent time in a jail prison or juvenile detention centre', 'how do you describe your sexual orientation select all that apply', 'other', 'childs last name', 'childs last name.1', 'what are your pronouns.1', 'childs date of birth', 'what is your gender.1', 'your gender identity.1', 'how would you describe your raceethnicity.1', 'how would you describe your raceethnicity select all that apply.1', 'primary language.1', 'if you selected other what language.1', 'what is your goal for taking this course', 'is this the first activity youve participated in at your program site', 'how many working computers do you have at home', 'how many tablets do you have at home e g ipad kindle fire samsung galaxy tab', 'do you have a smartphone', 'do you have home internet access i e wifi', 'is your internet reliable', 'is your internet reliable.1', 'are you aware of the affordable connectivity program acp an fcc federal communications commission program to help families and households afford internet service more info here httpswww fcc govacp', 'are you currently enrolled in the acp program', 'please describe your confidence level using the internet to find information you need', 'creating and sending emails', 'opening and replying to emails', 'downloading attachments i receive in an email documents or pictures', 'adding an attachment to an email i am sending like documents or pictures', 'turning the tablet on and off', 'adjusting the tablets settings like the size of the text or the background picture', 'connecting the tablet to wifi', 'installing applications from the chromebook store', 'saving files to the tablet and finding them later', 'using a mouse headset andor other accessories', 'turning the tablet on and off.1', 'adjusting the tablets settings like the size of the text or the background picture.1', 'connecting the tablet to wifi.1', 'installing applications apps', 'saving files to the tablet and finding them later.1', 'do you have an existing business', 'name of business', 'what industry is your business in', 'if you selected other please explain', 'do you have a website for your business', 'what is your website address url', 'which if any social media tools do you use for your business', 'please enter anyall of your social media handles separated by a comma', 'acepto que usen citas tomen fotos y graben pelculas o videos mos o de mis hijos en el programa de tech goes home concedo a tech goes home el derecho de editar usar y reutilizar los productos mencionados sin nimo de lucro incluido el uso impreso en internet y en cualquier formato multimedia acepto estos trminos de forma voluntaria y entiendo que no recibir ninguna compensacin financiera por el presente documento libero a tech goes home y sus agentes y empleados de cualquier reclamacin demanda y responsabilidad en el marco de lo anterior si no desea que tech goes home use su foto indquelo a sus instructores de tgh para que no nos enven fotografas suyas', 'i am aware of what my skills are to achiev ...
# ----------------------------------------
# File: Learner+Enrollment+ENGLISH.csv
# Columns: ['submitted date', 'course name', 'name of siteschool', 'course type', 'first name', 'last name', 'do you have home internet access i e wifi', 'what are your pronouns', 'have you received a tgh device chromebook or ipad in the last two years', 'date of birth', 'what is your gender', 'your gender identity', 'how would you describe your raceethnicity', 'how would you describe your raceethnicity select all that apply', 'primary language', 'if you selected other what language', 'are you a veteran', 'home street address including apartment number', 'city', 'state', 'zip code', 'phone number', 'email address', 'number of people in household', 'educational status', 'employment status', 'are you self employed', 'what is the zip code where you work', 'household income level', 'do you receive housing assistance', 'what other boston neighborhoods are you connected to for example do you receive services visit family or friends go to school or places of worship in any of the following neighborhoods select all that apply', 'other', 'were you born in the united states', 'have you ever spent time in a jail prison or juvenile detention centre', 'how do you describe your sexual orientation', 'other.1', 'childs last name', 'childs last name.1', 'what are your pronouns.1', 'childs date of birth', 'what is your gender.1', 'your gender identity.1', 'how would you describe your raceethnicity.1', 'how would you describe your raceethnicity select all that apply.1', 'primary language.1', 'if you selected other what language.1', 'what is your goal for taking this course', 'is this the first activity youve participated in at your program site', 'how many working computers do you have at home', 'how many tablets do you have at home e g ipad kindle fire samsung galaxy tab', 'do you have a smartphone e g iphone google pixel samsung galaxy', 'is your internet reliable', 'is your internet reliable.1', 'are you aware of the affordable connectivity program acp an fcc federal communications commission program to help families and households afford internet service more info here httpswww fcc govacp', 'are you currently enrolled in the acp program', 'please describe your confidence level using the internet to find information you need', 'creating and sending emails', 'opening and replying to emails', 'downloading attachments i receive in an email documents or pictures', 'adding an attachment to an email i am sending like documents or pictures', 'turning the tablet on and off', 'adjusting the tablets settings like the size of the text or the background picture', 'connecting the tablet to wifi', 'installing applications from the chromebook store', 'saving files to the tablet and finding them later', 'using a mouse headset andor other accessories', 'turning the tablet on and off.1', 'adjusting the tablets settings like the size of the text or the background picture.1', 'connecting the tablet to wifi.1', 'installing applications apps', 'saving files to the tablet and finding them later.1', 'i am aware of what my skills are to be employed in a goodjob e g digital skills specific trade skills etc', 'i am aware of what my resources are to be employed in a good job e g resources for job searching child care resources etc', 'i am able to utilize my skills to move toward career goals', 'i am able to utilize my skills to move toward career goals.1', 'even if i am not able to achieve my financial goals right away i will find a way to get there', 'because of my money situation i feel like i will never have thethings i want in life', 'i am just getting by financially', 'i am concerned that the money i have or will save wont last', 'do you have an existing business', 'name of business', 'what industry is your business in', 'if you selected other please explain', 'do you have a website for your business', 'what is your website address url', 'which if any social media tools do you use for your business', 'please enter any all of your social media handles separated by a c ...
# ----------------------------------------
# /var/folders/q6/v__5dqvn4fsgnld9cp_x0v1m0000gn/T/ipykernel_23866/719564596.py:13: DtypeWarning: Columns (16,27,30,31,32,33,34,35,49,76,77,78,82,100) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file)
# /var/folders/q6/v__5dqvn4fsgnld9cp_x0v1m0000gn/T/ipykernel_23866/719564596.py:13: DtypeWarning: Columns (14,17,18,31,34,36,78) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file)
# File: (OLD) TGH Learner Enrollment Form (6.2.2022).csv
# Columns: ['course name', 'name of siteschool', 'course type', 'first name', 'last name', 'have you received a tgh device chromebook or ipad in the last two years', 'date of birth', 'to which gender identity do you most identify', 'your gender identity', 'race ethnicity', 'your race ethnicity', 'primary language', 'if you selected other what language', 'home street address including apartment number', 'city', 'state', 'zip code', 'phone number', 'email address', 'number of people in household', 'educational status', 'employment status', 'household income level', 'do you receive housing assistance', 'childs last name', 'childs last name.1', 'childs date of birth', 'childs grade', 'your gender identity.1', 'your race ethnicity.1', 'your race ethnicity.2', 'primary language.1', 'if you selected other what language.1', 'what is your goal for taking this course', 'is this the first activity youve participated in at your program site', 'how many working computers do you have at home', 'how many tablets do you have at home e g ipad kindle fire samsung galaxy tab', 'do you have a smartphone e g iphone google pixel samsung galaxy', 'do you have home internet access i e wifi', 'are you aware of the affordable connectivity program acp an fcc federal communications commission program to help families and households afford internet service more info here httpswww fcc govacp', 'are you currently enrolled in the acp program', 'please describe your confidence level using the internet to find information you need', 'creating and sending emails', 'opening and replying to emails', 'downloading attachments i receive in an email documents or pictures', 'adding an attachment to an email i am sending like documents or pictures', 'turning the tablet on and off', 'adjusting the tablets settings like the size of the text or the background picture', 'connecting the tablet to wifi', 'installing applications from the chromebook store', 'saving files to the tablet and finding them later', 'using a mouse headset andor other accessories', 'turning the tablet on and off.1', 'adjusting the tablets settings like the size of the text or the background picture.1', 'connecting the tablet to wifi.1', 'installing applications apps', 'saving files to the tablet and finding them later.1', 'do you have an existing business', 'name of business', 'what industry is your business in', 'if you selected other please explain', 'do you have a website for your business', 'what is your website address url', 'which if any social media tools do you use for your business', 'please enter any all of your social media handles separated by a comma e g techgoeshome facebook com yourbusinessname', 'i hereby give the unqualified right to the tgh program to take pictures and or video of me while participating in my course i give permission for these images as well as materials that we have created in the tgh program to be used in print and web based publications the tgh program will put these images to legitimate use without limitation or reservation if you do not wish for your photo to be used by tgh please let your tgh trainers know so they will not send us pictures of you', 'i agree to the learner agreement as listed above', 'course id', 'form name', 'creation date', 'modified date', 'submitted date', 'completion time', 'response html', 'response html.1', 'response text', 'response', 'response.1', 'resume email', 'file list', 'unprotected file list', 'response.2', 'referrer', 'ip address']
# ----------------------------------------
# File: (OLD)+TGH+Learner+Enrollment+Form+2025-03-06-11-24-39+457499.csv.csv
# Columns: ['submitted date', 'name of siteschool', 'course type', 'first name', 'middle initial', 'last name', 'do you have school age children in your household', 'childs last name', 'childs last name.1', 'is this your first activity program at the school or site where you are taking tgh', 'employment status', 'race ethnicity', 'household income level', 'primary language', 'course name', 'have you received a tgh device chromebook or ipad in the last two years', 'date of birth', 'to which gender identity do you most identify', 'if you selected other please explain', 'if you selected other what type', 'if you selected other what language', 'home street address including apartment number', 'city', 'state', 'zip', 'phone number', 'email address', 'number of people in household', 'educational status', 'occupation', 'place of work', 'do you receive housing assistance', 'childs grade', 'childs date of birth', 'childs grade.1', 'if you selected other please explain.1', 'your race ethnicity', 'if you selected other what type.1', 'primary language.1', 'if you selected other what language.1', 'what is the main reason you decided to participate in tgh', 'if you selected other please explain.2', 'which devices do you use at home', 'if you selected other what type.2', 'number of working computers at home', 'do you have home internet access i e wifi', 'how do you or anyone living in your household access the internet in your home', 'if you selected other what type.3', 'how do you or anyone living in your household access the internet in your home.1', 'if you selected other please explain.3', 'is your internet access through a discounted program eg internet essentials pcs for people', 'how satisfied are you with your internet service at home', 'if you selected other please explain.4', 'why dont you have internet access at home', 'if you selected other please explain.5', 'have you ever had to change or cancel your internet subscription because it is too expensive', 'what do you and other household members use the internet for', 'what financial resources do you use', 'if you selected other please explain.6', 'do you have an existing business', 'what best describes the organization you are starting or running', 'if you selected other please explain.7', 'what are the biggest challenges you are currently facing in running your business if you have not yet started your business what are the biggest obstacles', 'name of business', 'how old is your business', 'annual revenue of business', 'number of employees', 'what industry is your business in', 'if you selected other please explain.8', 'do you accept credit debit cards', 'what does your business use the internet for', 'if you selected other please explain.9', 'do you know of organizations that help small business owners navigate licensing and permitting taxes law marketing access to funding and other business issues', 'do you have a website for your business', 'which if any social media tools do you use for your business', 'if you selected other please explain.10', 'how often are your business social media pages updated', 'i hereby give the unqualified right to the tgh program to take pictures and or video of me while participating in my course i give permission for these images as well as materials that we have created in the tgh program to be used in print and web based publications the tgh program will put these images to legitimate use without limitation or reservation if you do not wish for your photo to be used by tgh please let your tgh trainers know so they will not send us pictures of you', 'i agree to the learner agreement as listed above', 'course id', 'form name', 'creation date', 'modified date', 'completion time', 'response html', 'response html.1', 'response text', 'response', 'response.1', 'resume email', 'file list', 'unprotected file list', 'response.2', 'referrer', 'ip address']
# ----------------------------------------
# File: cleaned_translated_ES_haitian_creole.csv
# Columns: ['course name', 'name of siteschool', 'course type', 'first name', 'last name', 'what are your pronouns', 'have you received a tgh device chromebook or ipad in the last two years', 'date of birth', 'what is your gender', 'your gender identity', 'how would you describe your raceethnicity', 'how would you describe your raceethnicity select all that apply', 'primary language', 'if you selected other what language', 'home street address including apartment number', 'city', 'state', 'zip code', 'phone number', 'email address', 'number of people in household', 'educational status', 'employment status', 'are you self employed', 'what is the zip code where you work', 'household income level', 'do you receive housing assistance', 'what other boston neighborhoods are you connected to for example do you receive services visit family or friends go to school or places of worship in any of the following neighborhoods select all that apply', 'other', 'were you born in the united states', 'have you ever spent time in a jail prison or juvenile detention centre', 'how do you describe your sexual orientation select all that apply', 'other.1', 'childs last name', 'childs last name.1', 'what are your pronouns.1', 'childs date of birth', 'what is your gender.1', 'idantite seksyl pitit ou a your childs gender identity', 'how would you describe your raceethnicity.1', 'how would you describe your raceethnicity select all that apply.1', 'primary language.1', 'if you selected other what language.1', 'what is your goal for taking this course', 'is this the first activity youve participated in at your program site', 'how many working computers do you have at home', 'how many tablets do you have at home e g ipad kindle fire samsung galaxy tab', 'do you have a smartphone e g iphone google pixel samsung galaxy', 'do you have home internet access i e wifi', 'is your internet reliable', 'is your internet reliable.1', 'are you aware of the affordable connectivity program acp an fcc federal communications commission program to help families and households afford internet service more info here httpswww fcc govacp', 'are you currently enrolled in the acp program', 'please describe your confidence level using the internet to find information you need', 'creating and sending emails', 'opening and replying to emails', 'downloading attachments i receive in an email documents or pictures', 'adding an attachment to an email i am sending like documents or pictures', 'turning the tablet on and off', 'adjusting the tablets settings like the size of the text or the background picture', 'connecting the tablet to wifi', 'installing applications from the chromebook store', 'saving files to the tablet and finding them later', 'using a mouse headset andor other accessories', 'turning the tablet on and off.1', 'adjusting the tablets settings like the size of the text or the background picture.1', 'connecting the tablet to wifi.1', 'installing applications apps', 'saving files to the tablet and finding them later.1', 'i am aware of what my skills are to be employed in a goodjob e g digital skills specific trade skills etc', 'i am aware of what my resources are to be employed in a good job e g resources for job searching child care resources etc', 'i am able to utilize my skills to move toward career goals', 'i am able to utilize my skills to move toward career goals.1', 'even if i am not able to achieve my financial goals right away i will find a way to get there', 'because of my money situation i feel like i will never have thethings i want in life', 'i am just getting by financially', 'i am concerned that the money i have or will save wont last', 'do you have an existing business', 'non biznis la name of business', 'what industry is your business in', 'if you selected other please explain', 'ske w gen yon sitwb pou biznis ou a do you have a website for your business', 'what is your website address url', 'which if any social media tools do you use for your business', 't ...
# ----------------------------------------
# File: Cleaned_ES_translated_chinese.csv
# Columns: ['course name', 'name of siteschool', 'course type', 'first name', 'last name', 'what are your pronouns', 'have you received a tgh device chromebook or ipad in the last two years', 'date of birth', 'what is your gender', 'your gender identity', 'how would you describe your raceethnicity', 'how would you describe your raceethnicity select all that apply', 'primary language', 'if you selected other what language', 'home street address including apartment number', 'city', 'state', 'zip code', 'phone number', 'email address', 'number of people in household', 'educational status', 'employment status', 'are you self employed', 'household income level', 'do you receive housing assistance', 'childs last name', 'childs last name.1', 'what are your pronouns.1', 'childs date of birth', 'what is your gender.1', 'your gender identity.1', 'how would you describe your raceethnicity.1', 'how would you describe your raceethnicity select all that apply.1', 'primary language.1', 'if you selected other what language.1', 'what is your goal for taking this course', 'is this the first activity youve participated in at your program site', 'how many working computers do you have at home', 'how many tablets do you have at home e g ipad kindle fire samsung galaxy tab', 'do you have a smartphone e g iphone google pixel samsung galaxy', 'do you have home internet access i e wifi', 'is your internet reliable', 'is your internet reliable.1', 'are you aware of the affordable connectivity program acp an fcc federal communications commission program to help families and households afford internet service more info here httpswww fcc govacp', 'are you currently enrolled in the acp program', 'please describe your confidence level using the internet to find information you need', 'creating and sending emails', 'opening and replying to emails', 'downloading attachments i receive in an email documents or pictures', 'adding an attachment to an email i am sending like documents or pictures', 'turning the tablet on and off', 'adjusting the tablets settings like the size of the text or the background picture', 'connecting the tablet to wifi', 'installing applications from the chromebook store', 'saving files to the tablet and finding them later', 'using a mouse headset andor other accessories', 'turning the tablet on and off.1', 'adjusting the tablets settings like the size of the text or the background picture.1', 'connecting the tablet to wifi.1', 'installing applications apps', 'saving files to the tablet and finding them later.1', 'do you have an existing business', 'name of business', 'what industry is your business in', 'if you selected other please explain', 'do you have a website for your business', 'what is your website address url', 'which if any social media tools do you use for your business', 'please enter any all of your social media handles separated by a comma e g techgoeshome facebook com yourbusinessname', 'tech goes home tech goes home tech goes home tech goes home tgh', 'i agree to the learner agreement as listed above', 'course id', 'fa list learner enrollment english 1', 'form name', 'creation date', 'modified date', 'submitted date', 'completion time', 'response html', 'response html.1', 'response text', 'response', 'response.1', 'resume email', 'file list', 'unprotected file list', 'response.2', 'referrer', 'ip address']
# ----------------------------------------
# === Cleaned Column Names in Each File ===
# File: cleaned_translated_ES_spanish.csv
# Cleaned Columns: ['course_name', 'name_of_siteschool', 'course_type', 'first_name', 'last_name', 'what_are_your_pronouns', 'have_you_received_a_tgh_device_chromebook_or_ipad_in_the_last_two_years', 'date_of_birth', 'what_is_your_gender', 'your_gender_identity', 'how_would_you_describe_your_raceethnicity', 'how_would_you_describe_your_raceethnicity_select_all_that_apply', 'primary_language', 'if_you_selected_other_what_language', 'home_street_address_including_apartment_number', 'city', 'state', 'zip_code', 'phone_number', 'email_address', 'number_of_people_in_household', 'educational_status', 'employment_status', 'what_is_the_zip_code_where_you_work', 'are_you_self_employed', 'household_income_level', 'do_you_receive_housing_assistance', 'what_other_boston_neighborhoods_are_you_connected_to_for_example_do_you_receive_services_visit_family_or_friends_go_to_school_or_places_of_worship_in_any_of_the_following_neighborhoods_select_all_that_apply', 'were_you_born_in_the_united_states', 'have_you_ever_spent_time_in_a_jail_prison_or_juvenile_detention_centre', 'how_do_you_describe_your_sexual_orientation_select_all_that_apply', 'other', 'childs_last_name', 'childs_last_name.1', 'what_are_your_pronouns.1', 'childs_date_of_birth', 'what_is_your_gender.1', 'your_gender_identity.1', 'how_would_you_describe_your_raceethnicity.1', 'how_would_you_describe_your_raceethnicity_select_all_that_apply.1', 'primary_language.1', 'if_you_selected_other_what_language.1', 'what_is_your_goal_for_taking_this_course', 'is_this_the_first_activity_youve_participated_in_at_your_program_site', 'how_many_working_computers_do_you_have_at_home', 'how_many_tablets_do_you_have_at_home_e_g_ipad_kindle_fire_samsung_galaxy_tab', 'do_you_have_a_smartphone', 'do_you_have_home_internet_access_i_e_wifi', 'is_your_internet_reliable', 'is_your_internet_reliable.1', 'are_you_aware_of_the_affordable_connectivity_program_acp_an_fcc_federal_communications_commission_program_to_help_families_and_households_afford_internet_service_more_info_here_httpswww_fcc_govacp', 'are_you_currently_enrolled_in_the_acp_program', 'please_describe_your_confidence_level_using_the_internet_to_find_information_you_need', 'creating_and_sending_emails', 'opening_and_replying_to_emails', 'downloading_attachments_i_receive_in_an_email_documents_or_pictures', 'adding_an_attachment_to_an_email_i_am_sending_like_documents_or_pictures', 'turning_the_tablet_on_and_off', 'adjusting_the_tablets_settings_like_the_size_of_the_text_or_the_background_picture', 'connecting_the_tablet_to_wifi', 'installing_applications_from_the_chromebook_store', 'saving_files_to_the_tablet_and_finding_them_later', 'using_a_mouse_headset_andor_other_accessories', 'turning_the_tablet_on_and_off.1', 'adjusting_the_tablets_settings_like_the_size_of_the_text_or_the_background_picture.1', 'connecting_the_tablet_to_wifi.1', 'installing_applications_apps', 'saving_files_to_the_tablet_and_finding_them_later.1', 'do_you_have_an_existing_business', 'name_of_business', 'what_industry_is_your_business_in', 'if_you_selected_other_please_explain', 'do_you_have_a_website_for_your_business', 'what_is_your_website_address_url', 'which_if_any_social_media_tools_do_you_use_for_your_business', 'please_enter_anyall_of_your_social_media_handles_separated_by_a_comma', 'acepto_que_usen_citas_tomen_fotos_y_graben_pelculas_o_videos_mos_o_de_mis_hijos_en_el_programa_de_tech_goes_home_concedo_a_tech_goes_home_el_derecho_de_editar_usar_y_reutilizar_los_productos_mencionados_sin_nimo_de_lucro_incluido_el_uso_impreso_en_internet_y_en_cualquier_formato_multimedia_acepto_estos_trminos_de_forma_voluntaria_y_entiendo_que_no_recibir_ninguna_compensacin_financiera_por_el_presente_documento_libero_a_tech_goes_home_y_sus_agentes_y_empleados_de_cualquier_reclamacin_demanda_y_responsabilidad_en_el_marco_de_lo_anterior_si_no_desea_que_tech_goes_home_use_su_foto_indquelo_a_sus_instructores_de_tgh_para_que_no_nos_enven_fotografas_suyas', 'i_am_aware_of_what_my_skills_are_t ...
# ----------------------------------------
# File: Learner+Enrollment+ENGLISH.csv
# Cleaned Columns: ['submitted_date', 'course_name', 'name_of_siteschool', 'course_type', 'first_name', 'last_name', 'do_you_have_home_internet_access_i_e_wifi', 'what_are_your_pronouns', 'have_you_received_a_tgh_device_chromebook_or_ipad_in_the_last_two_years', 'date_of_birth', 'what_is_your_gender', 'your_gender_identity', 'how_would_you_describe_your_raceethnicity', 'how_would_you_describe_your_raceethnicity_select_all_that_apply', 'primary_language', 'if_you_selected_other_what_language', 'are_you_a_veteran', 'home_street_address_including_apartment_number', 'city', 'state', 'zip_code', 'phone_number', 'email_address', 'number_of_people_in_household', 'educational_status', 'employment_status', 'are_you_self_employed', 'what_is_the_zip_code_where_you_work', 'household_income_level', 'do_you_receive_housing_assistance', 'what_other_boston_neighborhoods_are_you_connected_to_for_example_do_you_receive_services_visit_family_or_friends_go_to_school_or_places_of_worship_in_any_of_the_following_neighborhoods_select_all_that_apply', 'other', 'were_you_born_in_the_united_states', 'have_you_ever_spent_time_in_a_jail_prison_or_juvenile_detention_centre', 'how_do_you_describe_your_sexual_orientation', 'other.1', 'childs_last_name', 'childs_last_name.1', 'what_are_your_pronouns.1', 'childs_date_of_birth', 'what_is_your_gender.1', 'your_gender_identity.1', 'how_would_you_describe_your_raceethnicity.1', 'how_would_you_describe_your_raceethnicity_select_all_that_apply.1', 'primary_language.1', 'if_you_selected_other_what_language.1', 'what_is_your_goal_for_taking_this_course', 'is_this_the_first_activity_youve_participated_in_at_your_program_site', 'how_many_working_computers_do_you_have_at_home', 'how_many_tablets_do_you_have_at_home_e_g_ipad_kindle_fire_samsung_galaxy_tab', 'do_you_have_a_smartphone_e_g_iphone_google_pixel_samsung_galaxy', 'is_your_internet_reliable', 'is_your_internet_reliable.1', 'are_you_aware_of_the_affordable_connectivity_program_acp_an_fcc_federal_communications_commission_program_to_help_families_and_households_afford_internet_service_more_info_here_httpswww_fcc_govacp', 'are_you_currently_enrolled_in_the_acp_program', 'please_describe_your_confidence_level_using_the_internet_to_find_information_you_need', 'creating_and_sending_emails', 'opening_and_replying_to_emails', 'downloading_attachments_i_receive_in_an_email_documents_or_pictures', 'adding_an_attachment_to_an_email_i_am_sending_like_documents_or_pictures', 'turning_the_tablet_on_and_off', 'adjusting_the_tablets_settings_like_the_size_of_the_text_or_the_background_picture', 'connecting_the_tablet_to_wifi', 'installing_applications_from_the_chromebook_store', 'saving_files_to_the_tablet_and_finding_them_later', 'using_a_mouse_headset_andor_other_accessories', 'turning_the_tablet_on_and_off.1', 'adjusting_the_tablets_settings_like_the_size_of_the_text_or_the_background_picture.1', 'connecting_the_tablet_to_wifi.1', 'installing_applications_apps', 'saving_files_to_the_tablet_and_finding_them_later.1', 'i_am_aware_of_what_my_skills_are_to_be_employed_in_a_goodjob_e_g_digital_skills_specific_trade_skills_etc', 'i_am_aware_of_what_my_resources_are_to_be_employed_in_a_good_job_e_g_resources_for_job_searching_child_care_resources_etc', 'i_am_able_to_utilize_my_skills_to_move_toward_career_goals', 'i_am_able_to_utilize_my_skills_to_move_toward_career_goals.1', 'even_if_i_am_not_able_to_achieve_my_financial_goals_right_away_i_will_find_a_way_to_get_there', 'because_of_my_money_situation_i_feel_like_i_will_never_have_thethings_i_want_in_life', 'i_am_just_getting_by_financially', 'i_am_concerned_that_the_money_i_have_or_will_save_wont_last', 'do_you_have_an_existing_business', 'name_of_business', 'what_industry_is_your_business_in', 'if_you_selected_other_please_explain', 'do_you_have_a_website_for_your_business', 'what_is_your_website_address_url', 'which_if_any_social_media_tools_do_you_use_for_your_business', 'please_enter_any_all_of_your_social_media_handles_separate ...
# ----------------------------------------
# File: (OLD) TGH Learner Enrollment Form (6.2.2022).csv
# Cleaned Columns: ['course_name', 'name_of_siteschool', 'course_type', 'first_name', 'last_name', 'have_you_received_a_tgh_device_chromebook_or_ipad_in_the_last_two_years', 'date_of_birth', 'to_which_gender_identity_do_you_most_identify', 'your_gender_identity', 'race_ethnicity', 'your_race_ethnicity', 'primary_language', 'if_you_selected_other_what_language', 'home_street_address_including_apartment_number', 'city', 'state', 'zip_code', 'phone_number', 'email_address', 'number_of_people_in_household', 'educational_status', 'employment_status', 'household_income_level', 'do_you_receive_housing_assistance', 'childs_last_name', 'childs_last_name.1', 'childs_date_of_birth', 'childs_grade', 'your_gender_identity.1', 'your_race_ethnicity.1', 'your_race_ethnicity.2', 'primary_language.1', 'if_you_selected_other_what_language.1', 'what_is_your_goal_for_taking_this_course', 'is_this_the_first_activity_youve_participated_in_at_your_program_site', 'how_many_working_computers_do_you_have_at_home', 'how_many_tablets_do_you_have_at_home_e_g_ipad_kindle_fire_samsung_galaxy_tab', 'do_you_have_a_smartphone_e_g_iphone_google_pixel_samsung_galaxy', 'do_you_have_home_internet_access_i_e_wifi', 'are_you_aware_of_the_affordable_connectivity_program_acp_an_fcc_federal_communications_commission_program_to_help_families_and_households_afford_internet_service_more_info_here_httpswww_fcc_govacp', 'are_you_currently_enrolled_in_the_acp_program', 'please_describe_your_confidence_level_using_the_internet_to_find_information_you_need', 'creating_and_sending_emails', 'opening_and_replying_to_emails', 'downloading_attachments_i_receive_in_an_email_documents_or_pictures', 'adding_an_attachment_to_an_email_i_am_sending_like_documents_or_pictures', 'turning_the_tablet_on_and_off', 'adjusting_the_tablets_settings_like_the_size_of_the_text_or_the_background_picture', 'connecting_the_tablet_to_wifi', 'installing_applications_from_the_chromebook_store', 'saving_files_to_the_tablet_and_finding_them_later', 'using_a_mouse_headset_andor_other_accessories', 'turning_the_tablet_on_and_off.1', 'adjusting_the_tablets_settings_like_the_size_of_the_text_or_the_background_picture.1', 'connecting_the_tablet_to_wifi.1', 'installing_applications_apps', 'saving_files_to_the_tablet_and_finding_them_later.1', 'do_you_have_an_existing_business', 'name_of_business', 'what_industry_is_your_business_in', 'if_you_selected_other_please_explain', 'do_you_have_a_website_for_your_business', 'what_is_your_website_address_url', 'which_if_any_social_media_tools_do_you_use_for_your_business', 'please_enter_any_all_of_your_social_media_handles_separated_by_a_comma_e_g_techgoeshome_facebook_com_yourbusinessname', 'i_hereby_give_the_unqualified_right_to_the_tgh_program_to_take_pictures_and_or_video_of_me_while_participating_in_my_course_i_give_permission_for_these_images_as_well_as_materials_that_we_have_created_in_the_tgh_program_to_be_used_in_print_and_web_based_publications_the_tgh_program_will_put_these_images_to_legitimate_use_without_limitation_or_reservation_if_you_do_not_wish_for_your_photo_to_be_used_by_tgh_please_let_your_tgh_trainers_know_so_they_will_not_send_us_pictures_of_you', 'i_agree_to_the_learner_agreement_as_listed_above', 'course_id', 'form_name', 'creation_date', 'modified_date', 'submitted_date', 'completion_time', 'response_html', 'response_html.1', 'response_text', 'response', 'response.1', 'resume_email', 'file_list', 'unprotected_file_list', 'response.2', 'referrer', 'ip_address']
# ----------------------------------------
# /var/folders/q6/v__5dqvn4fsgnld9cp_x0v1m0000gn/T/ipykernel_23866/719564596.py:34: DtypeWarning: Columns (16,27,30,31,32,33,34,35,49,76,77,78,82,100) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file)
# /var/folders/q6/v__5dqvn4fsgnld9cp_x0v1m0000gn/T/ipykernel_23866/719564596.py:34: DtypeWarning: Columns (14,17,18,31,34,36,78) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file)
# File: (OLD)+TGH+Learner+Enrollment+Form+2025-03-06-11-24-39+457499.csv.csv
# Cleaned Columns: ['submitted_date', 'name_of_siteschool', 'course_type', 'first_name', 'middle_initial', 'last_name', 'do_you_have_school_age_children_in_your_household', 'childs_last_name', 'childs_last_name.1', 'is_this_your_first_activity_program_at_the_school_or_site_where_you_are_taking_tgh', 'employment_status', 'race_ethnicity', 'household_income_level', 'primary_language', 'course_name', 'have_you_received_a_tgh_device_chromebook_or_ipad_in_the_last_two_years', 'date_of_birth', 'to_which_gender_identity_do_you_most_identify', 'if_you_selected_other_please_explain', 'if_you_selected_other_what_type', 'if_you_selected_other_what_language', 'home_street_address_including_apartment_number', 'city', 'state', 'zip', 'phone_number', 'email_address', 'number_of_people_in_household', 'educational_status', 'occupation', 'place_of_work', 'do_you_receive_housing_assistance', 'childs_grade', 'childs_date_of_birth', 'childs_grade.1', 'if_you_selected_other_please_explain.1', 'your_race_ethnicity', 'if_you_selected_other_what_type.1', 'primary_language.1', 'if_you_selected_other_what_language.1', 'what_is_the_main_reason_you_decided_to_participate_in_tgh', 'if_you_selected_other_please_explain.2', 'which_devices_do_you_use_at_home', 'if_you_selected_other_what_type.2', 'number_of_working_computers_at_home', 'do_you_have_home_internet_access_i_e_wifi', 'how_do_you_or_anyone_living_in_your_household_access_the_internet_in_your_home', 'if_you_selected_other_what_type.3', 'how_do_you_or_anyone_living_in_your_household_access_the_internet_in_your_home.1', 'if_you_selected_other_please_explain.3', 'is_your_internet_access_through_a_discounted_program_eg_internet_essentials_pcs_for_people', 'how_satisfied_are_you_with_your_internet_service_at_home', 'if_you_selected_other_please_explain.4', 'why_dont_you_have_internet_access_at_home', 'if_you_selected_other_please_explain.5', 'have_you_ever_had_to_change_or_cancel_your_internet_subscription_because_it_is_too_expensive', 'what_do_you_and_other_household_members_use_the_internet_for', 'what_financial_resources_do_you_use', 'if_you_selected_other_please_explain.6', 'do_you_have_an_existing_business', 'what_best_describes_the_organization_you_are_starting_or_running', 'if_you_selected_other_please_explain.7', 'what_are_the_biggest_challenges_you_are_currently_facing_in_running_your_business_if_you_have_not_yet_started_your_business_what_are_the_biggest_obstacles', 'name_of_business', 'how_old_is_your_business', 'annual_revenue_of_business', 'number_of_employees', 'what_industry_is_your_business_in', 'if_you_selected_other_please_explain.8', 'do_you_accept_credit_debit_cards', 'what_does_your_business_use_the_internet_for', 'if_you_selected_other_please_explain.9', 'do_you_know_of_organizations_that_help_small_business_owners_navigate_licensing_and_permitting_taxes_law_marketing_access_to_funding_and_other_business_issues', 'do_you_have_a_website_for_your_business', 'which_if_any_social_media_tools_do_you_use_for_your_business', 'if_you_selected_other_please_explain.10', 'how_often_are_your_business_social_media_pages_updated', 'i_hereby_give_the_unqualified_right_to_the_tgh_program_to_take_pictures_and_or_video_of_me_while_participating_in_my_course_i_give_permission_for_these_images_as_well_as_materials_that_we_have_created_in_the_tgh_program_to_be_used_in_print_and_web_based_publications_the_tgh_program_will_put_these_images_to_legitimate_use_without_limitation_or_reservation_if_you_do_not_wish_for_your_photo_to_be_used_by_tgh_please_let_your_tgh_trainers_know_so_they_will_not_send_us_pictures_of_you', 'i_agree_to_the_learner_agreement_as_listed_above', 'course_id', 'form_name', 'creation_date', 'modified_date', 'completion_time', 'response_html', 'response_html.1', 'response_text', 'response', 'response.1', 'resume_email', 'file_list', 'unprotected_file_list', 'response.2', 'referrer', 'ip_address']
# ----------------------------------------
# File: cleaned_translated_ES_haitian_creole.csv
# Cleaned Columns: ['course_name', 'name_of_siteschool', 'course_type', 'first_name', 'last_name', 'what_are_your_pronouns', 'have_you_received_a_tgh_device_chromebook_or_ipad_in_the_last_two_years', 'date_of_birth', 'what_is_your_gender', 'your_gender_identity', 'how_would_you_describe_your_raceethnicity', 'how_would_you_describe_your_raceethnicity_select_all_that_apply', 'primary_language', 'if_you_selected_other_what_language', 'home_street_address_including_apartment_number', 'city', 'state', 'zip_code', 'phone_number', 'email_address', 'number_of_people_in_household', 'educational_status', 'employment_status', 'are_you_self_employed', 'what_is_the_zip_code_where_you_work', 'household_income_level', 'do_you_receive_housing_assistance', 'what_other_boston_neighborhoods_are_you_connected_to_for_example_do_you_receive_services_visit_family_or_friends_go_to_school_or_places_of_worship_in_any_of_the_following_neighborhoods_select_all_that_apply', 'other', 'were_you_born_in_the_united_states', 'have_you_ever_spent_time_in_a_jail_prison_or_juvenile_detention_centre', 'how_do_you_describe_your_sexual_orientation_select_all_that_apply', 'other.1', 'childs_last_name', 'childs_last_name.1', 'what_are_your_pronouns.1', 'childs_date_of_birth', 'what_is_your_gender.1', 'idantite_seksyl_pitit_ou_a_your_childs_gender_identity', 'how_would_you_describe_your_raceethnicity.1', 'how_would_you_describe_your_raceethnicity_select_all_that_apply.1', 'primary_language.1', 'if_you_selected_other_what_language.1', 'what_is_your_goal_for_taking_this_course', 'is_this_the_first_activity_youve_participated_in_at_your_program_site', 'how_many_working_computers_do_you_have_at_home', 'how_many_tablets_do_you_have_at_home_e_g_ipad_kindle_fire_samsung_galaxy_tab', 'do_you_have_a_smartphone_e_g_iphone_google_pixel_samsung_galaxy', 'do_you_have_home_internet_access_i_e_wifi', 'is_your_internet_reliable', 'is_your_internet_reliable.1', 'are_you_aware_of_the_affordable_connectivity_program_acp_an_fcc_federal_communications_commission_program_to_help_families_and_households_afford_internet_service_more_info_here_httpswww_fcc_govacp', 'are_you_currently_enrolled_in_the_acp_program', 'please_describe_your_confidence_level_using_the_internet_to_find_information_you_need', 'creating_and_sending_emails', 'opening_and_replying_to_emails', 'downloading_attachments_i_receive_in_an_email_documents_or_pictures', 'adding_an_attachment_to_an_email_i_am_sending_like_documents_or_pictures', 'turning_the_tablet_on_and_off', 'adjusting_the_tablets_settings_like_the_size_of_the_text_or_the_background_picture', 'connecting_the_tablet_to_wifi', 'installing_applications_from_the_chromebook_store', 'saving_files_to_the_tablet_and_finding_them_later', 'using_a_mouse_headset_andor_other_accessories', 'turning_the_tablet_on_and_off.1', 'adjusting_the_tablets_settings_like_the_size_of_the_text_or_the_background_picture.1', 'connecting_the_tablet_to_wifi.1', 'installing_applications_apps', 'saving_files_to_the_tablet_and_finding_them_later.1', 'i_am_aware_of_what_my_skills_are_to_be_employed_in_a_goodjob_e_g_digital_skills_specific_trade_skills_etc', 'i_am_aware_of_what_my_resources_are_to_be_employed_in_a_good_job_e_g_resources_for_job_searching_child_care_resources_etc', 'i_am_able_to_utilize_my_skills_to_move_toward_career_goals', 'i_am_able_to_utilize_my_skills_to_move_toward_career_goals.1', 'even_if_i_am_not_able_to_achieve_my_financial_goals_right_away_i_will_find_a_way_to_get_there', 'because_of_my_money_situation_i_feel_like_i_will_never_have_thethings_i_want_in_life', 'i_am_just_getting_by_financially', 'i_am_concerned_that_the_money_i_have_or_will_save_wont_last', 'do_you_have_an_existing_business', 'non_biznis_la_name_of_business', 'what_industry_is_your_business_in', 'if_you_selected_other_please_explain', 'ske_w_gen_yon_sitwb_pou_biznis_ou_a_do_you_have_a_website_for_your_business', 'what_is_your_website_address_url', 'which_if_any_social_media_tools_do_you_use_for_your_busin ...
# ----------------------------------------
# File: Cleaned_ES_translated_chinese.csv
# Cleaned Columns: ['course_name', 'name_of_siteschool', 'course_type', 'first_name', 'last_name', 'what_are_your_pronouns', 'have_you_received_a_tgh_device_chromebook_or_ipad_in_the_last_two_years', 'date_of_birth', 'what_is_your_gender', 'your_gender_identity', 'how_would_you_describe_your_raceethnicity', 'how_would_you_describe_your_raceethnicity_select_all_that_apply', 'primary_language', 'if_you_selected_other_what_language', 'home_street_address_including_apartment_number', 'city', 'state', 'zip_code', 'phone_number', 'email_address', 'number_of_people_in_household', 'educational_status', 'employment_status', 'are_you_self_employed', 'household_income_level', 'do_you_receive_housing_assistance', 'childs_last_name', 'childs_last_name.1', 'what_are_your_pronouns.1', 'childs_date_of_birth', 'what_is_your_gender.1', 'your_gender_identity.1', 'how_would_you_describe_your_raceethnicity.1', 'how_would_you_describe_your_raceethnicity_select_all_that_apply.1', 'primary_language.1', 'if_you_selected_other_what_language.1', 'what_is_your_goal_for_taking_this_course', 'is_this_the_first_activity_youve_participated_in_at_your_program_site', 'how_many_working_computers_do_you_have_at_home', 'how_many_tablets_do_you_have_at_home_e_g_ipad_kindle_fire_samsung_galaxy_tab', 'do_you_have_a_smartphone_e_g_iphone_google_pixel_samsung_galaxy', 'do_you_have_home_internet_access_i_e_wifi', 'is_your_internet_reliable', 'is_your_internet_reliable.1', 'are_you_aware_of_the_affordable_connectivity_program_acp_an_fcc_federal_communications_commission_program_to_help_families_and_households_afford_internet_service_more_info_here_httpswww_fcc_govacp', 'are_you_currently_enrolled_in_the_acp_program', 'please_describe_your_confidence_level_using_the_internet_to_find_information_you_need', 'creating_and_sending_emails', 'opening_and_replying_to_emails', 'downloading_attachments_i_receive_in_an_email_documents_or_pictures', 'adding_an_attachment_to_an_email_i_am_sending_like_documents_or_pictures', 'turning_the_tablet_on_and_off', 'adjusting_the_tablets_settings_like_the_size_of_the_text_or_the_background_picture', 'connecting_the_tablet_to_wifi', 'installing_applications_from_the_chromebook_store', 'saving_files_to_the_tablet_and_finding_them_later', 'using_a_mouse_headset_andor_other_accessories', 'turning_the_tablet_on_and_off.1', 'adjusting_the_tablets_settings_like_the_size_of_the_text_or_the_background_picture.1', 'connecting_the_tablet_to_wifi.1', 'installing_applications_apps', 'saving_files_to_the_tablet_and_finding_them_later.1', 'do_you_have_an_existing_business', 'name_of_business', 'what_industry_is_your_business_in', 'if_you_selected_other_please_explain', 'do_you_have_a_website_for_your_business', 'what_is_your_website_address_url', 'which_if_any_social_media_tools_do_you_use_for_your_business', 'please_enter_any_all_of_your_social_media_handles_separated_by_a_comma_e_g_techgoeshome_facebook_com_yourbusinessname', 'tech_goes_home_tech_goes_home_tech_goes_home_tech_goes_home_tgh', 'i_agree_to_the_learner_agreement_as_listed_above', 'course_id', 'fa_list_learner_enrollment_english_1', 'form_name', 'creation_date', 'modified_date', 'submitted_date', 'completion_time', 'response_html', 'response_html.1', 'response_text', 'response', 'response.1', 'resume_email', 'file_list', 'unprotected_file_list', 'response.2', 'referrer', 'ip_address']
# ----------------------------------------

# %%
#cleaning the column names

import os
import pandas as pd

# Specify the directory containing your CSV and XLSM files
files_path = '/Users/sreeharsha/Documents/TGH Data Management Cleaning/Merge testing/Enrollment Survey'  # Update this path

# Gather all CSV and XLSM file paths
all_files = []
for file in os.listdir(files_path):
    if file.endswith('.csv') or file.endswith('.xlsm'):
        all_files.append(os.path.join(files_path, file))

# Function to clean and standardize column names:
def clean_column_names(columns):
    """
    Cleans column names by stripping leading/trailing whitespace and converting to lowercase.
    Additional cleaning (like replacing spaces with underscores) can be added as needed.
    """
    return [col.strip().lower() for col in columns]

# Dictionary to store file names and their cleaned columns as sets
file_columns = {}

for file in all_files:
    # Read file based on type
    if file.endswith('.csv'):
        df = pd.read_csv(file)
    else:  # for .xlsm files, read the first sheet by default
        df = pd.read_excel(file)
    
    # Clean the column names
    cleaned_cols = clean_column_names(df.columns.tolist())
    
    # Save the unique cleaned columns as a set
    file_columns[os.path.basename(file)] = set(cleaned_cols)

# Compute the union and intersection of all columns across the files
all_union = set()
all_intersection = None

for file, cols in file_columns.items():
    all_union |= cols  # union of all columns
    if all_intersection is None:
        all_intersection = cols.copy()
    else:
        all_intersection &= cols  # intersection of columns

# Determine counts
matching_count = len(all_intersection)
non_matching_columns = all_union - all_intersection
non_matching_count = len(non_matching_columns)

# Print the results
print("=== Columns per File ===")
for file, cols in file_columns.items():
    print(f"{file}: {sorted(cols)}")
    print("-" * 40)

print("\n=== Summary ===")
print("Matching columns (present in all files):")
print(sorted(all_intersection))
print("Count of matching columns:", matching_count)
print("\nNon-matching columns (not present in all files):")
print(sorted(non_matching_columns))
print("Count of non-matching columns:", non_matching_count)
# Out:
# /var/folders/q6/v__5dqvn4fsgnld9cp_x0v1m0000gn/T/ipykernel_23866/182775922.py:29: DtypeWarning: Columns (16,27,30,31,32,33,34,35,48,75,76,77,81,99) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file)
# /var/folders/q6/v__5dqvn4fsgnld9cp_x0v1m0000gn/T/ipykernel_23866/182775922.py:29: DtypeWarning: Columns (14,17,18,31,34,36,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file)
# === Columns per File ===
# Learner+Enrollment+ENGLISH.csv: ['8. how would you describe your race/ethnicity?', 'adding an attachment to an email i am sending (like documents or pictures)', "adjusting the computer's settings (like the size of the text or the background picture)", "adjusting the tablet's settings (like the size of the text or the background picture)", 'are you a veteran?', 'are you aware of the affordable connectivity program (acp), an fcc (federal communications commission) program to help families and households afford internet service? (more info here: https://www.fcc.gov/acp)', 'are you currently enrolled in the acp program?', 'are you self-employed?', 'because of my money situation, i feel like i will never have thethings i want in life.', "child's date of birth", "child's first name", "child's last name", "child's primary language", 'city', 'completion time', 'connecting the computer to wifi', 'connecting the tablet to wifi', 'course id', 'course name', 'course type', 'creating and sending emails', 'creation date', 'date of birth', 'do you have a smartphone? (e.g. iphone, google pixel, samsung galaxy)', 'do you have a website for your business?', 'do you have an existing business?', 'do you have home internet access (i.e. wifi)?', 'do you receive housing assistance?', 'downloading attachments i receive in an email (documents or pictures)', 'educational status', 'email address', 'employment status', 'even if i am not able to achieve my financial goals right away, i will find a way to get there.', 'fa list: learner enrollment english (1.1.23)', 'file list', 'first name', 'form name', 'have you ever spent time in a jail, prison, or juvenile detention center?', 'have you received a tgh device (chromebook or ipad) in the last two years?', 'home street address (including apartment number)', 'household income level', 'how do you describe your sexual orientation?', 'how many tablets do you have at home? (e.g. ipad, kindle fire, samsung galaxy tab)', 'how many working computers do you have at home?', "how would you describe your child's race/ethnicity? (select all that apply)", 'how would you describe your race/ethnicity? (select all that apply)', 'i agree to the learner agreement as listed above', 'i am able to utilize my resources to move toward career goals.', 'i am able to utilize my skills to move toward career goals.', 'i am aware of what my resources are to be employed in a good job (e.g., resources for job searching, child care resources, etc.).', 'i am aware of what my skills are to be employed in a goodjob (e.g., digital skills, specific trade skills, etc.).', 'i am concerned that the money i have or will save won’t last.', 'i am just getting by financially.', 'i consent to the use of quotes, and the taking of photos, movies, or videos of my child and me in the tech goes home program. i grant tech goes home the right to edit, use, and reuse said products for nonprofit purposes, including use in print, on the internet, and all other forms of media. i understand that my agreement to these terms is voluntary, and i will receive no financial compensation. i also hereby release tech goes home and its agents and employees from all claims, demands, and liabilities whatsoever in connection with the above. if you do not wish for your photo to be used by tech goes home, please let your tgh instructors know so they will not send us pictures of you.', 'if you selected "other," please explain:', 'installing applications (apps)', 'installing applications from the chromebook store', 'ip address', "is this the first activity you've participated in at your program site?", 'is your internet affordable?', 'is your internet reliable?', 'last name', 'modified date', 'name of business', 'name of site/school', 'number of people in household', 'opening and replying to emails', 'other_child_language?', 'other_language', 'other_neighborhoods', 'other_sexual_orientation', 'phone number', 'please describe your confidence level using the internet to find inform ...
# ----------------------------------------
# translated_spanish.xlsm: ['acepto que usen citas, tomen fotos y graben pel√≠culas o videos m√≠os o de mis hijos en el programa de tech goes home. concedo a tech goes home el derecho de editar, usar y reutilizar los productos mencionados sin √°nimo de lucro, incluido el uso impreso, en internet y en cualquier formato multimedia. acepto estos t√©rminos de forma voluntaria y entiendo que no recibir√© ninguna compensaci√≥n financiera. por el presente documento, libero a tech goes home y sus agentes y empleados de cualquier reclamaci√≥n, demanda y responsabilidad en el marco de lo anterior. si no desea que tech goes home use su foto, ind√≠quelo a sus instructores de tgh para que no nos env√≠en fotograf√≠as suyas.', 'adding an attachment to an email i am sending (like documents or pictures)', "adjusting the computer's settings (like the size of the text or the background picture)", "adjusting the tablet's settings (like the size of the text or the background picture)", 'are you aware of the affordable connectivity program (acp), an fcc (federal communications commission) program to help families and households afford internet service? (more info here: https://www.fcc.gov/acp)', 'are you currently enrolled in the acp program?', 'are you self-employed?', "child's date of birth", "child's first name", "child's last name", "child's primary language", 'city', 'completion time', 'connecting the computer to wifi', 'connecting the tablet to wifi', 'course id', 'course name', 'course type', 'creating and sending emails', 'creation date', 'date of birth', 'do you have a smartphone?', 'do you have a website for your business?', 'do you have an existing business?', 'do you have home internet access (i.e. wifi)?', 'do you receive housing assistance?', 'downloading attachments i receive in an email (documents or pictures)', 'due to my financial situation, i feel that i will never have the things i want in life.', 'educational status', 'email address', 'employment status', 'even if i am not able to achieve my financial goals right away, i will find a way to get there.', 'fa list: learner enrollment spanish (3.8.23)', 'file list', 'first name', 'form name', 'have you ever spent time in a jail, prison, or juvenile detention centre?', 'have you received a tgh device (chromebook or ipad) in the last two years?', 'home street address (including apartment number)', 'household income level', 'how do you describe your sexual orientation? select all that apply.', 'how many tablets do you have at home? (e.g. ipad, kindle fire, samsung galaxy tab)', 'how many working computers do you have at home?', "how would you describe your child's race/ethnicity", "how would you describe your child's race/ethnicity? (select all that apply)", 'how would you describe your race/ethnicity?', 'how would you describe your race/ethnicity? (select all that apply)', 'i agree to the learner agreement as listed above', 'i am able to utilize my resources to move toward career goals', 'i am able to utilize my skills to move toward career goals.', 'i am aware of what my resources are to be employed in a good job (e.g., resources for job searching, child care resources, etc.).', 'i am aware of what my skills are to achieve a good employment (e.g. digital knowledge, job-specific skills, etc.).', 'i am concerned that the money i have or will save won‚äôt last.', 'i am just getting by financially.', 'if you selected "other", what language?', 'if you selected "other," please explain:', 'if you selected "other," what language?', 'installing applications (apps)', 'installing applications from the chromebook store', 'ip address', "is this the first activity you've participated in at your program site?", 'is your internet affordable?', 'is your internet reliable?', 'last name', 'modified date', 'name of business', 'name of site/school', 'number of people in household', 'opening and replying to emails', 'other', 'phone number', 'please describe your confidence level using the internet to find  ...
# ----------------------------------------
# (OLD) TGH Learner Enrollment Form (6.2.2022).csv: ['adding an attachment to an email i am sending (like documents or pictures)', "adjusting the computer's settings (like the size of the text or the background picture)", "adjusting the tablet's settings (like the size of the text or the background picture)", 'are you aware of the affordable connectivity program (acp), an fcc (federal communications commission) program to help families and households afford internet service? (more info here: https://www.fcc.gov/acp)', 'are you currently enrolled in the acp program?', "child's date of birth", "child's first name", "child's gender", "child's last name", "child's primary language", "child's race/ethnicity", 'city', 'completion time', 'connecting the computer to wifi', 'connecting the tablet to wifi', 'course id', 'course name', 'course type', 'creating and sending emails', 'creation date', 'date of birth', 'do you have a smartphone? (e.g. iphone, google pixel, samsung galaxy)', 'do you have a website for your business?', 'do you have an existing business?', 'do you have home internet access (i.e. wifi)?', 'do you receive housing assistance?', 'downloading attachments i receive in an email (documents or pictures)', 'educational status', 'email address', 'employment status', 'file list', 'first name', 'form name', 'have you received a tgh device (chromebook or ipad) in the last two years?', 'home street address (including apartment number)', 'household income level', 'how many tablets do you have at home? (e.g. ipad, kindle fire, samsung galaxy tab)', 'how many working computers do you have at home?', 'i agree to the learner agreement as listed above', 'i hereby give the unqualified right to the tgh program to take pictures and/ or video of me while participating in my course. i give permission for these images as well as materials that we have created in the tgh program to be used in print and web-based publications. the tgh program will put these images to legitimate use without limitation or reservation. if you do not wish for your photo to be used by tgh, please let your tgh instructors know so they will not send us pictures of you.', 'if you selected "other", please explain:', 'if you selected "other", what language?', 'installing applications (apps)', 'installing applications from the chromebook store', 'ip address', "is this the first activity you've participated in at your program site?", 'last name', 'modified date', 'name of business', 'name of site/school', 'number of people in household', 'opening and replying to emails', 'other_primary_language', 'phone number', 'please describe your confidence level using the internet to find information you need:', 'please enter any/all of your social media handles separated by a comma(,) (e.g. @techgoeshome, facebook.com/yourbusinessname)', 'primary language', 'race/ethnicity', 'referrer', 'response', 'response html', 'response html beta', 'response id', 'response text', 'response url', 'resume email', 'saving files to the computer and finding them later', 'saving files to the tablet and finding them later', 'state', 'submitted date', 'to which gender identity do you most identify?', 'turning the computer on and off', 'turning the tablet on and off', 'unprotected file list', 'using a mouse, headset and/or other accessories', 'what industry is your business in?', 'what is your goal for taking this course?', 'what is your website address (url)?', 'which, if any, social media tools do you use for your business?', "your child's gender identity:", "your child's race/ethnicity:", 'your gender identity:', 'your race/ethnicity', 'zip code']
# ----------------------------------------
# (OLD)+TGH+Learner+Enrollment+Form+2025-03-06-11-24-39+457499.csv.csv: ['annual revenue of business', "child's date of birth", "child's first name", "child's gender", "child's grade", "child's last name", "child's primary language", "child's race/ethnicity", 'city', 'completion time', 'course id', 'course name', 'course type', 'creation date', 'date of birth', 'do you accept credit/debit cards?', 'do you have a website for your business?', 'do you have an existing business?', 'do you have home internet access (i.e. wifi)?', 'do you have school age children in your household?', 'do you know of organizations that help small business owners navigate licensing and permitting, taxes, law, marketing, access to funding, and other business issues?', 'do you receive housing assistance?', 'educational status', 'email address', 'employment status', 'file list', 'financial_other', 'first name', 'form name', 'have you ever had to change or cancel your internet subscription because it is too expensive?', 'have you received a tgh device (chromebook or ipad) in the last two years?', 'home street address (including apartment number)', 'household income level', 'how do you (or anyone living in your household) access the internet in your home?', 'how often are your business social media pages updated?', 'how old is your business?', 'how satisfied are you with your internet service at home?', 'i agree to the learner agreement as listed above', 'i hereby give the unqualified right to the tgh program to take pictures and/ or video of me while participating in my course. i give permission for these images as well as materials that we have created in the tgh program to be used in print and web-based publications. the tgh program will put these images to legitimate use without limitation or reservation. if you do not wish for your photo to be used by tgh, please let your tgh trainers know so they will not send us pictures of you.', 'if you selected "other", please explain:', 'if you selected "other", please specify:', 'if you selected "other", what language?', 'if you selected "other", what race/ethnicity?', 'if you selected "other", what type of device?', 'if you selected "other", what type?', 'if you selected other, please specify:', 'ip address', 'is this your first activity/program at the school or site where you are taking tgh?', 'is your internet access through a discounted program? (eg. internet essentials, pcs for people)', 'last name', 'middle initial', 'modified date', 'name of business', 'name of site/school', 'number of employees', 'number of members in household', 'number of working computers at home', 'occupation', 'other_business_industry', 'other_internet_cause', 'other_internet_use_for_business', 'other_language', 'other_race/ethnicity', 'phone number', 'place of work', 'primary language', 'race/ethnicity', 'referrer', 'response', 'response html', 'response html beta', 'response id', 'response text', 'response url', 'resume email', 'state', 'submitted date', 'to which gender identity do you most identify?', 'unprotected file list', 'what are the biggest challenges you are currently facing in running your business? if you have not yet started your business, what are the biggest obstacles?', 'what best describes the organization you are starting or running?', 'what do you and other household members use the internet for?', 'what does your business use the internet for?', 'what financial resources do you use?', 'what industry is your business in?', 'what is the main reason you decided to participate in tgh?', 'which devices do you (or anyone living in your household) use to access the internet in your home?', 'which devices do you use at home?', 'which, if any, social media tools do you use for your business?', "why don't you have internet access at home?", 'zip']
# ----------------------------------------
# Cleaned_ES_translated_chinese.csv: ['adding an attachment to an email i am sending like documents or pictures', 'adjusting the tablets settings like the size of the text or the background picture', 'are you aware of the affordable connectivity program acp an fcc federal communications commission program to help families and households afford internet service more info here httpswww fcc govacp', 'are you currently enrolled in the acp program', 'are you self employed', 'childs date of birth', 'childs first name', 'childs last name', 'childs primary language', 'city', 'completion time', 'connecting the tablet to wifi', 'course id', 'course name', 'course type', 'creating and sending emails', 'creation date', 'date of birth', 'do you have a smartphone e g iphone google pixel samsung galaxy', 'do you have a website for your business', 'do you have an existing business', 'do you have home internet access i e wifi', 'do you receive housing assistance', 'downloading attachments i receive in an email documents or pictures', 'educational status', 'email address', 'employment status', 'fa list learner enrollment english 1', 'file list', 'first name', 'form name', 'have you received a tgh device chromebook or ipad in the last two years', 'home street address including apartment number', 'household income level', 'how many tablets do you have at home e g ipad kindle fire samsung galaxy tab', 'how many working computers do you have at home', 'how would you describe your childs raceethnicity', 'how would you describe your raceethnicity select all that apply', 'i agree to the learner agreement as listed above', 'if you selected other please explain', 'if you selected other what language', 'installing applications from the chromebook store', 'ip address', 'is this the first activity youve participated in at your program site', 'is your internet affordable', 'is your internet reliable', 'last name', 'modified date', 'name of business', 'name of siteschool', 'number of people in household', 'opening and replying to emails', 'phone number', 'please describe your confidence level using the internet to find information you need', 'please enter any all of your social media handles separated by a comma e g techgoeshome facebook com yourbusinessname', 'primary language', 'referrer', 'response', 'response text', 'response_html', 'resume email', 'saving files to the tablet and finding them later', 'state', 'submitted date', 'tech goes home tech goes home tech goes home tech goes home tgh', 'turning the tablet on and off', 'unnamed: 33', 'unprotected file list', 'using a mouse headset andor other accessories', 'what are your childs pronouns', 'what are your pronouns', 'what industry is your business in', "what is your child's gender", 'what is your gender', 'what is your goal for taking this course', 'what is your website address url', 'which if any social media tools do you use for your business', "your child's gender identity", 'your gender identity', 'zip code']
# ----------------------------------------
# translated_haitian_creole.xlsm: ['adding an attachment to an email i am sending (like documents or pictures)', "adjusting the computer's settings (like the size of the text or the background picture)", "adjusting the tablet's settings (like the size of the text or the background picture)", 'are you aware of the affordable connectivity program (acp), an fcc (federal communications commission) program to help families and households afford internet service? (more info here: https://www.fcc.gov/acp)', 'are you currently enrolled in the acp program?', 'are you self-employed?', 'because of my money situation, i feel like i yesll never have the things i want in life.', "child's date of birth", "child's first name", "child's last name", "child's other language", "child's primary language", 'city', 'completion time', 'connecting the computer to yesfi', 'connecting the tablet to yesfi', 'course id', 'course name', 'course type', 'creating and sending emails', 'creation date', 'date of birth', 'do you have a smartphone? (e.g. iphone, google pixel, samsung galaxy)', 'do you have a website for your business?', 'do you have an existing business?', 'do you have home internet access (i.e. yesfi)?', 'do you receive housing assistance?', 'downloading attachments i receive in an email (documents or pictures)', 'educational status', 'email address', 'employment status', 'even if i am not able to achieve my financial goals right away, i yesll find a way to get there.', 'fa list: learner enrollment haitian creole (3.8.23)', 'file list', 'first name', 'form name', 'have you ever spent time in a jail, prison, or juvenile detention centre?', 'have you received a tgh device (chromebook or ipad) in the last two years?', 'home street address (including apartment number)', 'household income level', 'how do you describe your sexual orientation? select all that apply.', 'how many tablets do you have at home? (e.g. ipad, kindle fire, samsung galaxy tab)', 'how many working computers do you have at home?', "how would you describe your child's race/ethnicity:", "how would you describe your child's race/ethnicity? (select all that apply)", 'how would you describe your race/ethnicity?', 'how would you describe your race/ethnicity? (select all that apply)', 'i agree to the learner agreement as listed above', 'i am able to utilize my resources to move toward career goals', 'i am able to utilize my skills to move toward career goals.', 'i am aware of what my resources are to be employed in a good job (e.g., resources for job searching, child care resources, etc.).', 'i am aware of what my skills are to be employed in a good job (e.g., digital skills, specific trade skills, etc.).', 'i am concerned that the money i have or yesll save won‚äôt last.', 'i am just getting by financially.', 'if you selected "other," please explain:', 'if you selected "other," what language?', 'installing applications (apps)', 'installing applications from the chromebook store', 'ip address', "is this the first activity you've participated in at your program site?", 'is your internet affordable?', 'is your internet reliable?', 'last name', 'modified date', 'name of business', 'name of site/school', 'number of people in household', 'opening and replying to emails', 'other_neighboorhood', 'phone number', 'please describe your confidence level using the internet to find information you need:', 'please enter any/all of your social media handles separated by a comma(,) (e.g. @techgoeshome, facebook.com/yourbusinessname)', 'primary language', 'referrer', 'response', 'response html', 'response html beta', 'response id', 'response text', 'response url', 'resume email', 'saving files to the computer and finding them later', 'saving files to the tablet and finding them later', 'state', 'submitted date', 'turning the computer on and off', 'turning the tablet on and off', 'unprotected file list', 'using a mouse, headset, and/or other accessories', 'were you born in the united states?', "what are you ...
# ----------------------------------------
#
# === Summary ===
# Matching columns (present in all files):
# ['city', 'completion time', 'course id', 'course name', 'course type', 'creation date', 'date of birth', 'educational status', 'email address', 'employment status', 'file list', 'first name', 'form name', 'household income level', 'i agree to the learner agreement as listed above', 'ip address', 'last name', 'modified date', 'name of business', 'phone number', 'primary language', 'referrer', 'response', 'response text', 'resume email', 'state', 'submitted date', 'unprotected file list']
# Count of matching columns: 28
#
# Non-matching columns (not present in all files):
# ['8. how would you describe your race/ethnicity?', 'acepto que usen citas, tomen fotos y graben pel√≠culas o videos m√≠os o de mis hijos en el programa de tech goes home. concedo a tech goes home el derecho de editar, usar y reutilizar los productos mencionados sin √°nimo de lucro, incluido el uso impreso, en internet y en cualquier formato multimedia. acepto estos t√©rminos de forma voluntaria y entiendo que no recibir√© ninguna compensaci√≥n financiera. por el presente documento, libero a tech goes home y sus agentes y empleados de cualquier reclamaci√≥n, demanda y responsabilidad en el marco de lo anterior. si no desea que tech goes home use su foto, ind√≠quelo a sus instructores de tgh para que no nos env√≠en fotograf√≠as suyas.', 'adding an attachment to an email i am sending (like documents or pictures)', 'adding an attachment to an email i am sending like documents or pictures', "adjusting the computer's settings (like the size of the text or the background picture)", "adjusting the tablet's settings (like the size of the text or the background picture)", 'adjusting the tablets settings like the size of the text or the background picture', 'annual revenue of business', 'are you a veteran?', 'are you aware of the affordable connectivity program (acp), an fcc (federal communications commission) program to help families and households afford internet service? (more info here: https://www.fcc.gov/acp)', 'are you aware of the affordable connectivity program acp an fcc federal communications commission program to help families and households afford internet service more info here httpswww fcc govacp', 'are you currently enrolled in the acp program', 'are you currently enrolled in the acp program?', 'are you self employed', 'are you self-employed?', 'because of my money situation, i feel like i will never have thethings i want in life.', 'because of my money situation, i feel like i yesll never have the things i want in life.', "child's date of birth", "child's first name", "child's gender", "child's grade", "child's last name", "child's other language", "child's primary language", "child's race/ethnicity", 'childs date of birth', 'childs first name', 'childs last name', 'childs primary language', 'connecting the computer to wifi', 'connecting the computer to yesfi', 'connecting the tablet to wifi', 'connecting the tablet to yesfi', 'creating and sending emails', 'do you accept credit/debit cards?', 'do you have a smartphone e g iphone google pixel samsung galaxy', 'do you have a smartphone?', 'do you have a smartphone? (e.g. iphone, google pixel, samsung galaxy)', 'do you have a website for your business', 'do you have a website for your business?', 'do you have an existing business', 'do you have an existing business?', 'do you have home internet access (i.e. wifi)?', 'do you have home internet access (i.e. yesfi)?', 'do you have home internet access i e wifi', 'do you have school age children in your household?', 'do you know of organizations that help small business owners navigate licensing and permitting, taxes, law, marketing, access to funding, and other business issues?', 'do you receive housing assistance', 'do you receive housing assistance?', 'downloading attachments i receive in an email (documents or pictures)', 'downloading attachments i receive in an email documents or pictures', 'due to my financial situation, i feel that i will never have the things i want in life.', 'even if i am not able to achieve my financial goals right away, i will find a way to get there.', 'even if i am not able to achieve my financial goals right away, i yesll find a way to get there.', 'fa list learner enrollment english 1', 'fa list: learner enrollment english (1.1.23)', 'fa list: learner enrollment haitian creole (3.8.23)', 'fa list: learner enrollment spanish (3.8.23)', 'financial_other', 'have you ever had to change or cancel your internet subscription because it is too expensive?', 'have you ever spent time in a jail, prison, o ...
# Count of non-matching columns: 198

# %%
#standardizing the column names


import os
import pandas as pd
import re
import unicodedata

# Directory containing your CSV and XLSM files
files_path = "/Users/sreeharsha/Documents/TGH Data Management Cleaning/Merge testing/Enrollment Survey"  # Update this path

# Gather all CSV and XLSM file paths
all_files = [os.path.join(files_path, f) for f in os.listdir(files_path) if f.endswith('.csv') or f.endswith('.xlsm')]

def normalize_column_name(col):
    """
    Normalize a column name by stripping whitespace, converting to lowercase,
    normalizing accented characters, removing punctuation, and replacing spaces with underscores.
    """
    # Remove leading/trailing spaces and convert to lowercase
    col = col.strip().lower()
    # Normalize unicode (e.g., remove accents)
    col = unicodedata.normalize('NFKD', col).encode('ASCII', 'ignore').decode('utf-8')
    # Remove punctuation (anything that is not a word character or whitespace)
    col = re.sub(r'[^\w\s]', '', col)
    # Replace one or more whitespace with a single underscore
    col = re.sub(r'\s+', '_', col)
    return col

# Dictionary to store file names and their normalized column sets
file_columns = {}

for file in all_files:
    # Read file depending on its type
    if file.endswith('.csv'):
        df = pd.read_csv(file)
    else:  # for .xlsm files, read the first sheet by default
        df = pd.read_excel(file)
    
    # Normalize the column names
    normalized_cols = [normalize_column_name(col) for col in df.columns.tolist()]
    
    # Save the unique normalized columns as a set
    file_columns[os.path.basename(file)] = set(normalized_cols)

# Compute the union (all unique columns) and intersection (common to every file)
all_union = set()
all_intersection = None

for cols in file_columns.values():
    all_union |= cols  # accumulate union of columns
    if all_intersection is None:
        all_intersection = cols.copy()
    else:
        all_intersection &= cols  # intersect with columns from the next file

# Determine counts
matching_count = len(all_intersection)
non_matching_columns = all_union - all_intersection
non_matching_count = len(non_matching_columns)

# Print the results
print("=== Normalized Columns per File ===")
for file, cols in file_columns.items():
    print(f"{file}: {sorted(cols)}")
    print("-" * 40)

print("\n=== Summary ===")
print("Matching columns (present in all files):")
print(sorted(all_intersection))
print("Count of matching columns:", matching_count)
print("\nNon-matching columns (not present in all files):")
print(sorted(non_matching_columns))
print("Count of non-matching columns:", non_matching_count)
# Out:
# /var/folders/q6/v__5dqvn4fsgnld9cp_x0v1m0000gn/T/ipykernel_23866/1268297189.py:36: DtypeWarning: Columns (16,27,30,31,32,33,34,35,48,75,76,77,81,99) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file)
# /var/folders/q6/v__5dqvn4fsgnld9cp_x0v1m0000gn/T/ipykernel_23866/1268297189.py:36: DtypeWarning: Columns (14,17,18,31,34,36,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file)
# === Normalized Columns per File ===
# Learner+Enrollment+ENGLISH.csv: ['8_how_would_you_describe_your_raceethnicity', 'adding_an_attachment_to_an_email_i_am_sending_like_documents_or_pictures', 'adjusting_the_computers_settings_like_the_size_of_the_text_or_the_background_picture', 'adjusting_the_tablets_settings_like_the_size_of_the_text_or_the_background_picture', 'are_you_a_veteran', 'are_you_aware_of_the_affordable_connectivity_program_acp_an_fcc_federal_communications_commission_program_to_help_families_and_households_afford_internet_service_more_info_here_httpswwwfccgovacp', 'are_you_currently_enrolled_in_the_acp_program', 'are_you_selfemployed', 'because_of_my_money_situation_i_feel_like_i_will_never_have_thethings_i_want_in_life', 'childs_date_of_birth', 'childs_first_name', 'childs_last_name', 'childs_primary_language', 'city', 'completion_time', 'connecting_the_computer_to_wifi', 'connecting_the_tablet_to_wifi', 'course_id', 'course_name', 'course_type', 'creating_and_sending_emails', 'creation_date', 'date_of_birth', 'do_you_have_a_smartphone_eg_iphone_google_pixel_samsung_galaxy', 'do_you_have_a_website_for_your_business', 'do_you_have_an_existing_business', 'do_you_have_home_internet_access_ie_wifi', 'do_you_receive_housing_assistance', 'downloading_attachments_i_receive_in_an_email_documents_or_pictures', 'educational_status', 'email_address', 'employment_status', 'even_if_i_am_not_able_to_achieve_my_financial_goals_right_away_i_will_find_a_way_to_get_there', 'fa_list_learner_enrollment_english_1123', 'file_list', 'first_name', 'form_name', 'have_you_ever_spent_time_in_a_jail_prison_or_juvenile_detention_center', 'have_you_received_a_tgh_device_chromebook_or_ipad_in_the_last_two_years', 'home_street_address_including_apartment_number', 'household_income_level', 'how_do_you_describe_your_sexual_orientation', 'how_many_tablets_do_you_have_at_home_eg_ipad_kindle_fire_samsung_galaxy_tab', 'how_many_working_computers_do_you_have_at_home', 'how_would_you_describe_your_childs_raceethnicity_select_all_that_apply', 'how_would_you_describe_your_raceethnicity_select_all_that_apply', 'i_agree_to_the_learner_agreement_as_listed_above', 'i_am_able_to_utilize_my_resources_to_move_toward_career_goals', 'i_am_able_to_utilize_my_skills_to_move_toward_career_goals', 'i_am_aware_of_what_my_resources_are_to_be_employed_in_a_good_job_eg_resources_for_job_searching_child_care_resources_etc', 'i_am_aware_of_what_my_skills_are_to_be_employed_in_a_goodjob_eg_digital_skills_specific_trade_skills_etc', 'i_am_concerned_that_the_money_i_have_or_will_save_wont_last', 'i_am_just_getting_by_financially', 'i_consent_to_the_use_of_quotes_and_the_taking_of_photos_movies_or_videos_of_my_child_and_me_in_the_tech_goes_home_program_i_grant_tech_goes_home_the_right_to_edit_use_and_reuse_said_products_for_nonprofit_purposes_including_use_in_print_on_the_internet_and_all_other_forms_of_media_i_understand_that_my_agreement_to_these_terms_is_voluntary_and_i_will_receive_no_financial_compensation_i_also_hereby_release_tech_goes_home_and_its_agents_and_employees_from_all_claims_demands_and_liabilities_whatsoever_in_connection_with_the_above_if_you_do_not_wish_for_your_photo_to_be_used_by_tech_goes_home_please_let_your_tgh_instructors_know_so_they_will_not_send_us_pictures_of_you', 'if_you_selected_other_please_explain', 'installing_applications_apps', 'installing_applications_from_the_chromebook_store', 'ip_address', 'is_this_the_first_activity_youve_participated_in_at_your_program_site', 'is_your_internet_affordable', 'is_your_internet_reliable', 'last_name', 'modified_date', 'name_of_business', 'name_of_siteschool', 'number_of_people_in_household', 'opening_and_replying_to_emails', 'other_child_language', 'other_language', 'other_neighborhoods', 'other_sexual_orientation', 'phone_number', 'please_describe_your_confidence_level_using_the_internet_to_find_information_you_need', 'please_enter_anyall_of_your_social_media_handles_separated_by_a_comma_eg_techgoeshome_facebookcomyourbusinessname', 'pri ...
# ----------------------------------------
# translated_spanish.xlsm: ['acepto_que_usen_citas_tomen_fotos_y_graben_pelculas_o_videos_mos_o_de_mis_hijos_en_el_programa_de_tech_goes_home_concedo_a_tech_goes_home_el_derecho_de_editar_usar_y_reutilizar_los_productos_mencionados_sin_nimo_de_lucro_incluido_el_uso_impreso_en_internet_y_en_cualquier_formato_multimedia_acepto_estos_trminos_de_forma_voluntaria_y_entiendo_que_no_recibir_ninguna_compensacin_financiera_por_el_presente_documento_libero_a_tech_goes_home_y_sus_agentes_y_empleados_de_cualquier_reclamacin_demanda_y_responsabilidad_en_el_marco_de_lo_anterior_si_no_desea_que_tech_goes_home_use_su_foto_indquelo_a_sus_instructores_de_tgh_para_que_no_nos_enven_fotografas_suyas', 'adding_an_attachment_to_an_email_i_am_sending_like_documents_or_pictures', 'adjusting_the_computers_settings_like_the_size_of_the_text_or_the_background_picture', 'adjusting_the_tablets_settings_like_the_size_of_the_text_or_the_background_picture', 'are_you_aware_of_the_affordable_connectivity_program_acp_an_fcc_federal_communications_commission_program_to_help_families_and_households_afford_internet_service_more_info_here_httpswwwfccgovacp', 'are_you_currently_enrolled_in_the_acp_program', 'are_you_selfemployed', 'childs_date_of_birth', 'childs_first_name', 'childs_last_name', 'childs_primary_language', 'city', 'completion_time', 'connecting_the_computer_to_wifi', 'connecting_the_tablet_to_wifi', 'course_id', 'course_name', 'course_type', 'creating_and_sending_emails', 'creation_date', 'date_of_birth', 'do_you_have_a_smartphone', 'do_you_have_a_website_for_your_business', 'do_you_have_an_existing_business', 'do_you_have_home_internet_access_ie_wifi', 'do_you_receive_housing_assistance', 'downloading_attachments_i_receive_in_an_email_documents_or_pictures', 'due_to_my_financial_situation_i_feel_that_i_will_never_have_the_things_i_want_in_life', 'educational_status', 'email_address', 'employment_status', 'even_if_i_am_not_able_to_achieve_my_financial_goals_right_away_i_will_find_a_way_to_get_there', 'fa_list_learner_enrollment_spanish_3823', 'file_list', 'first_name', 'form_name', 'have_you_ever_spent_time_in_a_jail_prison_or_juvenile_detention_centre', 'have_you_received_a_tgh_device_chromebook_or_ipad_in_the_last_two_years', 'home_street_address_including_apartment_number', 'household_income_level', 'how_do_you_describe_your_sexual_orientation_select_all_that_apply', 'how_many_tablets_do_you_have_at_home_eg_ipad_kindle_fire_samsung_galaxy_tab', 'how_many_working_computers_do_you_have_at_home', 'how_would_you_describe_your_childs_raceethnicity', 'how_would_you_describe_your_childs_raceethnicity_select_all_that_apply', 'how_would_you_describe_your_raceethnicity', 'how_would_you_describe_your_raceethnicity_select_all_that_apply', 'i_agree_to_the_learner_agreement_as_listed_above', 'i_am_able_to_utilize_my_resources_to_move_toward_career_goals', 'i_am_able_to_utilize_my_skills_to_move_toward_career_goals', 'i_am_aware_of_what_my_resources_are_to_be_employed_in_a_good_job_eg_resources_for_job_searching_child_care_resources_etc', 'i_am_aware_of_what_my_skills_are_to_achieve_a_good_employment_eg_digital_knowledge_jobspecific_skills_etc', 'i_am_concerned_that_the_money_i_have_or_will_save_wonaot_last', 'i_am_just_getting_by_financially', 'if_you_selected_other_please_explain', 'if_you_selected_other_what_language', 'installing_applications_apps', 'installing_applications_from_the_chromebook_store', 'ip_address', 'is_this_the_first_activity_youve_participated_in_at_your_program_site', 'is_your_internet_affordable', 'is_your_internet_reliable', 'last_name', 'modified_date', 'name_of_business', 'name_of_siteschool', 'number_of_people_in_household', 'opening_and_replying_to_emails', 'other', 'phone_number', 'please_describe_your_confidence_level_using_the_internet_to_find_information_you_need', 'please_enter_anyall_of_your_social_media_handles_separated_by_a_comma', 'primary_language', 'referrer', 'response', 'response_html', 'response_html_beta', 'response_id', ...
# ----------------------------------------
# (OLD) TGH Learner Enrollment Form (6.2.2022).csv: ['adding_an_attachment_to_an_email_i_am_sending_like_documents_or_pictures', 'adjusting_the_computers_settings_like_the_size_of_the_text_or_the_background_picture', 'adjusting_the_tablets_settings_like_the_size_of_the_text_or_the_background_picture', 'are_you_aware_of_the_affordable_connectivity_program_acp_an_fcc_federal_communications_commission_program_to_help_families_and_households_afford_internet_service_more_info_here_httpswwwfccgovacp', 'are_you_currently_enrolled_in_the_acp_program', 'childs_date_of_birth', 'childs_first_name', 'childs_gender', 'childs_last_name', 'childs_primary_language', 'childs_raceethnicity', 'city', 'completion_time', 'connecting_the_computer_to_wifi', 'connecting_the_tablet_to_wifi', 'course_id', 'course_name', 'course_type', 'creating_and_sending_emails', 'creation_date', 'date_of_birth', 'do_you_have_a_smartphone_eg_iphone_google_pixel_samsung_galaxy', 'do_you_have_a_website_for_your_business', 'do_you_have_an_existing_business', 'do_you_have_home_internet_access_ie_wifi', 'do_you_receive_housing_assistance', 'downloading_attachments_i_receive_in_an_email_documents_or_pictures', 'educational_status', 'email_address', 'employment_status', 'file_list', 'first_name', 'form_name', 'have_you_received_a_tgh_device_chromebook_or_ipad_in_the_last_two_years', 'home_street_address_including_apartment_number', 'household_income_level', 'how_many_tablets_do_you_have_at_home_eg_ipad_kindle_fire_samsung_galaxy_tab', 'how_many_working_computers_do_you_have_at_home', 'i_agree_to_the_learner_agreement_as_listed_above', 'i_hereby_give_the_unqualified_right_to_the_tgh_program_to_take_pictures_and_or_video_of_me_while_participating_in_my_course_i_give_permission_for_these_images_as_well_as_materials_that_we_have_created_in_the_tgh_program_to_be_used_in_print_and_webbased_publications_the_tgh_program_will_put_these_images_to_legitimate_use_without_limitation_or_reservation_if_you_do_not_wish_for_your_photo_to_be_used_by_tgh_please_let_your_tgh_instructors_know_so_they_will_not_send_us_pictures_of_you', 'if_you_selected_other_please_explain', 'if_you_selected_other_what_language', 'installing_applications_apps', 'installing_applications_from_the_chromebook_store', 'ip_address', 'is_this_the_first_activity_youve_participated_in_at_your_program_site', 'last_name', 'modified_date', 'name_of_business', 'name_of_siteschool', 'number_of_people_in_household', 'opening_and_replying_to_emails', 'other_primary_language', 'phone_number', 'please_describe_your_confidence_level_using_the_internet_to_find_information_you_need', 'please_enter_anyall_of_your_social_media_handles_separated_by_a_comma_eg_techgoeshome_facebookcomyourbusinessname', 'primary_language', 'raceethnicity', 'referrer', 'response', 'response_html', 'response_html_beta', 'response_id', 'response_text', 'response_url', 'resume_email', 'saving_files_to_the_computer_and_finding_them_later', 'saving_files_to_the_tablet_and_finding_them_later', 'state', 'submitted_date', 'to_which_gender_identity_do_you_most_identify', 'turning_the_computer_on_and_off', 'turning_the_tablet_on_and_off', 'unprotected_file_list', 'using_a_mouse_headset_andor_other_accessories', 'what_industry_is_your_business_in', 'what_is_your_goal_for_taking_this_course', 'what_is_your_website_address_url', 'which_if_any_social_media_tools_do_you_use_for_your_business', 'your_childs_gender_identity', 'your_childs_raceethnicity', 'your_gender_identity', 'your_raceethnicity', 'zip_code']
# ----------------------------------------
# (OLD)+TGH+Learner+Enrollment+Form+2025-03-06-11-24-39+457499.csv.csv: ['annual_revenue_of_business', 'childs_date_of_birth', 'childs_first_name', 'childs_gender', 'childs_grade', 'childs_last_name', 'childs_primary_language', 'childs_raceethnicity', 'city', 'completion_time', 'course_id', 'course_name', 'course_type', 'creation_date', 'date_of_birth', 'do_you_accept_creditdebit_cards', 'do_you_have_a_website_for_your_business', 'do_you_have_an_existing_business', 'do_you_have_home_internet_access_ie_wifi', 'do_you_have_school_age_children_in_your_household', 'do_you_know_of_organizations_that_help_small_business_owners_navigate_licensing_and_permitting_taxes_law_marketing_access_to_funding_and_other_business_issues', 'do_you_receive_housing_assistance', 'educational_status', 'email_address', 'employment_status', 'file_list', 'financial_other', 'first_name', 'form_name', 'have_you_ever_had_to_change_or_cancel_your_internet_subscription_because_it_is_too_expensive', 'have_you_received_a_tgh_device_chromebook_or_ipad_in_the_last_two_years', 'home_street_address_including_apartment_number', 'household_income_level', 'how_do_you_or_anyone_living_in_your_household_access_the_internet_in_your_home', 'how_often_are_your_business_social_media_pages_updated', 'how_old_is_your_business', 'how_satisfied_are_you_with_your_internet_service_at_home', 'i_agree_to_the_learner_agreement_as_listed_above', 'i_hereby_give_the_unqualified_right_to_the_tgh_program_to_take_pictures_and_or_video_of_me_while_participating_in_my_course_i_give_permission_for_these_images_as_well_as_materials_that_we_have_created_in_the_tgh_program_to_be_used_in_print_and_webbased_publications_the_tgh_program_will_put_these_images_to_legitimate_use_without_limitation_or_reservation_if_you_do_not_wish_for_your_photo_to_be_used_by_tgh_please_let_your_tgh_trainers_know_so_they_will_not_send_us_pictures_of_you', 'if_you_selected_other_please_explain', 'if_you_selected_other_please_specify', 'if_you_selected_other_what_language', 'if_you_selected_other_what_raceethnicity', 'if_you_selected_other_what_type', 'if_you_selected_other_what_type_of_device', 'ip_address', 'is_this_your_first_activityprogram_at_the_school_or_site_where_you_are_taking_tgh', 'is_your_internet_access_through_a_discounted_program_eg_internet_essentials_pcs_for_people', 'last_name', 'middle_initial', 'modified_date', 'name_of_business', 'name_of_siteschool', 'number_of_employees', 'number_of_members_in_household', 'number_of_working_computers_at_home', 'occupation', 'other_business_industry', 'other_internet_cause', 'other_internet_use_for_business', 'other_language', 'other_raceethnicity', 'phone_number', 'place_of_work', 'primary_language', 'raceethnicity', 'referrer', 'response', 'response_html', 'response_html_beta', 'response_id', 'response_text', 'response_url', 'resume_email', 'state', 'submitted_date', 'to_which_gender_identity_do_you_most_identify', 'unprotected_file_list', 'what_are_the_biggest_challenges_you_are_currently_facing_in_running_your_business_if_you_have_not_yet_started_your_business_what_are_the_biggest_obstacles', 'what_best_describes_the_organization_you_are_starting_or_running', 'what_do_you_and_other_household_members_use_the_internet_for', 'what_does_your_business_use_the_internet_for', 'what_financial_resources_do_you_use', 'what_industry_is_your_business_in', 'what_is_the_main_reason_you_decided_to_participate_in_tgh', 'which_devices_do_you_or_anyone_living_in_your_household_use_to_access_the_internet_in_your_home', 'which_devices_do_you_use_at_home', 'which_if_any_social_media_tools_do_you_use_for_your_business', 'why_dont_you_have_internet_access_at_home', 'zip']
# ----------------------------------------
# Cleaned_ES_translated_chinese.csv: ['adding_an_attachment_to_an_email_i_am_sending_like_documents_or_pictures', 'adjusting_the_tablets_settings_like_the_size_of_the_text_or_the_background_picture', 'are_you_aware_of_the_affordable_connectivity_program_acp_an_fcc_federal_communications_commission_program_to_help_families_and_households_afford_internet_service_more_info_here_httpswww_fcc_govacp', 'are_you_currently_enrolled_in_the_acp_program', 'are_you_self_employed', 'childs_date_of_birth', 'childs_first_name', 'childs_last_name', 'childs_primary_language', 'city', 'completion_time', 'connecting_the_tablet_to_wifi', 'course_id', 'course_name', 'course_type', 'creating_and_sending_emails', 'creation_date', 'date_of_birth', 'do_you_have_a_smartphone_e_g_iphone_google_pixel_samsung_galaxy', 'do_you_have_a_website_for_your_business', 'do_you_have_an_existing_business', 'do_you_have_home_internet_access_i_e_wifi', 'do_you_receive_housing_assistance', 'downloading_attachments_i_receive_in_an_email_documents_or_pictures', 'educational_status', 'email_address', 'employment_status', 'fa_list_learner_enrollment_english_1', 'file_list', 'first_name', 'form_name', 'have_you_received_a_tgh_device_chromebook_or_ipad_in_the_last_two_years', 'home_street_address_including_apartment_number', 'household_income_level', 'how_many_tablets_do_you_have_at_home_e_g_ipad_kindle_fire_samsung_galaxy_tab', 'how_many_working_computers_do_you_have_at_home', 'how_would_you_describe_your_childs_raceethnicity', 'how_would_you_describe_your_raceethnicity_select_all_that_apply', 'i_agree_to_the_learner_agreement_as_listed_above', 'if_you_selected_other_please_explain', 'if_you_selected_other_what_language', 'installing_applications_from_the_chromebook_store', 'ip_address', 'is_this_the_first_activity_youve_participated_in_at_your_program_site', 'is_your_internet_affordable', 'is_your_internet_reliable', 'last_name', 'modified_date', 'name_of_business', 'name_of_siteschool', 'number_of_people_in_household', 'opening_and_replying_to_emails', 'phone_number', 'please_describe_your_confidence_level_using_the_internet_to_find_information_you_need', 'please_enter_any_all_of_your_social_media_handles_separated_by_a_comma_e_g_techgoeshome_facebook_com_yourbusinessname', 'primary_language', 'referrer', 'response', 'response_html', 'response_text', 'resume_email', 'saving_files_to_the_tablet_and_finding_them_later', 'state', 'submitted_date', 'tech_goes_home_tech_goes_home_tech_goes_home_tech_goes_home_tgh', 'turning_the_tablet_on_and_off', 'unnamed_33', 'unprotected_file_list', 'using_a_mouse_headset_andor_other_accessories', 'what_are_your_childs_pronouns', 'what_are_your_pronouns', 'what_industry_is_your_business_in', 'what_is_your_childs_gender', 'what_is_your_gender', 'what_is_your_goal_for_taking_this_course', 'what_is_your_website_address_url', 'which_if_any_social_media_tools_do_you_use_for_your_business', 'your_childs_gender_identity', 'your_gender_identity', 'zip_code']
# ----------------------------------------
# translated_haitian_creole.xlsm: ['adding_an_attachment_to_an_email_i_am_sending_like_documents_or_pictures', 'adjusting_the_computers_settings_like_the_size_of_the_text_or_the_background_picture', 'adjusting_the_tablets_settings_like_the_size_of_the_text_or_the_background_picture', 'are_you_aware_of_the_affordable_connectivity_program_acp_an_fcc_federal_communications_commission_program_to_help_families_and_households_afford_internet_service_more_info_here_httpswwwfccgovacp', 'are_you_currently_enrolled_in_the_acp_program', 'are_you_selfemployed', 'because_of_my_money_situation_i_feel_like_i_yesll_never_have_the_things_i_want_in_life', 'childs_date_of_birth', 'childs_first_name', 'childs_last_name', 'childs_other_language', 'childs_primary_language', 'city', 'completion_time', 'connecting_the_computer_to_yesfi', 'connecting_the_tablet_to_yesfi', 'course_id', 'course_name', 'course_type', 'creating_and_sending_emails', 'creation_date', 'date_of_birth', 'do_you_have_a_smartphone_eg_iphone_google_pixel_samsung_galaxy', 'do_you_have_a_website_for_your_business', 'do_you_have_an_existing_business', 'do_you_have_home_internet_access_ie_yesfi', 'do_you_receive_housing_assistance', 'downloading_attachments_i_receive_in_an_email_documents_or_pictures', 'educational_status', 'email_address', 'employment_status', 'even_if_i_am_not_able_to_achieve_my_financial_goals_right_away_i_yesll_find_a_way_to_get_there', 'fa_list_learner_enrollment_haitian_creole_3823', 'file_list', 'first_name', 'form_name', 'have_you_ever_spent_time_in_a_jail_prison_or_juvenile_detention_centre', 'have_you_received_a_tgh_device_chromebook_or_ipad_in_the_last_two_years', 'home_street_address_including_apartment_number', 'household_income_level', 'how_do_you_describe_your_sexual_orientation_select_all_that_apply', 'how_many_tablets_do_you_have_at_home_eg_ipad_kindle_fire_samsung_galaxy_tab', 'how_many_working_computers_do_you_have_at_home', 'how_would_you_describe_your_childs_raceethnicity', 'how_would_you_describe_your_childs_raceethnicity_select_all_that_apply', 'how_would_you_describe_your_raceethnicity', 'how_would_you_describe_your_raceethnicity_select_all_that_apply', 'i_agree_to_the_learner_agreement_as_listed_above', 'i_am_able_to_utilize_my_resources_to_move_toward_career_goals', 'i_am_able_to_utilize_my_skills_to_move_toward_career_goals', 'i_am_aware_of_what_my_resources_are_to_be_employed_in_a_good_job_eg_resources_for_job_searching_child_care_resources_etc', 'i_am_aware_of_what_my_skills_are_to_be_employed_in_a_good_job_eg_digital_skills_specific_trade_skills_etc', 'i_am_concerned_that_the_money_i_have_or_yesll_save_wonaot_last', 'i_am_just_getting_by_financially', 'if_you_selected_other_please_explain', 'if_you_selected_other_what_language', 'installing_applications_apps', 'installing_applications_from_the_chromebook_store', 'ip_address', 'is_this_the_first_activity_youve_participated_in_at_your_program_site', 'is_your_internet_affordable', 'is_your_internet_reliable', 'last_name', 'modified_date', 'name_of_business', 'name_of_siteschool', 'number_of_people_in_household', 'opening_and_replying_to_emails', 'other_neighboorhood', 'phone_number', 'please_describe_your_confidence_level_using_the_internet_to_find_information_you_need', 'please_enter_anyall_of_your_social_media_handles_separated_by_a_comma_eg_techgoeshome_facebookcomyourbusinessname', 'primary_language', 'referrer', 'response', 'response_html', 'response_html_beta', 'response_id', 'response_text', 'response_url', 'resume_email', 'saving_files_to_the_computer_and_finding_them_later', 'saving_files_to_the_tablet_and_finding_them_later', 'state', 'submitted_date', 'turning_the_computer_on_and_off', 'turning_the_tablet_on_and_off', 'unprotected_file_list', 'using_a_mouse_headset_andor_other_accessories', 'were_you_born_in_the_united_states', 'what_are_your_childs_pronouns', 'what_are_your_pronouns', 'what_industry_is_your_business_in', 'what_is_the_zip_code_where_you_work', 'what_is_your_childs_ ...
# ----------------------------------------
#
# === Summary ===
# Matching columns (present in all files):
# ['childs_date_of_birth', 'childs_first_name', 'childs_last_name', 'childs_primary_language', 'city', 'completion_time', 'course_id', 'course_name', 'course_type', 'creation_date', 'date_of_birth', 'do_you_have_a_website_for_your_business', 'do_you_have_an_existing_business', 'do_you_receive_housing_assistance', 'educational_status', 'email_address', 'employment_status', 'file_list', 'first_name', 'form_name', 'have_you_received_a_tgh_device_chromebook_or_ipad_in_the_last_two_years', 'home_street_address_including_apartment_number', 'household_income_level', 'i_agree_to_the_learner_agreement_as_listed_above', 'if_you_selected_other_please_explain', 'ip_address', 'last_name', 'modified_date', 'name_of_business', 'name_of_siteschool', 'phone_number', 'primary_language', 'referrer', 'response', 'response_html', 'response_text', 'resume_email', 'state', 'submitted_date', 'unprotected_file_list', 'what_industry_is_your_business_in', 'which_if_any_social_media_tools_do_you_use_for_your_business']
# Count of matching columns: 42
#
# Non-matching columns (not present in all files):
# ['8_how_would_you_describe_your_raceethnicity', 'acepto_que_usen_citas_tomen_fotos_y_graben_pelculas_o_videos_mos_o_de_mis_hijos_en_el_programa_de_tech_goes_home_concedo_a_tech_goes_home_el_derecho_de_editar_usar_y_reutilizar_los_productos_mencionados_sin_nimo_de_lucro_incluido_el_uso_impreso_en_internet_y_en_cualquier_formato_multimedia_acepto_estos_trminos_de_forma_voluntaria_y_entiendo_que_no_recibir_ninguna_compensacin_financiera_por_el_presente_documento_libero_a_tech_goes_home_y_sus_agentes_y_empleados_de_cualquier_reclamacin_demanda_y_responsabilidad_en_el_marco_de_lo_anterior_si_no_desea_que_tech_goes_home_use_su_foto_indquelo_a_sus_instructores_de_tgh_para_que_no_nos_enven_fotografas_suyas', 'adding_an_attachment_to_an_email_i_am_sending_like_documents_or_pictures', 'adjusting_the_computers_settings_like_the_size_of_the_text_or_the_background_picture', 'adjusting_the_tablets_settings_like_the_size_of_the_text_or_the_background_picture', 'annual_revenue_of_business', 'are_you_a_veteran', 'are_you_aware_of_the_affordable_connectivity_program_acp_an_fcc_federal_communications_commission_program_to_help_families_and_households_afford_internet_service_more_info_here_httpswww_fcc_govacp', 'are_you_aware_of_the_affordable_connectivity_program_acp_an_fcc_federal_communications_commission_program_to_help_families_and_households_afford_internet_service_more_info_here_httpswwwfccgovacp', 'are_you_currently_enrolled_in_the_acp_program', 'are_you_self_employed', 'are_you_selfemployed', 'because_of_my_money_situation_i_feel_like_i_will_never_have_thethings_i_want_in_life', 'because_of_my_money_situation_i_feel_like_i_yesll_never_have_the_things_i_want_in_life', 'childs_gender', 'childs_grade', 'childs_other_language', 'childs_raceethnicity', 'connecting_the_computer_to_wifi', 'connecting_the_computer_to_yesfi', 'connecting_the_tablet_to_wifi', 'connecting_the_tablet_to_yesfi', 'creating_and_sending_emails', 'do_you_accept_creditdebit_cards', 'do_you_have_a_smartphone', 'do_you_have_a_smartphone_e_g_iphone_google_pixel_samsung_galaxy', 'do_you_have_a_smartphone_eg_iphone_google_pixel_samsung_galaxy', 'do_you_have_home_internet_access_i_e_wifi', 'do_you_have_home_internet_access_ie_wifi', 'do_you_have_home_internet_access_ie_yesfi', 'do_you_have_school_age_children_in_your_household', 'do_you_know_of_organizations_that_help_small_business_owners_navigate_licensing_and_permitting_taxes_law_marketing_access_to_funding_and_other_business_issues', 'downloading_attachments_i_receive_in_an_email_documents_or_pictures', 'due_to_my_financial_situation_i_feel_that_i_will_never_have_the_things_i_want_in_life', 'even_if_i_am_not_able_to_achieve_my_financial_goals_right_away_i_will_find_a_way_to_get_there', 'even_if_i_am_not_able_to_achieve_my_financial_goals_right_away_i_yesll_find_a_way_to_get_there', 'fa_list_learner_enrollment_english_1', 'fa_list_learner_enrollment_english_1123', 'fa_list_learner_enrollment_haitian_creole_3823', 'fa_list_learner_enrollment_spanish_3823', 'financial_other', 'have_you_ever_had_to_change_or_cancel_your_internet_subscription_because_it_is_too_expensive', 'have_you_ever_spent_time_in_a_jail_prison_or_juvenile_detention_center', 'have_you_ever_spent_time_in_a_jail_prison_or_juvenile_detention_centre', 'how_do_you_describe_your_sexual_orientation', 'how_do_you_describe_your_sexual_orientation_select_all_that_apply', 'how_do_you_or_anyone_living_in_your_household_access_the_internet_in_your_home', 'how_many_tablets_do_you_have_at_home_e_g_ipad_kindle_fire_samsung_galaxy_tab', 'how_many_tablets_do_you_have_at_home_eg_ipad_kindle_fire_samsung_galaxy_tab', 'how_many_working_computers_do_you_have_at_home', 'how_often_are_your_business_social_media_pages_updated', 'how_old_is_your_business', 'how_satisfied_are_you_with_your_internet_service_at_home', 'how_would_you_describe_your_childs_raceethnicity', 'how_would_you_describe_your_childs_raceethnicity_select_all_that_apply', 'how_would_you_describe_your_raceethnicity', ' ...
# Count of non-matching columns: 143

# %%
#advanced column names cleaning

import os
import pandas as pd
import re
import unicodedata

# Directory containing your CSV and XLSM files
files_path = "/Users/sreeharsha/Documents/TGH Data Management Cleaning/Merge testing/Enrollment Survey"  # Update this path accordingly

# Collect all CSV and XLSM files in the directory
all_files = [os.path.join(files_path, f) for f in os.listdir(files_path)
             if f.endswith('.csv') or f.endswith('.xlsm')]

# Optional mapping dictionary to standardize known variants
# For example, if "childs_first_name" should be "child_first_name"
mapping_dict = {
    "childs_first_name": "child_first_name",
    "childs_last_name": "child_last_name",
    "childs_date_of_birth": "child_date_of_birth",
    # add other mappings as needed
}

def advanced_normalize_column_name(col, mapping=None):
    """
    Normalize a column name by:
      - Stripping leading/trailing whitespace and converting to lowercase
      - Normalizing accented characters
      - Removing content within parentheses
      - Removing punctuation
      - Replacing one or more whitespace with an underscore
      - Removing numeric prefixes (e.g., "8_")
      - Applying a manual mapping for known variants if provided
    """
    # Step 1: Basic cleaning
    col = col.strip().lower()
    col = unicodedata.normalize('NFKD', col).encode('ASCII', 'ignore').decode('utf-8')
    # Remove text within parentheses
    col = re.sub(r'\(.*?\)', '', col)
    # Remove punctuation (keep alphanumerics and whitespace)
    col = re.sub(r'[^\w\s]', '', col)
    # Replace any whitespace with an underscore
    col = re.sub(r'\s+', '_', col)
    # Remove numeric prefixes followed by an underscore
    col = re.sub(r'^\d+_', '', col)
    
    # Step 2: Apply manual mapping if provided
    if mapping and col in mapping:
        col = mapping[col]
    
    return col

# Dictionary to store each file's normalized columns as a set
file_columns = {}

for file in all_files:
    # Read file based on its extension
    if file.endswith('.csv'):
        df = pd.read_csv(file)
    else:  # For .xlsm files (reads first sheet by default)
        df = pd.read_excel(file)
    
    # Normalize all column names in the DataFrame
    normalized_cols = [advanced_normalize_column_name(col, mapping=mapping_dict)
                       for col in df.columns.tolist()]
    
    file_columns[os.path.basename(file)] = set(normalized_cols)

# Compute the union and intersection of all normalized columns
all_union = set()
all_intersection = None

for cols in file_columns.values():
    all_union |= cols  # accumulate union
    if all_intersection is None:
        all_intersection = cols.copy()
    else:
        all_intersection &= cols  # intersect columns across files

matching_count = len(all_intersection)
non_matching_columns = all_union - all_intersection
non_matching_count = len(non_matching_columns)

# Print normalized columns per file
print("=== Normalized Columns per File ===")
for file, cols in file_columns.items():
    print(f"{file}:")
    print(sorted(cols))
    print("-" * 40)

# Print summary of matching vs. non-matching columns
print("\n=== Summary ===")
print("Matching columns (present in all files):")
print(sorted(all_intersection))
print("Count of matching columns:", matching_count)
print("\nNon-matching columns (not present in all files):")
print(sorted(non_matching_columns))
print("Count of non-matching columns:", non_matching_count)
# Out:
# /var/folders/q6/v__5dqvn4fsgnld9cp_x0v1m0000gn/T/ipykernel_23866/4024818860.py:59: DtypeWarning: Columns (16,27,30,31,32,33,34,35,48,75,76,77,81,99) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file)
# /var/folders/q6/v__5dqvn4fsgnld9cp_x0v1m0000gn/T/ipykernel_23866/4024818860.py:59: DtypeWarning: Columns (14,17,18,31,34,36,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file)
# === Normalized Columns per File ===
# Learner+Enrollment+ENGLISH.csv:
# ['adding_an_attachment_to_an_email_i_am_sending_', 'adjusting_the_computers_settings_', 'adjusting_the_tablets_settings_', 'are_you_a_veteran', 'are_you_aware_of_the_affordable_connectivity_program_an_fcc_program_to_help_families_and_households_afford_internet_service_', 'are_you_currently_enrolled_in_the_acp_program', 'are_you_selfemployed', 'because_of_my_money_situation_i_feel_like_i_will_never_have_thethings_i_want_in_life', 'child_date_of_birth', 'child_first_name', 'child_last_name', 'childs_primary_language', 'city', 'completion_time', 'connecting_the_computer_to_wifi', 'connecting_the_tablet_to_wifi', 'course_id', 'course_name', 'course_type', 'creating_and_sending_emails', 'creation_date', 'date_of_birth', 'do_you_have_a_smartphone_', 'do_you_have_a_website_for_your_business', 'do_you_have_an_existing_business', 'do_you_have_home_internet_access_', 'do_you_receive_housing_assistance', 'downloading_attachments_i_receive_in_an_email_', 'educational_status', 'email_address', 'employment_status', 'even_if_i_am_not_able_to_achieve_my_financial_goals_right_away_i_will_find_a_way_to_get_there', 'fa_list_learner_enrollment_english_', 'file_list', 'first_name', 'form_name', 'have_you_ever_spent_time_in_a_jail_prison_or_juvenile_detention_center', 'have_you_received_a_tgh_device_in_the_last_two_years', 'home_street_address_', 'household_income_level', 'how_do_you_describe_your_sexual_orientation', 'how_many_tablets_do_you_have_at_home_', 'how_many_working_computers_do_you_have_at_home', 'how_would_you_describe_your_childs_raceethnicity_', 'how_would_you_describe_your_raceethnicity', 'how_would_you_describe_your_raceethnicity_', 'i_agree_to_the_learner_agreement_as_listed_above', 'i_am_able_to_utilize_my_resources_to_move_toward_career_goals', 'i_am_able_to_utilize_my_skills_to_move_toward_career_goals', 'i_am_aware_of_what_my_resources_are_to_be_employed_in_a_good_job_', 'i_am_aware_of_what_my_skills_are_to_be_employed_in_a_goodjob_', 'i_am_concerned_that_the_money_i_have_or_will_save_wont_last', 'i_am_just_getting_by_financially', 'i_consent_to_the_use_of_quotes_and_the_taking_of_photos_movies_or_videos_of_my_child_and_me_in_the_tech_goes_home_program_i_grant_tech_goes_home_the_right_to_edit_use_and_reuse_said_products_for_nonprofit_purposes_including_use_in_print_on_the_internet_and_all_other_forms_of_media_i_understand_that_my_agreement_to_these_terms_is_voluntary_and_i_will_receive_no_financial_compensation_i_also_hereby_release_tech_goes_home_and_its_agents_and_employees_from_all_claims_demands_and_liabilities_whatsoever_in_connection_with_the_above_if_you_do_not_wish_for_your_photo_to_be_used_by_tech_goes_home_please_let_your_tgh_instructors_know_so_they_will_not_send_us_pictures_of_you', 'if_you_selected_other_please_explain', 'installing_applications_', 'installing_applications_from_the_chromebook_store', 'ip_address', 'is_this_the_first_activity_youve_participated_in_at_your_program_site', 'is_your_internet_affordable', 'is_your_internet_reliable', 'last_name', 'modified_date', 'name_of_business', 'name_of_siteschool', 'number_of_people_in_household', 'opening_and_replying_to_emails', 'other_child_language', 'other_language', 'other_neighborhoods', 'other_sexual_orientation', 'phone_number', 'please_describe_your_confidence_level_using_the_internet_to_find_information_you_need', 'please_enter_anyall_of_your_social_media_handles_separated_by_a_comma_', 'primary_language', 'referrer', 'response', 'response_html', 'response_html_beta', 'response_id', 'response_text', 'response_url', 'resume_email', 'saving_files_to_the_computer_and_finding_them_later', 'saving_files_to_the_tablet_and_finding_them_later', 'state', 'submitted_date', 'turning_the_computer_on_and_off', 'turning_the_tablet_on_and_off', 'unprotected_file_list', 'using_a_mouse_headset_andor_other_accessories', 'were_you_born_in_the_united_states', 'what_are_your_childs_pronouns', 'what_are_your_pronouns', 'what_industry_is_your_business_in', 'what_is_the_zip_cod ...
# ----------------------------------------
# translated_spanish.xlsm:
# ['acepto_que_usen_citas_tomen_fotos_y_graben_pelculas_o_videos_mos_o_de_mis_hijos_en_el_programa_de_tech_goes_home_concedo_a_tech_goes_home_el_derecho_de_editar_usar_y_reutilizar_los_productos_mencionados_sin_nimo_de_lucro_incluido_el_uso_impreso_en_internet_y_en_cualquier_formato_multimedia_acepto_estos_trminos_de_forma_voluntaria_y_entiendo_que_no_recibir_ninguna_compensacin_financiera_por_el_presente_documento_libero_a_tech_goes_home_y_sus_agentes_y_empleados_de_cualquier_reclamacin_demanda_y_responsabilidad_en_el_marco_de_lo_anterior_si_no_desea_que_tech_goes_home_use_su_foto_indquelo_a_sus_instructores_de_tgh_para_que_no_nos_enven_fotografas_suyas', 'adding_an_attachment_to_an_email_i_am_sending_', 'adjusting_the_computers_settings_', 'adjusting_the_tablets_settings_', 'are_you_aware_of_the_affordable_connectivity_program_an_fcc_program_to_help_families_and_households_afford_internet_service_', 'are_you_currently_enrolled_in_the_acp_program', 'are_you_selfemployed', 'child_date_of_birth', 'child_first_name', 'child_last_name', 'childs_primary_language', 'city', 'completion_time', 'connecting_the_computer_to_wifi', 'connecting_the_tablet_to_wifi', 'course_id', 'course_name', 'course_type', 'creating_and_sending_emails', 'creation_date', 'date_of_birth', 'do_you_have_a_smartphone', 'do_you_have_a_website_for_your_business', 'do_you_have_an_existing_business', 'do_you_have_home_internet_access_', 'do_you_receive_housing_assistance', 'downloading_attachments_i_receive_in_an_email_', 'due_to_my_financial_situation_i_feel_that_i_will_never_have_the_things_i_want_in_life', 'educational_status', 'email_address', 'employment_status', 'even_if_i_am_not_able_to_achieve_my_financial_goals_right_away_i_will_find_a_way_to_get_there', 'fa_list_learner_enrollment_spanish_', 'file_list', 'first_name', 'form_name', 'have_you_ever_spent_time_in_a_jail_prison_or_juvenile_detention_centre', 'have_you_received_a_tgh_device_in_the_last_two_years', 'home_street_address_', 'household_income_level', 'how_do_you_describe_your_sexual_orientation_select_all_that_apply', 'how_many_tablets_do_you_have_at_home_', 'how_many_working_computers_do_you_have_at_home', 'how_would_you_describe_your_childs_raceethnicity', 'how_would_you_describe_your_childs_raceethnicity_', 'how_would_you_describe_your_raceethnicity', 'how_would_you_describe_your_raceethnicity_', 'i_agree_to_the_learner_agreement_as_listed_above', 'i_am_able_to_utilize_my_resources_to_move_toward_career_goals', 'i_am_able_to_utilize_my_skills_to_move_toward_career_goals', 'i_am_aware_of_what_my_resources_are_to_be_employed_in_a_good_job_', 'i_am_aware_of_what_my_skills_are_to_achieve_a_good_employment_', 'i_am_concerned_that_the_money_i_have_or_will_save_wonaot_last', 'i_am_just_getting_by_financially', 'if_you_selected_other_please_explain', 'if_you_selected_other_what_language', 'installing_applications_', 'installing_applications_from_the_chromebook_store', 'ip_address', 'is_this_the_first_activity_youve_participated_in_at_your_program_site', 'is_your_internet_affordable', 'is_your_internet_reliable', 'last_name', 'modified_date', 'name_of_business', 'name_of_siteschool', 'number_of_people_in_household', 'opening_and_replying_to_emails', 'other', 'phone_number', 'please_describe_your_confidence_level_using_the_internet_to_find_information_you_need', 'please_enter_anyall_of_your_social_media_handles_separated_by_a_comma', 'primary_language', 'referrer', 'response', 'response_html', 'response_html_beta', 'response_id', 'response_text', 'response_url', 'resume_email', 'saving_files_to_the_computer_and_finding_them_later', 'saving_files_to_the_tablet_and_finding_them_later', 'state', 'submitted_date', 'turning_the_computer_on_and_off', 'turning_the_tablet_on_and_off', 'unprotected_file_list', 'using_a_mouse_headset_andor_other_accessories', 'were_you_born_in_the_united_states', 'what_are_your_childs_pronouns', 'what_are_your_pronouns', 'what_industry_is_your_business_in', 'what_is_the_zip_code_of ...
# ----------------------------------------
# (OLD) TGH Learner Enrollment Form (6.2.2022).csv:
# ['adding_an_attachment_to_an_email_i_am_sending_', 'adjusting_the_computers_settings_', 'adjusting_the_tablets_settings_', 'are_you_aware_of_the_affordable_connectivity_program_an_fcc_program_to_help_families_and_households_afford_internet_service_', 'are_you_currently_enrolled_in_the_acp_program', 'child_date_of_birth', 'child_first_name', 'child_last_name', 'childs_gender', 'childs_primary_language', 'childs_raceethnicity', 'city', 'completion_time', 'connecting_the_computer_to_wifi', 'connecting_the_tablet_to_wifi', 'course_id', 'course_name', 'course_type', 'creating_and_sending_emails', 'creation_date', 'date_of_birth', 'do_you_have_a_smartphone_', 'do_you_have_a_website_for_your_business', 'do_you_have_an_existing_business', 'do_you_have_home_internet_access_', 'do_you_receive_housing_assistance', 'downloading_attachments_i_receive_in_an_email_', 'educational_status', 'email_address', 'employment_status', 'file_list', 'first_name', 'form_name', 'have_you_received_a_tgh_device_in_the_last_two_years', 'home_street_address_', 'household_income_level', 'how_many_tablets_do_you_have_at_home_', 'how_many_working_computers_do_you_have_at_home', 'i_agree_to_the_learner_agreement_as_listed_above', 'i_hereby_give_the_unqualified_right_to_the_tgh_program_to_take_pictures_and_or_video_of_me_while_participating_in_my_course_i_give_permission_for_these_images_as_well_as_materials_that_we_have_created_in_the_tgh_program_to_be_used_in_print_and_webbased_publications_the_tgh_program_will_put_these_images_to_legitimate_use_without_limitation_or_reservation_if_you_do_not_wish_for_your_photo_to_be_used_by_tgh_please_let_your_tgh_instructors_know_so_they_will_not_send_us_pictures_of_you', 'if_you_selected_other_please_explain', 'if_you_selected_other_what_language', 'installing_applications_', 'installing_applications_from_the_chromebook_store', 'ip_address', 'is_this_the_first_activity_youve_participated_in_at_your_program_site', 'last_name', 'modified_date', 'name_of_business', 'name_of_siteschool', 'number_of_people_in_household', 'opening_and_replying_to_emails', 'other_primary_language', 'phone_number', 'please_describe_your_confidence_level_using_the_internet_to_find_information_you_need', 'please_enter_anyall_of_your_social_media_handles_separated_by_a_comma_', 'primary_language', 'raceethnicity', 'referrer', 'response', 'response_html', 'response_html_beta', 'response_id', 'response_text', 'response_url', 'resume_email', 'saving_files_to_the_computer_and_finding_them_later', 'saving_files_to_the_tablet_and_finding_them_later', 'state', 'submitted_date', 'to_which_gender_identity_do_you_most_identify', 'turning_the_computer_on_and_off', 'turning_the_tablet_on_and_off', 'unprotected_file_list', 'using_a_mouse_headset_andor_other_accessories', 'what_industry_is_your_business_in', 'what_is_your_goal_for_taking_this_course', 'what_is_your_website_address_', 'which_if_any_social_media_tools_do_you_use_for_your_business', 'your_childs_gender_identity', 'your_childs_raceethnicity', 'your_gender_identity', 'your_raceethnicity', 'zip_code']
# ----------------------------------------
# (OLD)+TGH+Learner+Enrollment+Form+2025-03-06-11-24-39+457499.csv.csv:
# ['annual_revenue_of_business', 'child_date_of_birth', 'child_first_name', 'child_last_name', 'childs_gender', 'childs_grade', 'childs_primary_language', 'childs_raceethnicity', 'city', 'completion_time', 'course_id', 'course_name', 'course_type', 'creation_date', 'date_of_birth', 'do_you_accept_creditdebit_cards', 'do_you_have_a_website_for_your_business', 'do_you_have_an_existing_business', 'do_you_have_home_internet_access_', 'do_you_have_school_age_children_in_your_household', 'do_you_know_of_organizations_that_help_small_business_owners_navigate_licensing_and_permitting_taxes_law_marketing_access_to_funding_and_other_business_issues', 'do_you_receive_housing_assistance', 'educational_status', 'email_address', 'employment_status', 'file_list', 'financial_other', 'first_name', 'form_name', 'have_you_ever_had_to_change_or_cancel_your_internet_subscription_because_it_is_too_expensive', 'have_you_received_a_tgh_device_in_the_last_two_years', 'home_street_address_', 'household_income_level', 'how_do_you_access_the_internet_in_your_home', 'how_often_are_your_business_social_media_pages_updated', 'how_old_is_your_business', 'how_satisfied_are_you_with_your_internet_service_at_home', 'i_agree_to_the_learner_agreement_as_listed_above', 'i_hereby_give_the_unqualified_right_to_the_tgh_program_to_take_pictures_and_or_video_of_me_while_participating_in_my_course_i_give_permission_for_these_images_as_well_as_materials_that_we_have_created_in_the_tgh_program_to_be_used_in_print_and_webbased_publications_the_tgh_program_will_put_these_images_to_legitimate_use_without_limitation_or_reservation_if_you_do_not_wish_for_your_photo_to_be_used_by_tgh_please_let_your_tgh_trainers_know_so_they_will_not_send_us_pictures_of_you', 'if_you_selected_other_please_explain', 'if_you_selected_other_please_specify', 'if_you_selected_other_what_language', 'if_you_selected_other_what_raceethnicity', 'if_you_selected_other_what_type', 'if_you_selected_other_what_type_of_device', 'ip_address', 'is_this_your_first_activityprogram_at_the_school_or_site_where_you_are_taking_tgh', 'is_your_internet_access_through_a_discounted_program_', 'last_name', 'middle_initial', 'modified_date', 'name_of_business', 'name_of_siteschool', 'number_of_employees', 'number_of_members_in_household', 'number_of_working_computers_at_home', 'occupation', 'other_business_industry', 'other_internet_cause', 'other_internet_use_for_business', 'other_language', 'other_raceethnicity', 'phone_number', 'place_of_work', 'primary_language', 'raceethnicity', 'referrer', 'response', 'response_html', 'response_html_beta', 'response_id', 'response_text', 'response_url', 'resume_email', 'state', 'submitted_date', 'to_which_gender_identity_do_you_most_identify', 'unprotected_file_list', 'what_are_the_biggest_challenges_you_are_currently_facing_in_running_your_business_if_you_have_not_yet_started_your_business_what_are_the_biggest_obstacles', 'what_best_describes_the_organization_you_are_starting_or_running', 'what_do_you_and_other_household_members_use_the_internet_for', 'what_does_your_business_use_the_internet_for', 'what_financial_resources_do_you_use', 'what_industry_is_your_business_in', 'what_is_the_main_reason_you_decided_to_participate_in_tgh', 'which_devices_do_you_use_at_home', 'which_devices_do_you_use_to_access_the_internet_in_your_home', 'which_if_any_social_media_tools_do_you_use_for_your_business', 'why_dont_you_have_internet_access_at_home', 'zip']
# ----------------------------------------
# Cleaned_ES_translated_chinese.csv:
# ['adding_an_attachment_to_an_email_i_am_sending_like_documents_or_pictures', 'adjusting_the_tablets_settings_like_the_size_of_the_text_or_the_background_picture', 'are_you_aware_of_the_affordable_connectivity_program_acp_an_fcc_federal_communications_commission_program_to_help_families_and_households_afford_internet_service_more_info_here_httpswww_fcc_govacp', 'are_you_currently_enrolled_in_the_acp_program', 'are_you_self_employed', 'child_date_of_birth', 'child_first_name', 'child_last_name', 'childs_primary_language', 'city', 'completion_time', 'connecting_the_tablet_to_wifi', 'course_id', 'course_name', 'course_type', 'creating_and_sending_emails', 'creation_date', 'date_of_birth', 'do_you_have_a_smartphone_e_g_iphone_google_pixel_samsung_galaxy', 'do_you_have_a_website_for_your_business', 'do_you_have_an_existing_business', 'do_you_have_home_internet_access_i_e_wifi', 'do_you_receive_housing_assistance', 'downloading_attachments_i_receive_in_an_email_documents_or_pictures', 'educational_status', 'email_address', 'employment_status', 'fa_list_learner_enrollment_english_1', 'file_list', 'first_name', 'form_name', 'have_you_received_a_tgh_device_chromebook_or_ipad_in_the_last_two_years', 'home_street_address_including_apartment_number', 'household_income_level', 'how_many_tablets_do_you_have_at_home_e_g_ipad_kindle_fire_samsung_galaxy_tab', 'how_many_working_computers_do_you_have_at_home', 'how_would_you_describe_your_childs_raceethnicity', 'how_would_you_describe_your_raceethnicity_select_all_that_apply', 'i_agree_to_the_learner_agreement_as_listed_above', 'if_you_selected_other_please_explain', 'if_you_selected_other_what_language', 'installing_applications_from_the_chromebook_store', 'ip_address', 'is_this_the_first_activity_youve_participated_in_at_your_program_site', 'is_your_internet_affordable', 'is_your_internet_reliable', 'last_name', 'modified_date', 'name_of_business', 'name_of_siteschool', 'number_of_people_in_household', 'opening_and_replying_to_emails', 'phone_number', 'please_describe_your_confidence_level_using_the_internet_to_find_information_you_need', 'please_enter_any_all_of_your_social_media_handles_separated_by_a_comma_e_g_techgoeshome_facebook_com_yourbusinessname', 'primary_language', 'referrer', 'response', 'response_html', 'response_text', 'resume_email', 'saving_files_to_the_tablet_and_finding_them_later', 'state', 'submitted_date', 'tech_goes_home_tech_goes_home_tech_goes_home_tech_goes_home_tgh', 'turning_the_tablet_on_and_off', 'unnamed_33', 'unprotected_file_list', 'using_a_mouse_headset_andor_other_accessories', 'what_are_your_childs_pronouns', 'what_are_your_pronouns', 'what_industry_is_your_business_in', 'what_is_your_childs_gender', 'what_is_your_gender', 'what_is_your_goal_for_taking_this_course', 'what_is_your_website_address_url', 'which_if_any_social_media_tools_do_you_use_for_your_business', 'your_childs_gender_identity', 'your_gender_identity', 'zip_code']
# ----------------------------------------
# translated_haitian_creole.xlsm:
# ['adding_an_attachment_to_an_email_i_am_sending_', 'adjusting_the_computers_settings_', 'adjusting_the_tablets_settings_', 'are_you_aware_of_the_affordable_connectivity_program_an_fcc_program_to_help_families_and_households_afford_internet_service_', 'are_you_currently_enrolled_in_the_acp_program', 'are_you_selfemployed', 'because_of_my_money_situation_i_feel_like_i_yesll_never_have_the_things_i_want_in_life', 'child_date_of_birth', 'child_first_name', 'child_last_name', 'childs_other_language', 'childs_primary_language', 'city', 'completion_time', 'connecting_the_computer_to_yesfi', 'connecting_the_tablet_to_yesfi', 'course_id', 'course_name', 'course_type', 'creating_and_sending_emails', 'creation_date', 'date_of_birth', 'do_you_have_a_smartphone_', 'do_you_have_a_website_for_your_business', 'do_you_have_an_existing_business', 'do_you_have_home_internet_access_', 'do_you_receive_housing_assistance', 'downloading_attachments_i_receive_in_an_email_', 'educational_status', 'email_address', 'employment_status', 'even_if_i_am_not_able_to_achieve_my_financial_goals_right_away_i_yesll_find_a_way_to_get_there', 'fa_list_learner_enrollment_haitian_creole_', 'file_list', 'first_name', 'form_name', 'have_you_ever_spent_time_in_a_jail_prison_or_juvenile_detention_centre', 'have_you_received_a_tgh_device_in_the_last_two_years', 'home_street_address_', 'household_income_level', 'how_do_you_describe_your_sexual_orientation_select_all_that_apply', 'how_many_tablets_do_you_have_at_home_', 'how_many_working_computers_do_you_have_at_home', 'how_would_you_describe_your_childs_raceethnicity', 'how_would_you_describe_your_childs_raceethnicity_', 'how_would_you_describe_your_raceethnicity', 'how_would_you_describe_your_raceethnicity_', 'i_agree_to_the_learner_agreement_as_listed_above', 'i_am_able_to_utilize_my_resources_to_move_toward_career_goals', 'i_am_able_to_utilize_my_skills_to_move_toward_career_goals', 'i_am_aware_of_what_my_resources_are_to_be_employed_in_a_good_job_', 'i_am_aware_of_what_my_skills_are_to_be_employed_in_a_good_job_', 'i_am_concerned_that_the_money_i_have_or_yesll_save_wonaot_last', 'i_am_just_getting_by_financially', 'if_you_selected_other_please_explain', 'if_you_selected_other_what_language', 'installing_applications_', 'installing_applications_from_the_chromebook_store', 'ip_address', 'is_this_the_first_activity_youve_participated_in_at_your_program_site', 'is_your_internet_affordable', 'is_your_internet_reliable', 'last_name', 'modified_date', 'name_of_business', 'name_of_siteschool', 'number_of_people_in_household', 'opening_and_replying_to_emails', 'other_neighboorhood', 'phone_number', 'please_describe_your_confidence_level_using_the_internet_to_find_information_you_need', 'please_enter_anyall_of_your_social_media_handles_separated_by_a_comma_', 'primary_language', 'referrer', 'response', 'response_html', 'response_html_beta', 'response_id', 'response_text', 'response_url', 'resume_email', 'saving_files_to_the_computer_and_finding_them_later', 'saving_files_to_the_tablet_and_finding_them_later', 'state', 'submitted_date', 'turning_the_computer_on_and_off', 'turning_the_tablet_on_and_off', 'unprotected_file_list', 'using_a_mouse_headset_andor_other_accessories', 'were_you_born_in_the_united_states', 'what_are_your_childs_pronouns', 'what_are_your_pronouns', 'what_industry_is_your_business_in', 'what_is_the_zip_code_where_you_work', 'what_is_your_childs_gender', 'what_is_your_gender', 'what_is_your_goal_for_taking_this_course', 'what_is_your_website_address_', 'what_other_boston_neighbourhoods_are_you_connected_to_for_example_do_you_receive_services_visit_family_or_friends_go_to_school_or_places_of_worship_in_any_of_the_folloyesng_neighbourhoods_select_all_that_apply', 'which_if_any_social_media_tools_do_you_use_for_your_business', 'your_childs_gender_identity', 'your_gender_identity', 'zip_code']
# ----------------------------------------
#
# === Summary ===
# Matching columns (present in all files):
# ['child_date_of_birth', 'child_first_name', 'child_last_name', 'childs_primary_language', 'city', 'completion_time', 'course_id', 'course_name', 'course_type', 'creation_date', 'date_of_birth', 'do_you_have_a_website_for_your_business', 'do_you_have_an_existing_business', 'do_you_receive_housing_assistance', 'educational_status', 'email_address', 'employment_status', 'file_list', 'first_name', 'form_name', 'household_income_level', 'i_agree_to_the_learner_agreement_as_listed_above', 'if_you_selected_other_please_explain', 'ip_address', 'last_name', 'modified_date', 'name_of_business', 'name_of_siteschool', 'phone_number', 'primary_language', 'referrer', 'response', 'response_html', 'response_text', 'resume_email', 'state', 'submitted_date', 'unprotected_file_list', 'what_industry_is_your_business_in', 'which_if_any_social_media_tools_do_you_use_for_your_business']
# Count of matching columns: 40
#
# Non-matching columns (not present in all files):
# ['acepto_que_usen_citas_tomen_fotos_y_graben_pelculas_o_videos_mos_o_de_mis_hijos_en_el_programa_de_tech_goes_home_concedo_a_tech_goes_home_el_derecho_de_editar_usar_y_reutilizar_los_productos_mencionados_sin_nimo_de_lucro_incluido_el_uso_impreso_en_internet_y_en_cualquier_formato_multimedia_acepto_estos_trminos_de_forma_voluntaria_y_entiendo_que_no_recibir_ninguna_compensacin_financiera_por_el_presente_documento_libero_a_tech_goes_home_y_sus_agentes_y_empleados_de_cualquier_reclamacin_demanda_y_responsabilidad_en_el_marco_de_lo_anterior_si_no_desea_que_tech_goes_home_use_su_foto_indquelo_a_sus_instructores_de_tgh_para_que_no_nos_enven_fotografas_suyas', 'adding_an_attachment_to_an_email_i_am_sending_', 'adding_an_attachment_to_an_email_i_am_sending_like_documents_or_pictures', 'adjusting_the_computers_settings_', 'adjusting_the_tablets_settings_', 'adjusting_the_tablets_settings_like_the_size_of_the_text_or_the_background_picture', 'annual_revenue_of_business', 'are_you_a_veteran', 'are_you_aware_of_the_affordable_connectivity_program_acp_an_fcc_federal_communications_commission_program_to_help_families_and_households_afford_internet_service_more_info_here_httpswww_fcc_govacp', 'are_you_aware_of_the_affordable_connectivity_program_an_fcc_program_to_help_families_and_households_afford_internet_service_', 'are_you_currently_enrolled_in_the_acp_program', 'are_you_self_employed', 'are_you_selfemployed', 'because_of_my_money_situation_i_feel_like_i_will_never_have_thethings_i_want_in_life', 'because_of_my_money_situation_i_feel_like_i_yesll_never_have_the_things_i_want_in_life', 'childs_gender', 'childs_grade', 'childs_other_language', 'childs_raceethnicity', 'connecting_the_computer_to_wifi', 'connecting_the_computer_to_yesfi', 'connecting_the_tablet_to_wifi', 'connecting_the_tablet_to_yesfi', 'creating_and_sending_emails', 'do_you_accept_creditdebit_cards', 'do_you_have_a_smartphone', 'do_you_have_a_smartphone_', 'do_you_have_a_smartphone_e_g_iphone_google_pixel_samsung_galaxy', 'do_you_have_home_internet_access_', 'do_you_have_home_internet_access_i_e_wifi', 'do_you_have_school_age_children_in_your_household', 'do_you_know_of_organizations_that_help_small_business_owners_navigate_licensing_and_permitting_taxes_law_marketing_access_to_funding_and_other_business_issues', 'downloading_attachments_i_receive_in_an_email_', 'downloading_attachments_i_receive_in_an_email_documents_or_pictures', 'due_to_my_financial_situation_i_feel_that_i_will_never_have_the_things_i_want_in_life', 'even_if_i_am_not_able_to_achieve_my_financial_goals_right_away_i_will_find_a_way_to_get_there', 'even_if_i_am_not_able_to_achieve_my_financial_goals_right_away_i_yesll_find_a_way_to_get_there', 'fa_list_learner_enrollment_english_', 'fa_list_learner_enrollment_english_1', 'fa_list_learner_enrollment_haitian_creole_', 'fa_list_learner_enrollment_spanish_', 'financial_other', 'have_you_ever_had_to_change_or_cancel_your_internet_subscription_because_it_is_too_expensive', 'have_you_ever_spent_time_in_a_jail_prison_or_juvenile_detention_center', 'have_you_ever_spent_time_in_a_jail_prison_or_juvenile_detention_centre', 'have_you_received_a_tgh_device_chromebook_or_ipad_in_the_last_two_years', 'have_you_received_a_tgh_device_in_the_last_two_years', 'home_street_address_', 'home_street_address_including_apartment_number', 'how_do_you_access_the_internet_in_your_home', 'how_do_you_describe_your_sexual_orientation', 'how_do_you_describe_your_sexual_orientation_select_all_that_apply', 'how_many_tablets_do_you_have_at_home_', 'how_many_tablets_do_you_have_at_home_e_g_ipad_kindle_fire_samsung_galaxy_tab', 'how_many_working_computers_do_you_have_at_home', 'how_often_are_your_business_social_media_pages_updated', 'how_old_is_your_business', 'how_satisfied_are_you_with_your_internet_service_at_home', 'how_would_you_describe_your_childs_raceethnicity', 'how_would_you_describe_your_childs_raceethnicity_', 'how_would_you_describe_your_raceethnicity', 'how_would_you_describe_ ...
# Count of non-matching columns: 150

# %%
import re
import unicodedata

def enhanced_normalize_column_name(col, mapping=None):
    """
    Normalize a column name by:
      - Stripping leading/trailing whitespace and converting to lowercase
      - Normalizing accented characters
      - Removing content within parentheses
      - Removing punctuation
      - Replacing one or more whitespace with an underscore
      - Removing numeric prefixes (e.g., "8_")
      - Removing redundant/trailing underscores
      - Applying a manual mapping for known variants if provided
    """
    # Basic cleaning: strip, lowercase, normalize accents
    col = col.strip().lower()
    col = unicodedata.normalize('NFKD', col).encode('ASCII', 'ignore').decode('utf-8')
    
    # Remove text within parentheses
    col = re.sub(r'\(.*?\)', '', col)
    
    # Remove punctuation (retain alphanumerics and whitespace)
    col = re.sub(r'[^\w\s]', '', col)
    
    # Replace any whitespace with an underscore
    col = re.sub(r'\s+', '_', col)
    
    # Remove numeric prefixes followed by an underscore
    col = re.sub(r'^\d+_', '', col)
    
    # Remove redundant or trailing underscores
    col = re.sub(r'_+', '_', col)  # collapse multiple underscores
    col = col.strip('_')
    
    # Apply manual mapping if provided
    if mapping and col in mapping:
        col = mapping[col]
    
    return col

# Example mapping dictionary for known variants
mapping_dict = {
    "are_you_selfemployed": "are_you_self_employed",
    "do_you_have_a_smartphone_": "do_you_have_a_smartphone",
    # Add more mappings as you identify them...
}

# Example usage with a list of test column names
test_columns = [
    "are_you_self_employed", 
    "are_you_selfemployed", 
    "do_you_have_a_smartphone_", 
    "adding_an_attachment_to_an_email_i_am_sending_",
    "adding_an_attachment_to_an_email_i_am_sending_like_documents_or_pictures"
]

normalized = [enhanced_normalize_column_name(col, mapping=mapping_dict) for col in test_columns]
print(normalized)
# Expected output:
# ['are_you_self_employed', 'are_you_self_employed', 'do_you_have_a_smartphone', 'adding_an_attachment_to_an_email_i_am_sending', 'adding_an_attachment_to_an_email_i_am_sending_like_documents_or_pictures']
# Out:
# ['are_you_self_employed', 'are_you_self_employed', 'do_you_have_a_smartphone', 'adding_an_attachment_to_an_email_i_am_sending', 'adding_an_attachment_to_an_email_i_am_sending_like_documents_or_pictures']

# %%
import os
import pandas as pd
import ipywidgets as widgets
from IPython.display import display

# -------------------------------
# Step 1: Gather Files and Columns
# -------------------------------

# Set the directory containing your CSV and XLSM files (update the path)
files_path = '/Users/sreeharsha/Documents/TGH Data Management Cleaning/Merge testing/Enrollment Survey'  # <-- UPDATE THIS PATH

# Gather all CSV and XLSM files
all_files = [os.path.join(files_path, f) for f in os.listdir(files_path) 
             if f.endswith('.csv') or f.endswith('.xlsm')]

# Extract all unique column names across files
unique_cols = set()
for file in all_files:
    try:
        if file.endswith('.csv'):
            df = pd.read_csv(file)
        else:
            df = pd.read_excel(file)
        unique_cols.update(df.columns.tolist())
    except Exception as e:
        print(f"Error reading {file}: {e}")

unique_cols = sorted(unique_cols)
print("Total unique columns found:", len(unique_cols))

# -------------------------------
# Step 2: Create Interactive Widgets for Mapping
# -------------------------------

# A simple initial cleaning function to pre-populate the text boxes
def initial_clean(col):
    # Lowercase, strip extra spaces, and replace spaces with underscores
    return col.strip().lower().replace(" ", "_")

# Create a dictionary to hold a Text widget for each unique column name
col_widgets = {}
for col in unique_cols:
    default_val = initial_clean(col)
    # The description shows the original column (truncated if needed)
    widget_desc = (col[:30] + '...') if len(col) > 30 else col
    text_widget = widgets.Text(
        value=default_val,
        description=widget_desc,
        layout=widgets.Layout(width='100%')
    )
    col_widgets[col] = text_widget

# Group all widgets in a VBox and put it inside a scrollable container (useful if there are many columns)
vbox = widgets.VBox(list(col_widgets.values()))
scrollable_vbox = widgets.Box([vbox], layout=widgets.Layout(overflow='scroll', border='1px solid gray', height='500px'))
display(scrollable_vbox)

# -------------------------------
# Step 3: Create a Submit Button to Finalize the Mapping
# -------------------------------

# Create a button and output area to show the final mapping dictionary
submit_button = widgets.Button(description="Submit Mapping", button_style='success')
output_area = widgets.Output()

# Global variable to store final mapping
final_mapping = {}

def on_submit(b):
    global final_mapping
    mapping_dict = {}
    for orig, widget in col_widgets.items():
        # Use the edited value as the standardized column name
        mapping_dict[orig] = widget.value.strip()
    final_mapping = mapping_dict
    with output_area:
        output_area.clear_output()
        print("Final Mapping Dictionary:")
        for k, v in mapping_dict.items():
            print(f"'{k}'  ->  '{v}'")

submit_button.on_click(on_submit)
display(submit_button, output_area)

# -------------------------------
# Step 4 (Optional): Apply the Mapping to Your Files
# -------------------------------
# Once you have finalized the mapping (stored in final_mapping), you can re-read your files,
# update the column names, and optionally save the updated DataFrames.
#
# Example: Renaming columns in each file and saving them to a new folder.

# Uncomment and update the following code if you want to save the files with standardized columns:
#
# output_dir = "path/to/save/standardized_files"  # Update this path
# os.makedirs(output_dir, exist_ok=True)
#
# for file in all_files:
#     try:
#         if file.endswith('.csv'):
#             df = pd.read_csv(file)
#         else:
#             df = pd.read_excel(file)
#         # Rename columns using the mapping dictionary (only update if the original column exists)
#         new_cols = {col: final_mapping.get(col, col) for col in df.columns}
#         df.rename(columns=new_cols, inplace=True)
#         # Save the updated DataFrame (preserving the file type)
#         base_name = os.path.basename(file)
#         out_path = os.path.join(output_dir, base_name)
#         if file.endswith('.csv'):
#             df.to_csv(out_path, index=False)
#         else:
#             df.to_excel(out_path, index=False)
#         print(f"Processed and saved: {out_path}")
#     except Exception as e:
#         print(f"Error processing {file}: {e}")
# Out:
# /var/folders/q6/v__5dqvn4fsgnld9cp_x0v1m0000gn/T/ipykernel_23866/3673116136.py:22: DtypeWarning: Columns (16,27,30,31,32,33,34,35,48,75,76,77,81,99) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file)
# /var/folders/q6/v__5dqvn4fsgnld9cp_x0v1m0000gn/T/ipykernel_23866/3673116136.py:22: DtypeWarning: Columns (14,17,18,31,34,36,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file)
# Total unique columns found: 271
# Box(children=(VBox(children=(Text(value="child's_date_of_birth", description=" Child's Date of Birth", layout=…
# Button(button_style='success', description='Submit Mapping', style=ButtonStyle())
# Output()

# %%
pip install ipywidgets
# Out:
# Requirement already satisfied: ipywidgets in /opt/anaconda3/lib/python3.12/site-packages (7.8.1)
# Requirement already satisfied: comm>=0.1.3 in /opt/anaconda3/lib/python3.12/site-packages (from ipywidgets) (0.2.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from ipywidgets) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=3.6.6 in /opt/anaconda3/lib/python3.12/site-packages (from ipywidgets) (3.6.6)
# Requirement already satisfied: ipython>=4.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from ipywidgets) (8.25.0)
# Requirement already satisfied: jupyterlab-widgets<3,>=1.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from ipywidgets) (1.0.0)
# Requirement already satisfied: decorator in /opt/anaconda3/lib/python3.12/site-packages (from ipython>=4.0.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/anaconda3/lib/python3.12/site-packages (from ipython>=4.0.0->ipywidgets) (0.18.1)
# Requirement already satisfied: matplotlib-inline in /opt/anaconda3/lib/python3.12/site-packages (from ipython>=4.0.0->ipywidgets) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /opt/anaconda3/lib/python3.12/site-packages (from ipython>=4.0.0->ipywidgets) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in /opt/anaconda3/lib/python3.12/site-packages (from ipython>=4.0.0->ipywidgets) (2.15.1)
# Requirement already satisfied: stack-data in /opt/anaconda3/lib/python3.12/site-packages (from ipython>=4.0.0->ipywidgets) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /opt/anaconda3/lib/python3.12/site-packages (from ipython>=4.0.0->ipywidgets) (4.8.0)
# Requirement already satisfied: notebook>=4.4.1 in /opt/anaconda3/lib/python3.12/site-packages (from widgetsnbextension~=3.6.6->ipywidgets) (7.0.8)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /opt/anaconda3/lib/python3.12/site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets) (0.8.3)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /opt/anaconda3/lib/python3.12/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.14.1)
# Requirement already satisfied: jupyterlab-server<3,>=2.22.1 in /opt/anaconda3/lib/python3.12/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.27.3)
# Requirement already satisfied: jupyterlab<4.1,>=4.0.2 in /opt/anaconda3/lib/python3.12/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (4.0.11)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in /opt/anaconda3/lib/python3.12/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.2.3)
# Requirement already satisfied: tornado>=6.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (6.4.1)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/anaconda3/lib/python3.12/site-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/anaconda3/lib/python3.12/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=4.0.0->ipywidgets) (0.2.5)
# Requirement already satisfied: executing in /opt/anaconda3/lib/python3.12/site-packages (from stack-data->ipython>=4.0.0->ipywidgets) (0.8.3)
# Requirement already satisfied: asttokens in /opt/anaconda3/lib/python3.12/site-packages (from stack-data->ipython>=4.0.0->ipywidgets) (2.0.5)
# Requirement already satisfied: pure-eval in /opt/anaconda3/lib/python3.12/site-packages (from stack-data->ipython>=4.0.0->ipywidgets) (0.2.2)
# Requirement already satisfied: anyio>=3.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (4.2.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (21.3.0)
# Requirement already satisfied: jinja2>=3.0.3 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (3.1.4)
# Requirement already satisfied: jupyter-client>=7.4.4 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (8.6.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (5.7.2)
# Requirement already satisfied: jupyter-events>=0.9.0 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.4.4)
# Requirement already satisfied: nbconvert>=6.4.4 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (7.10.0)
# Requirement already satisfied: nbformat>=5.3.0 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (5.9.2)
# Requirement already satisfied: overrides>=5.0 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (7.4.0)
# Requirement already satisfied: packaging>=22.0 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (23.2)
# Requirement already satisfied: prometheus-client>=0.9 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.14.1)
# Requirement already satisfied: pyzmq>=24 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (25.1.2)
# Requirement already satisfied: send2trash>=1.8.2 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.17.1)
# Requirement already satisfied: websocket-client>=1.7 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from jupyterlab<4.1,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.0.4)
# Requirement already satisfied: ipykernel in /opt/anaconda3/lib/python3.12/site-packages (from jupyterlab<4.1,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (6.28.0)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from jupyterlab<4.1,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.2.0)
# Requirement already satisfied: babel>=2.10 in /opt/anaconda3/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.11.0)
# Requirement already satisfied: json5>=0.9.0 in /opt/anaconda3/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.9.6)
# Requirement already satisfied: jsonschema>=4.18.0 in /opt/anaconda3/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (4.19.2)
# Requirement already satisfied: requests>=2.31 in /opt/anaconda3/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.32.2)
# Requirement already satisfied: six in /opt/anaconda3/lib/python3.12/site-packages (from asttokens->stack-data->ipython>=4.0.0->ipywidgets) (1.16.0)
# Requirement already satisfied: idna>=2.8 in /opt/anaconda3/lib/python3.12/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (3.7)
# Requirement already satisfied: sniffio>=1.1 in /opt/anaconda3/lib/python3.12/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (1.3.0)
# Requirement already satisfied: argon2-cffi-bindings in /opt/anaconda3/lib/python3.12/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (21.2.0)
# Requirement already satisfied: pytz>=2015.7 in /opt/anaconda3/lib/python3.12/site-packages (from babel>=2.10->jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2024.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/lib/python3.12/site-packages (from jinja2>=3.0.3->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.1.3)
# Requirement already satisfied: attrs>=22.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.10.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-client>=7.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (3.10.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (6.0.1)
# Requirement already satisfied: rfc3339-validator in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.1.1)
# Requirement already satisfied: beautifulsoup4 in /opt/anaconda3/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (4.1.0)
# Requirement already satisfied: defusedxml in /opt/anaconda3/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /opt/anaconda3/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.1.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in /opt/anaconda3/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.0.4)
# Requirement already satisfied: nbclient>=0.5.0 in /opt/anaconda3/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.8.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/anaconda3/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (1.5.0)
# Requirement already satisfied: tinycss2 in /opt/anaconda3/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (1.2.1)
# Requirement already satisfied: fastjsonschema in /opt/anaconda3/lib/python3.12/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.16.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2025.1.31)
# Requirement already satisfied: appnope in /opt/anaconda3/lib/python3.12/site-packages (from ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.1.3)
# Requirement already satisfied: debugpy>=1.6.5 in /opt/anaconda3/lib/python3.12/site-packages (from ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (1.6.7)
# Requirement already satisfied: nest-asyncio in /opt/anaconda3/lib/python3.12/site-packages (from ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (1.6.0)
# Requirement already satisfied: psutil in /opt/anaconda3/lib/python3.12/site-packages (from ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (5.9.0)
# Requirement already satisfied: webencodings in /opt/anaconda3/lib/python3.12/site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.5.1)
# Collecting fqdn (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets)
#   Downloading fqdn-1.5.1-py3-none-any.whl.metadata (1.4 kB)
# Collecting isoduration (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets)
#   Downloading isoduration-20.11.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: jsonpointer>1.13 in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.1)
# Collecting uri-template (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets)
#   Downloading uri_template-1.3.0-py3-none-any.whl.metadata (8.8 kB)
# Collecting webcolors>=1.11 (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets)
#   Downloading webcolors-24.11.1-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: cffi>=1.0.1 in /opt/anaconda3/lib/python3.12/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in /opt/anaconda3/lib/python3.12/site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.5)
# Requirement already satisfied: pycparser in /opt/anaconda3/lib/python3.12/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.21)
# Requirement already satisfied: arrow>=0.15.0 in /opt/anaconda3/lib/python3.12/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (1.2.3)
# Downloading webcolors-24.11.1-py3-none-any.whl (14 kB)
# Downloading fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Downloading isoduration-20.11.0-py3-none-any.whl (11 kB)
# Downloading uri_template-1.3.0-py3-none-any.whl (11 kB)
# Installing collected packages: webcolors, uri-template, fqdn, isoduration
# Successfully installed fqdn-1.5.1 isoduration-20.11.0 uri-template-1.3.0 webcolors-24.11.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install ipywidgets
# Out:
# Requirement already satisfied: ipywidgets in /opt/anaconda3/lib/python3.12/site-packages (7.8.1)
# Requirement already satisfied: comm>=0.1.3 in /opt/anaconda3/lib/python3.12/site-packages (from ipywidgets) (0.2.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from ipywidgets) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=3.6.6 in /opt/anaconda3/lib/python3.12/site-packages (from ipywidgets) (3.6.6)
# Requirement already satisfied: ipython>=4.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from ipywidgets) (8.25.0)
# Requirement already satisfied: jupyterlab-widgets<3,>=1.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from ipywidgets) (1.0.0)
# Requirement already satisfied: decorator in /opt/anaconda3/lib/python3.12/site-packages (from ipython>=4.0.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/anaconda3/lib/python3.12/site-packages (from ipython>=4.0.0->ipywidgets) (0.18.1)
# Requirement already satisfied: matplotlib-inline in /opt/anaconda3/lib/python3.12/site-packages (from ipython>=4.0.0->ipywidgets) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /opt/anaconda3/lib/python3.12/site-packages (from ipython>=4.0.0->ipywidgets) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in /opt/anaconda3/lib/python3.12/site-packages (from ipython>=4.0.0->ipywidgets) (2.15.1)
# Requirement already satisfied: stack-data in /opt/anaconda3/lib/python3.12/site-packages (from ipython>=4.0.0->ipywidgets) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /opt/anaconda3/lib/python3.12/site-packages (from ipython>=4.0.0->ipywidgets) (4.8.0)
# Requirement already satisfied: notebook>=4.4.1 in /opt/anaconda3/lib/python3.12/site-packages (from widgetsnbextension~=3.6.6->ipywidgets) (7.0.8)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /opt/anaconda3/lib/python3.12/site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets) (0.8.3)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /opt/anaconda3/lib/python3.12/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.14.1)
# Requirement already satisfied: jupyterlab-server<3,>=2.22.1 in /opt/anaconda3/lib/python3.12/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.27.3)
# Requirement already satisfied: jupyterlab<4.1,>=4.0.2 in /opt/anaconda3/lib/python3.12/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (4.0.11)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in /opt/anaconda3/lib/python3.12/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.2.3)
# Requirement already satisfied: tornado>=6.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (6.4.1)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/anaconda3/lib/python3.12/site-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/anaconda3/lib/python3.12/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=4.0.0->ipywidgets) (0.2.5)
# Requirement already satisfied: executing in /opt/anaconda3/lib/python3.12/site-packages (from stack-data->ipython>=4.0.0->ipywidgets) (0.8.3)
# Requirement already satisfied: asttokens in /opt/anaconda3/lib/python3.12/site-packages (from stack-data->ipython>=4.0.0->ipywidgets) (2.0.5)
# Requirement already satisfied: pure-eval in /opt/anaconda3/lib/python3.12/site-packages (from stack-data->ipython>=4.0.0->ipywidgets) (0.2.2)
# Requirement already satisfied: anyio>=3.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (4.2.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (21.3.0)
# Requirement already satisfied: jinja2>=3.0.3 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (3.1.4)
# Requirement already satisfied: jupyter-client>=7.4.4 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (8.6.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (5.7.2)
# Requirement already satisfied: jupyter-events>=0.9.0 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.4.4)
# Requirement already satisfied: nbconvert>=6.4.4 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (7.10.0)
# Requirement already satisfied: nbformat>=5.3.0 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (5.9.2)
# Requirement already satisfied: overrides>=5.0 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (7.4.0)
# Requirement already satisfied: packaging>=22.0 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (23.2)
# Requirement already satisfied: prometheus-client>=0.9 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.14.1)
# Requirement already satisfied: pyzmq>=24 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (25.1.2)
# Requirement already satisfied: send2trash>=1.8.2 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.17.1)
# Requirement already satisfied: websocket-client>=1.7 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from jupyterlab<4.1,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.0.4)
# Requirement already satisfied: ipykernel in /opt/anaconda3/lib/python3.12/site-packages (from jupyterlab<4.1,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (6.28.0)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from jupyterlab<4.1,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.2.0)
# Requirement already satisfied: babel>=2.10 in /opt/anaconda3/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.11.0)
# Requirement already satisfied: json5>=0.9.0 in /opt/anaconda3/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.9.6)
# Requirement already satisfied: jsonschema>=4.18.0 in /opt/anaconda3/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (4.19.2)
# Requirement already satisfied: requests>=2.31 in /opt/anaconda3/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.32.2)
# Requirement already satisfied: six in /opt/anaconda3/lib/python3.12/site-packages (from asttokens->stack-data->ipython>=4.0.0->ipywidgets) (1.16.0)
# Requirement already satisfied: idna>=2.8 in /opt/anaconda3/lib/python3.12/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (3.7)
# Requirement already satisfied: sniffio>=1.1 in /opt/anaconda3/lib/python3.12/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (1.3.0)
# Requirement already satisfied: argon2-cffi-bindings in /opt/anaconda3/lib/python3.12/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (21.2.0)
# Requirement already satisfied: pytz>=2015.7 in /opt/anaconda3/lib/python3.12/site-packages (from babel>=2.10->jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2024.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/lib/python3.12/site-packages (from jinja2>=3.0.3->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.1.3)
# Requirement already satisfied: attrs>=22.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.10.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-client>=7.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (3.10.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (6.0.1)
# Requirement already satisfied: rfc3339-validator in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.1.1)
# Requirement already satisfied: beautifulsoup4 in /opt/anaconda3/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (4.1.0)
# Requirement already satisfied: defusedxml in /opt/anaconda3/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /opt/anaconda3/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.1.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in /opt/anaconda3/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.0.4)
# Requirement already satisfied: nbclient>=0.5.0 in /opt/anaconda3/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.8.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/anaconda3/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (1.5.0)
# Requirement already satisfied: tinycss2 in /opt/anaconda3/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (1.2.1)
# Requirement already satisfied: fastjsonschema in /opt/anaconda3/lib/python3.12/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.16.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2025.1.31)
# Requirement already satisfied: appnope in /opt/anaconda3/lib/python3.12/site-packages (from ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.1.3)
# Requirement already satisfied: debugpy>=1.6.5 in /opt/anaconda3/lib/python3.12/site-packages (from ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (1.6.7)
# Requirement already satisfied: nest-asyncio in /opt/anaconda3/lib/python3.12/site-packages (from ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (1.6.0)
# Requirement already satisfied: psutil in /opt/anaconda3/lib/python3.12/site-packages (from ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (5.9.0)
# Requirement already satisfied: webencodings in /opt/anaconda3/lib/python3.12/site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.5.1)
# Requirement already satisfied: fqdn in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (1.5.1)
# Requirement already satisfied: isoduration in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.1)
# Requirement already satisfied: uri-template in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (24.11.1)
# Requirement already satisfied: cffi>=1.0.1 in /opt/anaconda3/lib/python3.12/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in /opt/anaconda3/lib/python3.12/site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.5)
# Requirement already satisfied: pycparser in /opt/anaconda3/lib/python3.12/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.21)
# Requirement already satisfied: arrow>=0.15.0 in /opt/anaconda3/lib/python3.12/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (1.2.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import ipywidgets as widgets
widgets.IntSlider()
# Out:
# IntSlider(value=0)

# %%
# !pip install ipywidgets
# !jupyter nbextension enable --py widgetsnbextension
# Out:
# zsh:1: command not found: pip
# zsh:1: command not found: jupyter

# %%
import os
import pandas as pd
import re
import unicodedata

# Define the directory with your CSV and XLSM files
files_path = "/Users/sreeharsha/Documents/TGH Data Management Cleaning/Merge testing/Enrollment Survey"  # <-- Update this path

# Function to apply basic cleaning to column names
def basic_clean(col):
    # Remove leading/trailing whitespace and convert to lowercase
    col = col.strip().lower()
    # Normalize accented characters (e.g., convert "é" to "e")
    col = unicodedata.normalize('NFKD', col).encode('ascii', 'ignore').decode('utf-8')
    # Remove punctuation and symbols (keeping alphanumerics and whitespace)
    col = re.sub(r'[^\w\s]', '', col)
    # Replace one or more whitespace with a single underscore
    col = re.sub(r'\s+', '_', col)
    # Remove any trailing underscores
    col = col.strip('_')
    return col

# Gather all CSV and XLSM file paths
all_files = [os.path.join(files_path, f) for f in os.listdir(files_path) 
             if f.endswith('.csv') or f.endswith('.xlsm')]

# Process each file and display the original and cleaned column names
for file in all_files:
    try:
        # Read the file based on its extension
        if file.endswith('.csv'):
            df = pd.read_csv(file)
        else:
            df = pd.read_excel(file)
        
        # Get original column names and apply basic cleaning
        original_cols = df.columns.tolist()
        cleaned_cols = [basic_clean(col) for col in original_cols]
        
        print(f"File: {os.path.basename(file)}")
        print("Original Columns:")
        print(original_cols)
        print("Cleaned Columns:")
        print(cleaned_cols)
        print("-" * 60)
        
        # Optionally, if you want to update the DataFrame in memory:
        # df.columns = cleaned_cols
        # And then, if you wish, save the cleaned DataFrame to a new file:
        # out_path = os.path.join("path/to/save", os.path.basename(file))
        # if file.endswith('.csv'):
        #     df.to_csv(out_path, index=False)
        # else:
        #     df.to_excel(out_path, index=False)
    except Exception as e:
        print(f"Error processing {file}: {e}")
# Out:
# /var/folders/q6/v__5dqvn4fsgnld9cp_x0v1m0000gn/T/ipykernel_23866/1096900719.py:32: DtypeWarning: Columns (16,27,30,31,32,33,34,35,48,75,76,77,81,99) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file)
# File: Learner+Enrollment+ENGLISH.csv
# Original Columns:
# ['Submitted Date', 'Course Name', 'Name of Site/School', 'Course Type', 'First Name', 'Last Name', 'Do you have home internet access (i.e. wifi)?', 'What are your pronouns?', 'Have you received a TGH device (Chromebook or iPad) in the last two years?', 'Date of Birth', 'What is your gender?', 'Your gender identity:', '8. How would you describe your race/ethnicity?', 'How would you describe your race/ethnicity? (select all that apply)', 'Primary Language', 'other_language', 'Are you a veteran?', 'Home Street Address (including apartment number)', 'City', 'State', 'Zip Code', 'Phone Number', 'Email Address', 'Number of people in Household', 'Educational Status', 'Employment Status', 'Are you self-employed?', 'What is the Zip Code where you work?', 'Household Income Level', 'Do you receive housing assistance?', 'What other Boston neighborhoods are you connected to? For example, do you receive services, visit family or friends, go to school or places of worship, in any of the following neighborhoods? [Select all that apply]', 'other_neighborhoods', 'Were you born in the United States?', 'Have you ever spent time in a jail, prison, or juvenile detention center?', 'How do you describe your sexual orientation?', 'other_sexual_orientation', "Child's First Name", "Child's Last Name", "What are your child's pronouns?", "Child's Date of Birth", "What is your child's gender?", "Your child's gender identity:", "How would you describe your child's race/ethnicity? (select all that apply)", "Child's Primary Language", 'other_child_language?', 'What is your goal for taking this course?', "Is this the first activity you've participated in at your program site?", 'How many working computers do you have at home?', 'How many tablets do you have at home? (e.g. iPad, Kindle Fire, Samsung Galaxy Tab)', 'Do you have a smartphone? (e.g. iPhone, Google Pixel, Samsung Galaxy)', 'Is your internet affordable?', 'Is your internet reliable?', 'Are you aware of the Affordable Connectivity Program (ACP), an FCC (Federal Communications Commission) program to help families and households afford internet service? (More info here: https://www.fcc.gov/acp)', 'Are you currently enrolled in the ACP program?', 'Please describe your confidence level using the internet to find information you need:', 'Creating and sending emails', 'Opening and replying to emails', 'Downloading attachments I receive in an email (documents or pictures)', 'Adding an attachment to an email I am sending (like documents or pictures)', 'Turning the computer on and off', "Adjusting the computer's settings (like the size of the text or the background picture)", 'Connecting the computer to wifi', 'Installing applications from the Chromebook store', 'Saving files to the computer and finding them later', 'Using a mouse, headset, and/or other accessories', 'Turning the tablet on and off', "Adjusting the tablet's settings (like the size of the text or the background picture)", 'Connecting the tablet to wifi', 'Installing applications (Apps)', 'Saving files to the tablet and finding them later', 'I am aware of what my skills are to be employed in a goodjob (e.g., digital skills, specific trade skills, etc.).', 'I am aware of what my resources are to be employed in a good job (e.g., resources for job searching, child care resources, etc.).', 'I am able to utilize my skills to move toward career goals.', 'I am able to utilize my resources to move toward career goals.', 'Even if I am not able to achieve my financial goals right away, I will find a way to get there.', 'Because of my money situation, I feel like I will never have thethings I want in life.', 'I am just getting by financially.', 'I am concerned that the money I have or will save won’t last.', 'Do you have an existing business?', 'Name of Business', 'What industry is your business in?', 'If you selected "Other," please explain:', 'Do you have a website for your business?', 'What is your website address (URL)?', 'Which, if any, social media to ...
# Cleaned Columns:
# ['submitted_date', 'course_name', 'name_of_siteschool', 'course_type', 'first_name', 'last_name', 'do_you_have_home_internet_access_ie_wifi', 'what_are_your_pronouns', 'have_you_received_a_tgh_device_chromebook_or_ipad_in_the_last_two_years', 'date_of_birth', 'what_is_your_gender', 'your_gender_identity', '8_how_would_you_describe_your_raceethnicity', 'how_would_you_describe_your_raceethnicity_select_all_that_apply', 'primary_language', 'other_language', 'are_you_a_veteran', 'home_street_address_including_apartment_number', 'city', 'state', 'zip_code', 'phone_number', 'email_address', 'number_of_people_in_household', 'educational_status', 'employment_status', 'are_you_selfemployed', 'what_is_the_zip_code_where_you_work', 'household_income_level', 'do_you_receive_housing_assistance', 'what_other_boston_neighborhoods_are_you_connected_to_for_example_do_you_receive_services_visit_family_or_friends_go_to_school_or_places_of_worship_in_any_of_the_following_neighborhoods_select_all_that_apply', 'other_neighborhoods', 'were_you_born_in_the_united_states', 'have_you_ever_spent_time_in_a_jail_prison_or_juvenile_detention_center', 'how_do_you_describe_your_sexual_orientation', 'other_sexual_orientation', 'childs_first_name', 'childs_last_name', 'what_are_your_childs_pronouns', 'childs_date_of_birth', 'what_is_your_childs_gender', 'your_childs_gender_identity', 'how_would_you_describe_your_childs_raceethnicity_select_all_that_apply', 'childs_primary_language', 'other_child_language', 'what_is_your_goal_for_taking_this_course', 'is_this_the_first_activity_youve_participated_in_at_your_program_site', 'how_many_working_computers_do_you_have_at_home', 'how_many_tablets_do_you_have_at_home_eg_ipad_kindle_fire_samsung_galaxy_tab', 'do_you_have_a_smartphone_eg_iphone_google_pixel_samsung_galaxy', 'is_your_internet_affordable', 'is_your_internet_reliable', 'are_you_aware_of_the_affordable_connectivity_program_acp_an_fcc_federal_communications_commission_program_to_help_families_and_households_afford_internet_service_more_info_here_httpswwwfccgovacp', 'are_you_currently_enrolled_in_the_acp_program', 'please_describe_your_confidence_level_using_the_internet_to_find_information_you_need', 'creating_and_sending_emails', 'opening_and_replying_to_emails', 'downloading_attachments_i_receive_in_an_email_documents_or_pictures', 'adding_an_attachment_to_an_email_i_am_sending_like_documents_or_pictures', 'turning_the_computer_on_and_off', 'adjusting_the_computers_settings_like_the_size_of_the_text_or_the_background_picture', 'connecting_the_computer_to_wifi', 'installing_applications_from_the_chromebook_store', 'saving_files_to_the_computer_and_finding_them_later', 'using_a_mouse_headset_andor_other_accessories', 'turning_the_tablet_on_and_off', 'adjusting_the_tablets_settings_like_the_size_of_the_text_or_the_background_picture', 'connecting_the_tablet_to_wifi', 'installing_applications_apps', 'saving_files_to_the_tablet_and_finding_them_later', 'i_am_aware_of_what_my_skills_are_to_be_employed_in_a_goodjob_eg_digital_skills_specific_trade_skills_etc', 'i_am_aware_of_what_my_resources_are_to_be_employed_in_a_good_job_eg_resources_for_job_searching_child_care_resources_etc', 'i_am_able_to_utilize_my_skills_to_move_toward_career_goals', 'i_am_able_to_utilize_my_resources_to_move_toward_career_goals', 'even_if_i_am_not_able_to_achieve_my_financial_goals_right_away_i_will_find_a_way_to_get_there', 'because_of_my_money_situation_i_feel_like_i_will_never_have_thethings_i_want_in_life', 'i_am_just_getting_by_financially', 'i_am_concerned_that_the_money_i_have_or_will_save_wont_last', 'do_you_have_an_existing_business', 'name_of_business', 'what_industry_is_your_business_in', 'if_you_selected_other_please_explain', 'do_you_have_a_website_for_your_business', 'what_is_your_website_address_url', 'which_if_any_social_media_tools_do_you_use_for_your_business', 'please_enter_anyall_of_your_social_media_handles_separated_by_a_comma_eg_techgoeshome_facebookcomyourbusinessn ...
# ------------------------------------------------------------
# File: translated_spanish.xlsm
# Original Columns:
# ['Course Name', 'Name of Site/School', 'Course Type', 'First Name', 'Last Name', 'What are your pronouns?', 'Have you received a TGH device (Chromebook or iPad) in the last two years?', 'Date of Birth', 'What is your gender?', 'Your gender identity', 'How would you describe your race/ethnicity?', 'How would you describe your race/ethnicity? (select all that apply)', 'Primary Language', 'If you selected "Other," what language?', 'Home Street Address (including apartment number)', 'City', 'State', 'Zip Code', 'Phone Number', 'Email Address', 'Number of people in Household', ' Educational Status', 'Employment Status', 'What is the zip code of your workplace?', 'Are you self-employed?', 'Household Income Level', 'Do you receive housing assistance?', 'What other Boston neighborhoods are you connected to? For example, do you receive services, visit family or friends, go to school or places of worship, in any of the following neighborhoods? [Select all that apply]', 'Were you born in the United States?', 'Have you ever spent time in a jail, prison, or juvenile detention centre?', 'How do you describe your sexual orientation? Select all that apply.', 'Other', "Child's First Name", "Child's Last Name", "What are your child's pronouns?", "Child's Date of Birth", "What is your child's gender?", "Your child's gender identity", "How would you describe your child's race/ethnicity", "How would you describe your child's race/ethnicity? (select all that apply)", "Child's Primary Language", 'If you selected "Other", what language?', 'What is your goal for taking this course?', "Is this the first activity you've participated in at your program site?", 'How many working computers do you have at home?', 'How many tablets do you have at home? (e.g. iPad, Kindle Fire, Samsung Galaxy Tab)', 'Do you have a smartphone?', 'Do you have home internet access (i.e. wifi)?', 'Is your internet affordable?', 'Is your internet reliable?', 'Are you aware of the Affordable Connectivity Program (ACP), an FCC (Federal Communications Commission) program to help families and households afford internet service? (More info here: https://www.fcc.gov/acp)', 'Are you currently enrolled in the ACP program?', 'Please describe your confidence level using the internet to find information you need:', 'Creating and Sending emails', 'Opening and replying to emails', 'Downloading attachments I receive in an email (documents or pictures)', 'Adding an attachment to an email I am sending (like documents or pictures)', 'Turning the computer on and off', "Adjusting the computer's settings (like the size of the text or the background picture)", 'Connecting the computer to wifi', 'Installing applications from the Chromebook store', 'Saving files to the computer and finding them later', 'Using a mouse, headset, and/or other accessories', 'Turning the tablet on and off', "Adjusting the tablet's settings (like the size of the text or the background picture)", 'Connecting the tablet to wifi', 'Installing applications (Apps)', 'Saving files to the tablet and finding them later', 'Do you have an existing business?', 'Name of Business', 'What industry is your business in?', 'If you selected "Other," please explain:', 'Do you have a website for your business?', 'What is your website address (URL)?', 'Which, if any, social media tools do you use for your business?', 'Please enter any/all of your social media handles separated by a comma', 'Acepto que usen citas, tomen fotos y graben pel√≠culas o videos m√≠os o de mis hijos en el programa de Tech Goes Home. Concedo a Tech Goes Home el derecho de editar, usar y reutilizar los productos mencionados sin √°nimo de lucro, incluido el uso impreso, en Internet y en cualquier formato multimedia. Acepto estos t√©rminos de forma voluntaria y entiendo que no recibir√© ninguna compensaci√≥n financiera. Por el presente documento, libero a Tech Goes Home y sus agentes y empleados de cualquier reclamaci√≥n, demanda y responsabilidad en el marco de lo anterior.  ...
# Cleaned Columns:
# ['course_name', 'name_of_siteschool', 'course_type', 'first_name', 'last_name', 'what_are_your_pronouns', 'have_you_received_a_tgh_device_chromebook_or_ipad_in_the_last_two_years', 'date_of_birth', 'what_is_your_gender', 'your_gender_identity', 'how_would_you_describe_your_raceethnicity', 'how_would_you_describe_your_raceethnicity_select_all_that_apply', 'primary_language', 'if_you_selected_other_what_language', 'home_street_address_including_apartment_number', 'city', 'state', 'zip_code', 'phone_number', 'email_address', 'number_of_people_in_household', 'educational_status', 'employment_status', 'what_is_the_zip_code_of_your_workplace', 'are_you_selfemployed', 'household_income_level', 'do_you_receive_housing_assistance', 'what_other_boston_neighborhoods_are_you_connected_to_for_example_do_you_receive_services_visit_family_or_friends_go_to_school_or_places_of_worship_in_any_of_the_following_neighborhoods_select_all_that_apply', 'were_you_born_in_the_united_states', 'have_you_ever_spent_time_in_a_jail_prison_or_juvenile_detention_centre', 'how_do_you_describe_your_sexual_orientation_select_all_that_apply', 'other', 'childs_first_name', 'childs_last_name', 'what_are_your_childs_pronouns', 'childs_date_of_birth', 'what_is_your_childs_gender', 'your_childs_gender_identity', 'how_would_you_describe_your_childs_raceethnicity', 'how_would_you_describe_your_childs_raceethnicity_select_all_that_apply', 'childs_primary_language', 'if_you_selected_other_what_language', 'what_is_your_goal_for_taking_this_course', 'is_this_the_first_activity_youve_participated_in_at_your_program_site', 'how_many_working_computers_do_you_have_at_home', 'how_many_tablets_do_you_have_at_home_eg_ipad_kindle_fire_samsung_galaxy_tab', 'do_you_have_a_smartphone', 'do_you_have_home_internet_access_ie_wifi', 'is_your_internet_affordable', 'is_your_internet_reliable', 'are_you_aware_of_the_affordable_connectivity_program_acp_an_fcc_federal_communications_commission_program_to_help_families_and_households_afford_internet_service_more_info_here_httpswwwfccgovacp', 'are_you_currently_enrolled_in_the_acp_program', 'please_describe_your_confidence_level_using_the_internet_to_find_information_you_need', 'creating_and_sending_emails', 'opening_and_replying_to_emails', 'downloading_attachments_i_receive_in_an_email_documents_or_pictures', 'adding_an_attachment_to_an_email_i_am_sending_like_documents_or_pictures', 'turning_the_computer_on_and_off', 'adjusting_the_computers_settings_like_the_size_of_the_text_or_the_background_picture', 'connecting_the_computer_to_wifi', 'installing_applications_from_the_chromebook_store', 'saving_files_to_the_computer_and_finding_them_later', 'using_a_mouse_headset_andor_other_accessories', 'turning_the_tablet_on_and_off', 'adjusting_the_tablets_settings_like_the_size_of_the_text_or_the_background_picture', 'connecting_the_tablet_to_wifi', 'installing_applications_apps', 'saving_files_to_the_tablet_and_finding_them_later', 'do_you_have_an_existing_business', 'name_of_business', 'what_industry_is_your_business_in', 'if_you_selected_other_please_explain', 'do_you_have_a_website_for_your_business', 'what_is_your_website_address_url', 'which_if_any_social_media_tools_do_you_use_for_your_business', 'please_enter_anyall_of_your_social_media_handles_separated_by_a_comma', 'acepto_que_usen_citas_tomen_fotos_y_graben_pelculas_o_videos_mos_o_de_mis_hijos_en_el_programa_de_tech_goes_home_concedo_a_tech_goes_home_el_derecho_de_editar_usar_y_reutilizar_los_productos_mencionados_sin_nimo_de_lucro_incluido_el_uso_impreso_en_internet_y_en_cualquier_formato_multimedia_acepto_estos_trminos_de_forma_voluntaria_y_entiendo_que_no_recibir_ninguna_compensacin_financiera_por_el_presente_documento_libero_a_tech_goes_home_y_sus_agentes_y_empleados_de_cualquier_reclamacin_demanda_y_responsabilidad_en_el_marco_de_lo_anterior_si_no_desea_que_tech_goes_home_use_su_foto_indquelo_a_sus_instructores_de_tgh_para_que_no_nos_enven_fotografas_suyas', 'i_am_aware_of_what_my_skil ...
# ------------------------------------------------------------
# File: (OLD) TGH Learner Enrollment Form (6.2.2022).csv
# Original Columns:
# ['Course Name', 'Name of Site/School', 'Course Type', 'First Name', 'Last Name', 'Have you received a TGH device (Chromebook or iPad) in the last two years?', 'Date of Birth', 'To which gender identity do you most identify?', 'Your gender identity:', 'Race/Ethnicity', 'Your Race/Ethnicity', 'Primary Language', 'other_primary_language', 'Home Street Address (including apartment number)', 'City', 'State', 'Zip Code', 'Phone Number', 'Email Address', 'Number of people in Household', 'Educational Status', 'Employment Status', 'Household Income Level', 'Do you receive housing assistance?', "Child's First Name", "Child's Last Name", "Child's Date of Birth", "Child's Gender", "Your child's gender identity:", "Child's Race/Ethnicity", "Your child's Race/Ethnicity:", "Child's Primary Language", 'If you selected "Other", what language?', 'What is your goal for taking this course?', "Is this the first activity you've participated in at your program site?", 'How many working computers do you have at home?', 'How many tablets do you have at home? (e.g. iPad, Kindle Fire, Samsung Galaxy Tab)', 'Do you have a smartphone? (e.g. iPhone, Google Pixel, Samsung Galaxy)', 'Do you have home internet access (i.e. wifi)?', 'Are you aware of the Affordable Connectivity Program (ACP), an FCC (Federal Communications Commission) program to help families and households afford internet service? (More info here: https://www.fcc.gov/acp)', 'Are you currently enrolled in the ACP Program?', 'Please describe your confidence level using the internet to find information you need:', 'Creating and sending emails', 'Opening and replying to emails', 'Downloading attachments I receive in an email (documents or pictures)', 'Adding an attachment to an email I am sending (like documents or pictures)', 'Turning the Computer on and off', "Adjusting the computer's settings (like the size of the text or the background picture)", 'Connecting the computer to wifi', 'Installing applications from the Chromebook store', 'Saving files to the computer and finding them later', 'Using a mouse, headset and/or other accessories', 'Turning the tablet on and off', "Adjusting the tablet's settings (like the size of the text or the background picture)", 'Connecting the tablet to wifi', 'Installing applications (Apps)', 'Saving files to the tablet and finding them later', 'Do you have an existing business?', 'Name of Business', 'What industry is your business in?', 'If you selected "Other", please explain:', 'Do you have a website for your business?', 'What is your website address (URL)?', 'Which, if any, social media tools do you use for your business?', 'Please enter any/all of your social media handles separated by a comma(,) (e.g. @techgoeshome, facebook.com/yourbusinessname)', 'I hereby give the unqualified right to the TGH program to take pictures and/ or video of me while participating in my course. I give permission for these images as well as materials that we have created in the TGH program to be used in print and web-based publications. The TGH program will put these images to legitimate use without limitation or reservation. If you do not wish for your photo to be used by TGH, please let your TGH instructors know so they will not send us pictures of you.', 'I agree to the Learner Agreement as listed above', 'Course ID', 'Form Name', 'Creation Date', 'Modified Date', 'Submitted Date', 'Completion Time', 'Response Html Beta', 'Response Html', 'Response Text', 'Response', 'Response Url', 'Resume Email', 'File List', 'Unprotected File List', 'Response Id', 'Referrer', 'Ip Address']
# Cleaned Columns:
# ['course_name', 'name_of_siteschool', 'course_type', 'first_name', 'last_name', 'have_you_received_a_tgh_device_chromebook_or_ipad_in_the_last_two_years', 'date_of_birth', 'to_which_gender_identity_do_you_most_identify', 'your_gender_identity', 'raceethnicity', 'your_raceethnicity', 'primary_language', 'other_primary_language', 'home_street_address_including_apartment_number', 'city', 'state', 'zip_code', 'phone_number', 'email_address', 'number_of_people_in_household', 'educational_status', 'employment_status', 'household_income_level', 'do_you_receive_housing_assistance', 'childs_first_name', 'childs_last_name', 'childs_date_of_birth', 'childs_gender', 'your_childs_gender_identity', 'childs_raceethnicity', 'your_childs_raceethnicity', 'childs_primary_language', 'if_you_selected_other_what_language', 'what_is_your_goal_for_taking_this_course', 'is_this_the_first_activity_youve_participated_in_at_your_program_site', 'how_many_working_computers_do_you_have_at_home', 'how_many_tablets_do_you_have_at_home_eg_ipad_kindle_fire_samsung_galaxy_tab', 'do_you_have_a_smartphone_eg_iphone_google_pixel_samsung_galaxy', 'do_you_have_home_internet_access_ie_wifi', 'are_you_aware_of_the_affordable_connectivity_program_acp_an_fcc_federal_communications_commission_program_to_help_families_and_households_afford_internet_service_more_info_here_httpswwwfccgovacp', 'are_you_currently_enrolled_in_the_acp_program', 'please_describe_your_confidence_level_using_the_internet_to_find_information_you_need', 'creating_and_sending_emails', 'opening_and_replying_to_emails', 'downloading_attachments_i_receive_in_an_email_documents_or_pictures', 'adding_an_attachment_to_an_email_i_am_sending_like_documents_or_pictures', 'turning_the_computer_on_and_off', 'adjusting_the_computers_settings_like_the_size_of_the_text_or_the_background_picture', 'connecting_the_computer_to_wifi', 'installing_applications_from_the_chromebook_store', 'saving_files_to_the_computer_and_finding_them_later', 'using_a_mouse_headset_andor_other_accessories', 'turning_the_tablet_on_and_off', 'adjusting_the_tablets_settings_like_the_size_of_the_text_or_the_background_picture', 'connecting_the_tablet_to_wifi', 'installing_applications_apps', 'saving_files_to_the_tablet_and_finding_them_later', 'do_you_have_an_existing_business', 'name_of_business', 'what_industry_is_your_business_in', 'if_you_selected_other_please_explain', 'do_you_have_a_website_for_your_business', 'what_is_your_website_address_url', 'which_if_any_social_media_tools_do_you_use_for_your_business', 'please_enter_anyall_of_your_social_media_handles_separated_by_a_comma_eg_techgoeshome_facebookcomyourbusinessname', 'i_hereby_give_the_unqualified_right_to_the_tgh_program_to_take_pictures_and_or_video_of_me_while_participating_in_my_course_i_give_permission_for_these_images_as_well_as_materials_that_we_have_created_in_the_tgh_program_to_be_used_in_print_and_webbased_publications_the_tgh_program_will_put_these_images_to_legitimate_use_without_limitation_or_reservation_if_you_do_not_wish_for_your_photo_to_be_used_by_tgh_please_let_your_tgh_instructors_know_so_they_will_not_send_us_pictures_of_you', 'i_agree_to_the_learner_agreement_as_listed_above', 'course_id', 'form_name', 'creation_date', 'modified_date', 'submitted_date', 'completion_time', 'response_html_beta', 'response_html', 'response_text', 'response', 'response_url', 'resume_email', 'file_list', 'unprotected_file_list', 'response_id', 'referrer', 'ip_address']
# ------------------------------------------------------------
# /var/folders/q6/v__5dqvn4fsgnld9cp_x0v1m0000gn/T/ipykernel_23866/1096900719.py:32: DtypeWarning: Columns (14,17,18,31,34,36,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file)
# File: (OLD)+TGH+Learner+Enrollment+Form+2025-03-06-11-24-39+457499.csv.csv
# Original Columns:
# ['Submitted Date', 'Name of Site/School', 'Course Type', 'First Name', 'Middle Initial', 'Last Name', 'Do you have school age children in your household?', "Child's First Name", "Child's Last Name", 'Is this your first activity/program at the school or site where you are taking TGH?', 'Employment Status', 'Race/Ethnicity', 'Household Income Level', 'Primary Language', 'Course Name', 'Have you received a TGH device (Chromebook or iPad) in the last two years?', 'Date of Birth', 'To which gender identity do you most identify?', 'If you selected "Other", please specify:', 'other_race/ethnicity', 'other_language', 'Home Street Address (including apartment number)', 'City', 'State', 'Zip', 'Phone Number', 'Email Address', 'Number of Members in Household', 'Educational Status', 'Occupation', 'Place of Work', 'Do you receive housing assistance?', "Child's Grade", "Child's Date of Birth", "Child's Gender", 'If you selected Other, please specify:', "Child's Race/Ethnicity", 'If you selected "Other", what race/ethnicity?', "Child's Primary Language", 'If you selected "Other", what language?', 'What is the main reason you decided to participate in TGH?', 'Which devices do you use at home?', 'If you selected "Other", what type of device?', 'Number of Working Computers at Home', 'Do you have home Internet access (i.e. wifi)?', 'How do you (or anyone living in your household) access the Internet in your home?', 'If you selected "Other", what type?', 'Which devices do you (or anyone living in your household) use to access the Internet in your home?', 'Is your Internet access through a discounted program? (Eg. Internet Essentials, PCs for People)', 'How satisfied are you with your Internet service at home?', "Why don't you have Internet access at home?", 'other_internet_cause', 'Have you ever had to change or cancel your Internet subscription because it is too expensive?', 'What do you and other household members use the Internet for?', 'What financial resources do you use?', 'financial_other', 'Do you have an existing business?', 'What best describes the organization you are starting or running?', 'What are the biggest challenges you are currently facing in running your business? If you have not yet started your business, what are the biggest obstacles?', 'Name of Business', 'How old is your business?', 'Annual Revenue of Business', 'Number of Employees', 'What industry is your business in?', 'other_business_industry', 'Do you accept credit/debit cards?', 'What does your business use the Internet for?', 'other_internet_use_for_business', 'Do you know of organizations that help small business owners navigate licensing and permitting, taxes, law, marketing, access to funding, and other business issues?', 'Do you have a website for your business?', 'Which, if any, social media tools do you use for your business?', 'If you selected "Other", please explain:', 'How often are your business social media pages updated?', 'I hereby give the unqualified right to the TGH program to take pictures and/ or video of me while participating in my course. I give permission for these images as well as materials that we have created in the TGH program to be used in print and web-based publications. The TGH program will put these images to legitimate use without limitation or reservation. If you do not wish for your photo to be used by TGH, please let your TGH trainers know so they will not send us pictures of you.', 'I agree to the Learner Agreement as listed above', 'Course ID', 'Form Name', 'Creation Date', 'Modified Date', 'Completion Time', 'Response Html Beta', 'Response Html', 'Response Text', 'Response', 'Response Url', 'Resume Email', 'File List', 'Unprotected File List', 'Response Id', 'Referrer', 'Ip Address']
# Cleaned Columns:
# ['submitted_date', 'name_of_siteschool', 'course_type', 'first_name', 'middle_initial', 'last_name', 'do_you_have_school_age_children_in_your_household', 'childs_first_name', 'childs_last_name', 'is_this_your_first_activityprogram_at_the_school_or_site_where_you_are_taking_tgh', 'employment_status', 'raceethnicity', 'household_income_level', 'primary_language', 'course_name', 'have_you_received_a_tgh_device_chromebook_or_ipad_in_the_last_two_years', 'date_of_birth', 'to_which_gender_identity_do_you_most_identify', 'if_you_selected_other_please_specify', 'other_raceethnicity', 'other_language', 'home_street_address_including_apartment_number', 'city', 'state', 'zip', 'phone_number', 'email_address', 'number_of_members_in_household', 'educational_status', 'occupation', 'place_of_work', 'do_you_receive_housing_assistance', 'childs_grade', 'childs_date_of_birth', 'childs_gender', 'if_you_selected_other_please_specify', 'childs_raceethnicity', 'if_you_selected_other_what_raceethnicity', 'childs_primary_language', 'if_you_selected_other_what_language', 'what_is_the_main_reason_you_decided_to_participate_in_tgh', 'which_devices_do_you_use_at_home', 'if_you_selected_other_what_type_of_device', 'number_of_working_computers_at_home', 'do_you_have_home_internet_access_ie_wifi', 'how_do_you_or_anyone_living_in_your_household_access_the_internet_in_your_home', 'if_you_selected_other_what_type', 'which_devices_do_you_or_anyone_living_in_your_household_use_to_access_the_internet_in_your_home', 'is_your_internet_access_through_a_discounted_program_eg_internet_essentials_pcs_for_people', 'how_satisfied_are_you_with_your_internet_service_at_home', 'why_dont_you_have_internet_access_at_home', 'other_internet_cause', 'have_you_ever_had_to_change_or_cancel_your_internet_subscription_because_it_is_too_expensive', 'what_do_you_and_other_household_members_use_the_internet_for', 'what_financial_resources_do_you_use', 'financial_other', 'do_you_have_an_existing_business', 'what_best_describes_the_organization_you_are_starting_or_running', 'what_are_the_biggest_challenges_you_are_currently_facing_in_running_your_business_if_you_have_not_yet_started_your_business_what_are_the_biggest_obstacles', 'name_of_business', 'how_old_is_your_business', 'annual_revenue_of_business', 'number_of_employees', 'what_industry_is_your_business_in', 'other_business_industry', 'do_you_accept_creditdebit_cards', 'what_does_your_business_use_the_internet_for', 'other_internet_use_for_business', 'do_you_know_of_organizations_that_help_small_business_owners_navigate_licensing_and_permitting_taxes_law_marketing_access_to_funding_and_other_business_issues', 'do_you_have_a_website_for_your_business', 'which_if_any_social_media_tools_do_you_use_for_your_business', 'if_you_selected_other_please_explain', 'how_often_are_your_business_social_media_pages_updated', 'i_hereby_give_the_unqualified_right_to_the_tgh_program_to_take_pictures_and_or_video_of_me_while_participating_in_my_course_i_give_permission_for_these_images_as_well_as_materials_that_we_have_created_in_the_tgh_program_to_be_used_in_print_and_webbased_publications_the_tgh_program_will_put_these_images_to_legitimate_use_without_limitation_or_reservation_if_you_do_not_wish_for_your_photo_to_be_used_by_tgh_please_let_your_tgh_trainers_know_so_they_will_not_send_us_pictures_of_you', 'i_agree_to_the_learner_agreement_as_listed_above', 'course_id', 'form_name', 'creation_date', 'modified_date', 'completion_time', 'response_html_beta', 'response_html', 'response_text', 'response', 'response_url', 'resume_email', 'file_list', 'unprotected_file_list', 'response_id', 'referrer', 'ip_address']
# ------------------------------------------------------------
# File: Cleaned_ES_translated_chinese.csv
# Original Columns:
# ['course name', 'name of siteschool', 'course type', 'first name', 'last name', 'what are your pronouns', 'have you received a tgh device chromebook or ipad in the last two years', 'date of birth', 'what is your gender', 'your gender identity', 'how would you describe your raceethnicity select all that apply', 'primary language', 'if you selected other what language', 'home street address including apartment number', 'city', 'state', 'zip code', 'phone number', 'email address', 'number of people in household', 'educational status', 'employment status', 'are you self employed', 'household income level', 'do you receive housing assistance', 'childs first name', 'childs last name', 'what are your childs pronouns', 'childs date of birth', "what is your child's gender", "your child's gender identity", 'how would you describe your childs raceethnicity', 'childs primary language', 'Unnamed: 33', 'what is your goal for taking this course', 'is this the first activity youve participated in at your program site', 'how many working computers do you have at home', 'how many tablets do you have at home e g ipad kindle fire samsung galaxy tab', 'do you have a smartphone e g iphone google pixel samsung galaxy', 'do you have home internet access i e wifi', 'is your internet affordable', 'is your internet reliable', 'are you aware of the affordable connectivity program acp an fcc federal communications commission program to help families and households afford internet service more info here httpswww fcc govacp', 'are you currently enrolled in the acp program', 'please describe your confidence level using the internet to find information you need', 'creating and sending emails', 'opening and replying to emails', 'downloading attachments i receive in an email documents or pictures', 'adding an attachment to an email i am sending like documents or pictures', 'turning the tablet on and off', 'adjusting the tablets settings like the size of the text or the background picture', 'connecting the tablet to wifi', 'installing applications from the chromebook store', 'saving files to the tablet and finding them later', 'using a mouse headset andor other accessories', 'do you have an existing business', 'name of business', 'what industry is your business in', 'if you selected other please explain', 'do you have a website for your business', 'what is your website address url', 'which if any social media tools do you use for your business', 'please enter any all of your social media handles separated by a comma e g techgoeshome facebook com yourbusinessname', 'tech goes home tech goes home tech goes home tech goes home tgh', 'i agree to the learner agreement as listed above', 'course id', 'fa list learner enrollment english 1', 'form name', 'creation date', 'modified date', 'submitted date', 'completion time', 'response text', 'response_html', 'resume email', 'file list', 'unprotected file list', 'response', 'referrer', 'ip address']
# Cleaned Columns:
# ['course_name', 'name_of_siteschool', 'course_type', 'first_name', 'last_name', 'what_are_your_pronouns', 'have_you_received_a_tgh_device_chromebook_or_ipad_in_the_last_two_years', 'date_of_birth', 'what_is_your_gender', 'your_gender_identity', 'how_would_you_describe_your_raceethnicity_select_all_that_apply', 'primary_language', 'if_you_selected_other_what_language', 'home_street_address_including_apartment_number', 'city', 'state', 'zip_code', 'phone_number', 'email_address', 'number_of_people_in_household', 'educational_status', 'employment_status', 'are_you_self_employed', 'household_income_level', 'do_you_receive_housing_assistance', 'childs_first_name', 'childs_last_name', 'what_are_your_childs_pronouns', 'childs_date_of_birth', 'what_is_your_childs_gender', 'your_childs_gender_identity', 'how_would_you_describe_your_childs_raceethnicity', 'childs_primary_language', 'unnamed_33', 'what_is_your_goal_for_taking_this_course', 'is_this_the_first_activity_youve_participated_in_at_your_program_site', 'how_many_working_computers_do_you_have_at_home', 'how_many_tablets_do_you_have_at_home_e_g_ipad_kindle_fire_samsung_galaxy_tab', 'do_you_have_a_smartphone_e_g_iphone_google_pixel_samsung_galaxy', 'do_you_have_home_internet_access_i_e_wifi', 'is_your_internet_affordable', 'is_your_internet_reliable', 'are_you_aware_of_the_affordable_connectivity_program_acp_an_fcc_federal_communications_commission_program_to_help_families_and_households_afford_internet_service_more_info_here_httpswww_fcc_govacp', 'are_you_currently_enrolled_in_the_acp_program', 'please_describe_your_confidence_level_using_the_internet_to_find_information_you_need', 'creating_and_sending_emails', 'opening_and_replying_to_emails', 'downloading_attachments_i_receive_in_an_email_documents_or_pictures', 'adding_an_attachment_to_an_email_i_am_sending_like_documents_or_pictures', 'turning_the_tablet_on_and_off', 'adjusting_the_tablets_settings_like_the_size_of_the_text_or_the_background_picture', 'connecting_the_tablet_to_wifi', 'installing_applications_from_the_chromebook_store', 'saving_files_to_the_tablet_and_finding_them_later', 'using_a_mouse_headset_andor_other_accessories', 'do_you_have_an_existing_business', 'name_of_business', 'what_industry_is_your_business_in', 'if_you_selected_other_please_explain', 'do_you_have_a_website_for_your_business', 'what_is_your_website_address_url', 'which_if_any_social_media_tools_do_you_use_for_your_business', 'please_enter_any_all_of_your_social_media_handles_separated_by_a_comma_e_g_techgoeshome_facebook_com_yourbusinessname', 'tech_goes_home_tech_goes_home_tech_goes_home_tech_goes_home_tgh', 'i_agree_to_the_learner_agreement_as_listed_above', 'course_id', 'fa_list_learner_enrollment_english_1', 'form_name', 'creation_date', 'modified_date', 'submitted_date', 'completion_time', 'response_text', 'response_html', 'resume_email', 'file_list', 'unprotected_file_list', 'response', 'referrer', 'ip_address']
# ------------------------------------------------------------
# File: translated_haitian_creole.xlsm
# Original Columns:
# ['Course Name', 'Name of Site/School', 'Course Type', 'First Name', 'Last Name', 'What are your pronouns?', 'Have you received a TGH device (Chromebook or iPad) in the last two years?', 'Date of Birth', 'What is your gender?', 'Your gender identity:', 'How would you describe your race/ethnicity?', 'How would you describe your race/ethnicity? (select all that apply)', 'Primary Language', 'If you selected "Other," what language?', 'Home Street Address (including apartment number)', 'City', 'State', 'Zip Code', 'Phone Number', 'Email Address', 'Number of people in Household', 'Educational Status', 'Employment Status', 'Are you self-employed?', 'What is the zip code where you work?', 'Household Income Level', 'Do you receive housing assistance?', 'What other Boston neighbourhoods are you connected to? For example, do you receive services, visit family or friends, go to school or places of worship, in any of the folloYesng neighbourhoods? [Select all that apply]', 'Other_neighboorhood', 'Were you born in the United States?', 'Have you ever spent time in a jail, prison, or juvenile detention centre?', 'How do you describe your sexual orientation? Select all that apply.', "Child's First Name", "Child's Last Name", "What are your child's pronouns?", " Child's Date of Birth", "What is your child's gender?", "Your child's gender identity:", "How would you describe your child's race/ethnicity:", "How would you describe your child's race/ethnicity? (select all that apply)", "Child's Primary Language", "child's other language", 'What is your goal for taking this course?', "Is this the first activity you've participated in at your program site?", 'How many working computers do you have at home?', 'How many tablets do you have at home? (e.g. iPad, Kindle Fire, Samsung Galaxy Tab)', 'Do you have a smartphone? (e.g. iPhone, Google Pixel, Samsung Galaxy)', ' Do you have home internet access (i.e. Yesfi)?', 'Is your internet affordable?', 'Is your internet reliable?', 'Are you aware of the Affordable Connectivity Program (ACP), an FCC (Federal Communications Commission) program to help families and households afford internet service? (More info here: https://www.fcc.gov/acp)', 'Are you currently enrolled in the ACP program?', 'Please describe your confidence level using the internet to find information you need:', 'Creating and Sending emails', 'Opening and replying to emails', 'Downloading attachments I receive in an email (documents or pictures)', 'Adding an attachment to an email I am sending (like documents or pictures)', 'Turning the computer on and off', "Adjusting the computer's settings (like the size of the text or the background picture)", 'Connecting the computer to Yesfi', 'Installing applications from the Chromebook store', 'Saving files to the computer and finding them later', 'Using a mouse, headset, and/or other accessories', 'Turning the tablet on and off', "Adjusting the tablet's settings (like the size of the text or the background picture)", 'Connecting the tablet to Yesfi', 'Installing applications (Apps)', 'Saving files to the tablet and finding them later', 'I am aware of what my skills are to be employed in a good job (e.g., digital skills, specific trade skills, etc.).', 'I am aware of what my resources are to be employed in a good job (e.g., resources for job searching, child care resources, etc.).', 'I am able to utilize my skills to move toward career goals.', 'I am able to utilize my resources to move toward career goals', 'Even if I am not able to achieve my financial goals right away, I Yesll find a way to get there.', 'Because of my money situation, I feel like I Yesll never have the things I want in life.', 'I am just getting by financially.', 'I am concerned that the money I have or Yesll save won‚Äôt last.', 'Do you have an existing business?', 'Name of Business', 'What industry is your business in?', 'If you selected "Other," please explain:', 'Do you have a website for your business?', 'What is your website a ...
# Cleaned Columns:
# ['course_name', 'name_of_siteschool', 'course_type', 'first_name', 'last_name', 'what_are_your_pronouns', 'have_you_received_a_tgh_device_chromebook_or_ipad_in_the_last_two_years', 'date_of_birth', 'what_is_your_gender', 'your_gender_identity', 'how_would_you_describe_your_raceethnicity', 'how_would_you_describe_your_raceethnicity_select_all_that_apply', 'primary_language', 'if_you_selected_other_what_language', 'home_street_address_including_apartment_number', 'city', 'state', 'zip_code', 'phone_number', 'email_address', 'number_of_people_in_household', 'educational_status', 'employment_status', 'are_you_selfemployed', 'what_is_the_zip_code_where_you_work', 'household_income_level', 'do_you_receive_housing_assistance', 'what_other_boston_neighbourhoods_are_you_connected_to_for_example_do_you_receive_services_visit_family_or_friends_go_to_school_or_places_of_worship_in_any_of_the_folloyesng_neighbourhoods_select_all_that_apply', 'other_neighboorhood', 'were_you_born_in_the_united_states', 'have_you_ever_spent_time_in_a_jail_prison_or_juvenile_detention_centre', 'how_do_you_describe_your_sexual_orientation_select_all_that_apply', 'childs_first_name', 'childs_last_name', 'what_are_your_childs_pronouns', 'childs_date_of_birth', 'what_is_your_childs_gender', 'your_childs_gender_identity', 'how_would_you_describe_your_childs_raceethnicity', 'how_would_you_describe_your_childs_raceethnicity_select_all_that_apply', 'childs_primary_language', 'childs_other_language', 'what_is_your_goal_for_taking_this_course', 'is_this_the_first_activity_youve_participated_in_at_your_program_site', 'how_many_working_computers_do_you_have_at_home', 'how_many_tablets_do_you_have_at_home_eg_ipad_kindle_fire_samsung_galaxy_tab', 'do_you_have_a_smartphone_eg_iphone_google_pixel_samsung_galaxy', 'do_you_have_home_internet_access_ie_yesfi', 'is_your_internet_affordable', 'is_your_internet_reliable', 'are_you_aware_of_the_affordable_connectivity_program_acp_an_fcc_federal_communications_commission_program_to_help_families_and_households_afford_internet_service_more_info_here_httpswwwfccgovacp', 'are_you_currently_enrolled_in_the_acp_program', 'please_describe_your_confidence_level_using_the_internet_to_find_information_you_need', 'creating_and_sending_emails', 'opening_and_replying_to_emails', 'downloading_attachments_i_receive_in_an_email_documents_or_pictures', 'adding_an_attachment_to_an_email_i_am_sending_like_documents_or_pictures', 'turning_the_computer_on_and_off', 'adjusting_the_computers_settings_like_the_size_of_the_text_or_the_background_picture', 'connecting_the_computer_to_yesfi', 'installing_applications_from_the_chromebook_store', 'saving_files_to_the_computer_and_finding_them_later', 'using_a_mouse_headset_andor_other_accessories', 'turning_the_tablet_on_and_off', 'adjusting_the_tablets_settings_like_the_size_of_the_text_or_the_background_picture', 'connecting_the_tablet_to_yesfi', 'installing_applications_apps', 'saving_files_to_the_tablet_and_finding_them_later', 'i_am_aware_of_what_my_skills_are_to_be_employed_in_a_good_job_eg_digital_skills_specific_trade_skills_etc', 'i_am_aware_of_what_my_resources_are_to_be_employed_in_a_good_job_eg_resources_for_job_searching_child_care_resources_etc', 'i_am_able_to_utilize_my_skills_to_move_toward_career_goals', 'i_am_able_to_utilize_my_resources_to_move_toward_career_goals', 'even_if_i_am_not_able_to_achieve_my_financial_goals_right_away_i_yesll_find_a_way_to_get_there', 'because_of_my_money_situation_i_feel_like_i_yesll_never_have_the_things_i_want_in_life', 'i_am_just_getting_by_financially', 'i_am_concerned_that_the_money_i_have_or_yesll_save_wonaot_last', 'do_you_have_an_existing_business', 'name_of_business', 'what_industry_is_your_business_in', 'if_you_selected_other_please_explain', 'do_you_have_a_website_for_your_business', 'what_is_your_website_address_url', 'which_if_any_social_media_tools_do_you_use_for_your_business', 'please_enter_anyall_of_your_social_media_handles_separated_by_a_comma_ ...
# ------------------------------------------------------------

# %%
import os
import pandas as pd

# Set the directory containing your CSV and XLSM files
files_path = '/Users/sreeharsha/Documents/TGH Data Management Cleaning/Merge testing/Enrollment Survey'  # <-- Update this path

# Gather all CSV and XLSM file paths
all_files = [os.path.join(files_path, f) for f in os.listdir(files_path)
             if f.endswith('.csv') or f.endswith('.xlsm')]

# Dictionaries to store stats:
# file_columns: maps filename -> list of columns in that file
# column_files: maps column name -> set of filenames where it appears
file_columns = {}
column_files = {}

# Process each file
for file in all_files:
    try:
        if file.endswith('.csv'):
            df = pd.read_csv(file)
        else:
            df = pd.read_excel(file)
        
        # Get list of columns in the current file
        cols = df.columns.tolist()
        filename = os.path.basename(file)
        file_columns[filename] = cols
        
        # Update column_files dictionary
        for col in cols:
            if col not in column_files:
                column_files[col] = set()
            column_files[col].add(filename)
    except Exception as e:
        print(f"Error processing {file}: {e}")

# Calculate frequency of each column (i.e., in how many files each column appears)
column_stats = {col: len(files) for col, files in column_files.items()}

# Sort columns by frequency (highest first)
sorted_columns = sorted(column_stats.items(), key=lambda x: x[1], reverse=True)

# Summary: print out column frequency stats
print("=== Column Frequency Across Files ===")
for col, freq in sorted_columns:
    files_list = ", ".join(sorted(column_files[col]))
    print(f"{col}: present in {freq} file(s) -> {files_list}")

# Summary: show number of fields in each file
print("\n=== Number of Fields per File ===")
for filename, cols in file_columns.items():
    print(f"{filename}: {len(cols)} fields")

# Optionally, create a DataFrame to visualize the stats
stats_df = pd.DataFrame(sorted_columns, columns=['Column', 'FileCount'])
stats_df.head(20)
# Out:
# /var/folders/q6/v__5dqvn4fsgnld9cp_x0v1m0000gn/T/ipykernel_23866/2597319308.py:21: DtypeWarning: Columns (16,27,30,31,32,33,34,35,48,75,76,77,81,99) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file)
# /var/folders/q6/v__5dqvn4fsgnld9cp_x0v1m0000gn/T/ipykernel_23866/2597319308.py:21: DtypeWarning: Columns (14,17,18,31,34,36,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file)
# === Column Frequency Across Files ===
# Submitted Date: present in 5 file(s) -> (OLD) TGH Learner Enrollment Form (6.2.2022).csv, (OLD)+TGH+Learner+Enrollment+Form+2025-03-06-11-24-39+457499.csv.csv, Learner+Enrollment+ENGLISH.csv, translated_haitian_creole.xlsm, translated_spanish.xlsm
# Course Name: present in 5 file(s) -> (OLD) TGH Learner Enrollment Form (6.2.2022).csv, (OLD)+TGH+Learner+Enrollment+Form+2025-03-06-11-24-39+457499.csv.csv, Learner+Enrollment+ENGLISH.csv, translated_haitian_creole.xlsm, translated_spanish.xlsm
# Name of Site/School: present in 5 file(s) -> (OLD) TGH Learner Enrollment Form (6.2.2022).csv, (OLD)+TGH+Learner+Enrollment+Form+2025-03-06-11-24-39+457499.csv.csv, Learner+Enrollment+ENGLISH.csv, translated_haitian_creole.xlsm, translated_spanish.xlsm
# Course Type: present in 5 file(s) -> (OLD) TGH Learner Enrollment Form (6.2.2022).csv, (OLD)+TGH+Learner+Enrollment+Form+2025-03-06-11-24-39+457499.csv.csv, Learner+Enrollment+ENGLISH.csv, translated_haitian_creole.xlsm, translated_spanish.xlsm
# First Name: present in 5 file(s) -> (OLD) TGH Learner Enrollment Form (6.2.2022).csv, (OLD)+TGH+Learner+Enrollment+Form+2025-03-06-11-24-39+457499.csv.csv, Learner+Enrollment+ENGLISH.csv, translated_haitian_creole.xlsm, translated_spanish.xlsm
# Last Name: present in 5 file(s) -> (OLD) TGH Learner Enrollment Form (6.2.2022).csv, (OLD)+TGH+Learner+Enrollment+Form+2025-03-06-11-24-39+457499.csv.csv, Learner+Enrollment+ENGLISH.csv, translated_haitian_creole.xlsm, translated_spanish.xlsm
# Have you received a TGH device (Chromebook or iPad) in the last two years?: present in 5 file(s) -> (OLD) TGH Learner Enrollment Form (6.2.2022).csv, (OLD)+TGH+Learner+Enrollment+Form+2025-03-06-11-24-39+457499.csv.csv, Learner+Enrollment+ENGLISH.csv, translated_haitian_creole.xlsm, translated_spanish.xlsm
# Date of Birth: present in 5 file(s) -> (OLD) TGH Learner Enrollment Form (6.2.2022).csv, (OLD)+TGH+Learner+Enrollment+Form+2025-03-06-11-24-39+457499.csv.csv, Learner+Enrollment+ENGLISH.csv, translated_haitian_creole.xlsm, translated_spanish.xlsm
# Primary Language: present in 5 file(s) -> (OLD) TGH Learner Enrollment Form (6.2.2022).csv, (OLD)+TGH+Learner+Enrollment+Form+2025-03-06-11-24-39+457499.csv.csv, Learner+Enrollment+ENGLISH.csv, translated_haitian_creole.xlsm, translated_spanish.xlsm
# Home Street Address (including apartment number): present in 5 file(s) -> (OLD) TGH Learner Enrollment Form (6.2.2022).csv, (OLD)+TGH+Learner+Enrollment+Form+2025-03-06-11-24-39+457499.csv.csv, Learner+Enrollment+ENGLISH.csv, translated_haitian_creole.xlsm, translated_spanish.xlsm
# City: present in 5 file(s) -> (OLD) TGH Learner Enrollment Form (6.2.2022).csv, (OLD)+TGH+Learner+Enrollment+Form+2025-03-06-11-24-39+457499.csv.csv, Learner+Enrollment+ENGLISH.csv, translated_haitian_creole.xlsm, translated_spanish.xlsm
# State: present in 5 file(s) -> (OLD) TGH Learner Enrollment Form (6.2.2022).csv, (OLD)+TGH+Learner+Enrollment+Form+2025-03-06-11-24-39+457499.csv.csv, Learner+Enrollment+ENGLISH.csv, translated_haitian_creole.xlsm, translated_spanish.xlsm
# Phone Number: present in 5 file(s) -> (OLD) TGH Learner Enrollment Form (6.2.2022).csv, (OLD)+TGH+Learner+Enrollment+Form+2025-03-06-11-24-39+457499.csv.csv, Learner+Enrollment+ENGLISH.csv, translated_haitian_creole.xlsm, translated_spanish.xlsm
# Email Address: present in 5 file(s) -> (OLD) TGH Learner Enrollment Form (6.2.2022).csv, (OLD)+TGH+Learner+Enrollment+Form+2025-03-06-11-24-39+457499.csv.csv, Learner+Enrollment+ENGLISH.csv, translated_haitian_creole.xlsm, translated_spanish.xlsm
# Employment Status: present in 5 file(s) -> (OLD) TGH Learner Enrollment Form (6.2.2022).csv, (OLD)+TGH+Learner+Enrollment+Form+2025-03-06-11-24-39+457499.csv.csv, Learner+Enrollment+ENGLISH.csv, translated_haitian_creole.xlsm, translated_spanish.xlsm
# Household Income Level: present in 5 file(s) -> (OLD) TGH Learner Enrollment Form (6.2.2022).csv, (OLD)+TGH+Learner+Enrollment+Form+2025-03-06-11-24-39+457499.csv.csv, Learner+Enrollment+ENGLISH.csv, translated_haitian_creole.xlsm, translated_spanish.xlsm
# Do you receive housing assistance?: present in 5 file(s) -> (OLD) TGH Learner Enrollment Form (6.2.2022).csv, (OLD)+TGH+Learner+Enrollment+Form+2025-03-06-11-24-39+457499.csv.csv, Learner+Enrollment+ENGLISH.csv, translated_haitian_creole.xlsm, translated_spanish.xlsm
# Child's First Name: present in 5 file(s) -> (OLD) TGH Learner Enrollment Form (6.2.2022).csv, (OLD)+TGH+Learner+Enrollment+Form+2025-03-06-11-24-39+457499.csv.csv, Learner+Enrollment+ENGLISH.csv, translated_haitian_creole.xlsm, translated_spanish.xlsm
# Child's Last Name: present in 5 file(s) -> (OLD) TGH Learner Enrollment Form (6.2.2022).csv, (OLD)+TGH+Learner+Enrollment+Form+2025-03-06-11-24-39+457499.csv.csv, Learner+Enrollment+ENGLISH.csv, translated_haitian_creole.xlsm, translated_spanish.xlsm
# Child's Primary Language: present in 5 file(s) -> (OLD) TGH Learner Enrollment Form (6.2.2022).csv, (OLD)+TGH+Learner+Enrollment+Form+2025-03-06-11-24-39+457499.csv.csv, Learner+Enrollment+ENGLISH.csv, translated_haitian_creole.xlsm, translated_spanish.xlsm
# Do you have an existing business?: present in 5 file(s) -> (OLD) TGH Learner Enrollment Form (6.2.2022).csv, (OLD)+TGH+Learner+Enrollment+Form+2025-03-06-11-24-39+457499.csv.csv, Learner+Enrollment+ENGLISH.csv, translated_haitian_creole.xlsm, translated_spanish.xlsm
# Name of Business: present in 5 file(s) -> (OLD) TGH Learner Enrollment Form (6.2.2022).csv, (OLD)+TGH+Learner+Enrollment+Form+2025-03-06-11-24-39+457499.csv.csv, Learner+Enrollment+ENGLISH.csv, translated_haitian_creole.xlsm, translated_spanish.xlsm
# What industry is your business in?: present in 5 file(s) -> (OLD) TGH Learner Enrollment Form (6.2.2022).csv, (OLD)+TGH+Learner+Enrollment+Form+2025-03-06-11-24-39+457499.csv.csv, Learner+Enrollment+ENGLISH.csv, translated_haitian_creole.xlsm, translated_spanish.xlsm
# Do you have a website for your business?: present in 5 file(s) -> (OLD) TGH Learner Enrollment Form (6.2.2022).csv, (OLD)+TGH+Learner+Enrollment+Form+2025-03-06-11-24-39+457499.csv.csv, Learner+Enrollment+ENGLISH.csv, translated_haitian_creole.xlsm, translated_spanish.xlsm
# Which, if any, social media tools do you use for your business?: present in 5 file(s) -> (OLD) TGH Learner Enrollment Form (6.2.2022).csv, (OLD)+TGH+Learner+Enrollment+Form+2025-03-06-11-24-39+457499.csv.csv, Learner+Enrollment+ENGLISH.csv, translated_haitian_creole.xlsm, translated_spanish.xlsm
# I agree to the Learner Agreement as listed above: present in 5 file(s) -> (OLD) TGH Learner Enrollment Form (6.2.2022).csv, (OLD)+TGH+Learner+Enrollment+Form+2025-03-06-11-24-39+457499.csv.csv, Learner+Enrollment+ENGLISH.csv, translated_haitian_creole.xlsm, translated_spanish.xlsm
# Course ID: present in 5 file(s) -> (OLD) TGH Learner Enrollment Form (6.2.2022).csv, (OLD)+TGH+Learner+Enrollment+Form+2025-03-06-11-24-39+457499.csv.csv, Learner+Enrollment+ENGLISH.csv, translated_haitian_creole.xlsm, translated_spanish.xlsm
# Form Name: present in 5 file(s) -> (OLD) TGH Learner Enrollment Form (6.2.2022).csv, (OLD)+TGH+Learner+Enrollment+Form+2025-03-06-11-24-39+457499.csv.csv, Learner+Enrollment+ENGLISH.csv, translated_haitian_creole.xlsm, translated_spanish.xlsm
# Creation Date: present in 5 file(s) -> (OLD) TGH Learner Enrollment Form (6.2.2022).csv, (OLD)+TGH+Learner+Enrollment+Form+2025-03-06-11-24-39+457499.csv.csv, Learner+Enrollment+ENGLISH.csv, translated_haitian_creole.xlsm, translated_spanish.xlsm
# Modified Date: present in 5 file(s) -> (OLD) TGH Learner Enrollment Form (6.2.2022).csv, (OLD)+TGH+Learner+Enrollment+Form+2025-03-06-11-24-39+457499.csv.csv, Learner+Enrollment+ENGLISH.csv, translated_haitian_creole.xlsm, translated_spanish.xlsm
# Completion Time: present in 5 file(s) -> (OLD) TGH Learner Enrollment Form (6.2.2022).csv, (OLD)+TGH+Learner+Enrollment+Form+2025-03-06-11-24-39+457499.csv.csv, Learner+Enrollment+ENGLISH.csv, translated_haitian_creole.xlsm, translated_spanish.xlsm
# Response Html Beta: present in 5 file(s) -> (OLD) TGH Learner Enrollment Form (6.2.2022).csv, (OLD)+TGH+Learner+Enrollment+Form+2025-03-06-11-24-39+457499.csv.csv, Learner+Enrollment+ENGLISH.csv, translated_haitian_creole.xlsm, translated_spanish.xlsm
# Response Html: present in 5 file(s) -> (OLD) TGH Learner Enrollment Form (6.2.2022).csv, (OLD)+TGH+Learner+Enrollment+Form+2025-03-06-11-24-39+457499.csv.csv, Learner+Enrollment+ENGLISH.csv, translated_haitian_creole.xlsm, translated_spanish.xlsm
# Response Text: present in 5 file(s) -> (OLD) TGH Learner Enrollment Form (6.2.2022).csv, (OLD)+TGH+Learner+Enrollment+Form+2025-03-06-11-24-39+457499.csv.csv, Learner+Enrollment+ENGLISH.csv, translated_haitian_creole.xlsm, translated_spanish.xlsm
# Response: present in 5 file(s) -> (OLD) TGH Learner Enrollment Form (6.2.2022).csv, (OLD)+TGH+Learner+Enrollment+Form+2025-03-06-11-24-39+457499.csv.csv, Learner+Enrollment+ENGLISH.csv, translated_haitian_creole.xlsm, translated_spanish.xlsm
# Response Url: present in 5 file(s) -> (OLD) TGH Learner Enrollment Form (6.2.2022).csv, (OLD)+TGH+Learner+Enrollment+Form+2025-03-06-11-24-39+457499.csv.csv, Learner+Enrollment+ENGLISH.csv, translated_haitian_creole.xlsm, translated_spanish.xlsm
# Resume Email: present in 5 file(s) -> (OLD) TGH Learner Enrollment Form (6.2.2022).csv, (OLD)+TGH+Learner+Enrollment+Form+2025-03-06-11-24-39+457499.csv.csv, Learner+Enrollment+ENGLISH.csv, translated_haitian_creole.xlsm, translated_spanish.xlsm
# File List: present in 5 file(s) -> (OLD) TGH Learner Enrollment Form (6.2.2022).csv, (OLD)+TGH+Learner+Enrollment+Form+2025-03-06-11-24-39+457499.csv.csv, Learner+Enrollment+ENGLISH.csv, translated_haitian_creole.xlsm, translated_spanish.xlsm
# Unprotected File List: present in 5 file(s) -> (OLD) TGH Learner Enrollment Form (6.2.2022).csv, (OLD)+TGH+Learner+Enrollment+Form+2025-03-06-11-24-39+457499.csv.csv, Learner+Enrollment+ENGLISH.csv, translated_haitian_creole.xlsm, translated_spanish.xlsm
# Response Id: present in 5 file(s) -> (OLD) TGH Learner Enrollment Form (6.2.2022).csv, (OLD)+TGH+Learner+Enrollment+Form+2025-03-06-11-24-39+457499.csv.csv, Learner+Enrollment+ENGLISH.csv, translated_haitian_creole.xlsm, translated_spanish.xlsm
# Referrer: present in 5 file(s) -> (OLD) TGH Learner Enrollment Form (6.2.2022).csv, (OLD)+TGH+Learner+Enrollment+Form+2025-03-06-11-24-39+457499.csv.csv, Learner+Enrollment+ENGLISH.csv, translated_haitian_creole.xlsm, translated_spanish.xlsm
# Ip Address: present in 5 file(s) -> (OLD) TGH Learner Enrollment Form (6.2.2022).csv, (OLD)+TGH+Learner+Enrollment+Form+2025-03-06-11-24-39+457499.csv.csv, Learner+Enrollment+ENGLISH.csv, translated_haitian_creole.xlsm, translated_spanish.xlsm
# Zip Code: present in 4 file(s) -> (OLD) TGH Learner Enrollment Form (6.2.2022).csv, Learner+Enrollment+ENGLISH.csv, translated_haitian_creole.xlsm, translated_spanish.xlsm
# Number of people in Household: present in 4 file(s) -> (OLD) TGH Learner Enrollment Form (6.2.2022).csv, Learner+Enrollment+ENGLISH.csv, translated_haitian_creole.xlsm, translated_spanish.xlsm
# Educational Status: present in 4 file(s) -> (OLD) TGH Learner Enrollment Form (6.2.2022).csv, (OLD)+TGH+Learner+Enrollment+Form+2025-03-06-11-24-39+457499.csv.csv, Learner+Enrollment+ENGLISH.csv, translated_haitian_creole.xlsm
# Child's Date of Birth: present in 4 file(s) -> (OLD) TGH Learner Enrollment Form (6.2.2022).csv, (OLD)+TGH+Learner+Enrollment+Form+2025-03-06-11-24-39+457499.csv.csv, Learner+Enrollment+ENGLISH.csv, translated_spanish.xlsm
# What is your goal for taking this course?: present in 4 file(s) -> (OLD) TGH Learner Enrollment Form (6.2.2022).csv, Learner+Enrollment+ENGLISH.csv, translated_haitian_creole.xlsm, translated_spanish.xlsm
# Is this the first activity you've participated in at your program site?: present in 4 file(s) -> (OLD) TGH Learner Enrollment Form (6.2.2022).csv, Learner+Enrollment+ENGLISH.csv, translated_haitian_creole.xlsm, translated_spanish.xlsm
# How many working computers do you have at home?: present in 4 file(s) -> (OLD) TGH Learner Enrollment Form (6.2.2022).csv, Learner+Enrollment+ENGLISH.csv, translated_haitian_creole.xlsm, translated_spanish.xlsm
# How many tablets do you have at home? (e.g. iPad, Kindle Fire, Samsung Galaxy Tab): present in 4 file(s) -> (OLD) TGH Learner Enrollment Form (6.2.2022).csv, Learner+Enrollment+ENGLISH.csv, translated_haitian_creole.xlsm, translated_spanish.xlsm
# Are you aware of the Affordable Connectivity Program (ACP), an FCC (Federal Communications Commission) program to help families and households afford internet service? (More info here: https://www.fcc.gov/acp): present in 4 file(s) -> (OLD) TGH Learner Enrollment Form (6.2.2022).csv, Learner+Enrollment+ENGLISH.csv, translated_haitian_creole.xlsm, translated_spanish.xlsm
# Please describe your confidence level using the internet to find information you need:: present in 4 file(s) -> (OLD) TGH Learner Enrollment Form (6.2.2022).csv, Learner+Enrollment+ENGLISH.csv, translated_haitian_creole.xlsm, translated_spanish.xlsm
# Opening and replying to emails: present in 4 file(s) -> (OLD) TGH Learner Enrollment Form (6.2.2022).csv, Learner+Enrollment+ENGLISH.csv, translated_haitian_creole.xlsm, translated_spanish.xlsm
# Downloading attachments I receive in an email (documents or pictures): present in 4 file(s) -> (OLD) TGH Learner Enrollment Form (6.2.2022).csv, Learner+Enrollment+ENGLISH.csv, translated_haitian_creole.xlsm, translated_spanish.xlsm
# Adding an attachment to an email I am sending (like documents or pictures): present in 4 file(s) -> (OLD) TGH Learner Enrollment Form (6.2.2022).csv, Learner+Enrollment+ENGLISH.csv, translated_haitian_creole.xlsm, translated_spanish.xlsm
# Adjusting the computer's settings (like the size of the text or the background picture): present in 4 file(s) -> (OLD) TGH Learner Enrollment Form (6.2.2022).csv, Learner+Enrollment+ENGLISH.csv, translated_haitian_creole.xlsm, translated_spanish.xlsm
# Installing applications from the Chromebook store: present in 4 file(s) -> (OLD) TGH Learner Enrollment Form (6.2.2022).csv, Learner+Enrollment+ENGLISH.csv, translated_haitian_creole.xlsm, translated_spanish.xlsm
# Saving files to the computer and finding them later: present in 4 file(s) -> (OLD) TGH Learner Enrollment Form (6.2.2022).csv, Learner+Enrollment+ENGLISH.csv, translated_haitian_creole.xlsm, translated_spanish.xlsm
# Turning the tablet on and off: present in 4 file(s) -> (OLD) TGH Learner Enrollment Form (6.2.2022).csv, Learner+Enrollment+ENGLISH.csv, translated_haitian_creole.xlsm, translated_spanish.xlsm
# Adjusting the tablet's settings (like the size of the text or the background picture): present in 4 file(s) -> (OLD) TGH Learner Enrollment Form (6.2.2022).csv, Learner+Enrollment+ENGLISH.csv, translated_haitian_creole.xlsm, translated_spanish.xlsm
# Installing applications (Apps): present in 4 file(s) -> (OLD) TGH Learner Enrollment Form (6.2.2022).csv, Learner+Enrollment+ENGLISH.csv, translated_haitian_creole.xlsm, translated_spanish.xlsm
# Saving files to the tablet and finding them later: present in 4 file(s) -> (OLD) TGH Learner Enrollment Form (6.2.2022).csv, Learner+Enrollment+ENGLISH.csv, translated_haitian_creole.xlsm, translated_spanish.xlsm
# What is your website address (URL)?: present in 4 file(s) -> (OLD) TGH Learner Enrollment Form (6.2.2022).csv, Learner+Enrollment+ENGLISH.csv, translated_haitian_creole.xlsm, translated_spanish.xlsm
# Do you have home internet access (i.e. wifi)?: present in 3 file(s) -> (OLD) TGH Learner Enrollment Form (6.2.2022).csv, Learner+Enrollment+ENGLISH.csv, translated_spanish.xlsm
# What are your pronouns?: present in 3 file(s) -> Learner+Enrollment+ENGLISH.csv, translated_haitian_creole.xlsm, translated_spanish.xlsm
# What is your gender?: present in 3 file(s) -> Learner+Enrollment+ENGLISH.csv, translated_haitian_creole.xlsm, translated_spanish.xlsm
# Your gender identity:: present in 3 file(s) -> (OLD) TGH Learner Enrollment Form (6.2.2022).csv, Learner+Enrollment+ENGLISH.csv, translated_haitian_creole.xlsm
# How would you describe your race/ethnicity? (select all that apply): present in 3 file(s) -> Learner+Enrollment+ENGLISH.csv, translated_haitian_creole.xlsm, translated_spanish.xlsm
# Are you self-employed?: present in 3 file(s) -> Learner+Enrollment+ENGLISH.csv, translated_haitian_creole.xlsm, translated_spanish.xlsm
# Were you born in the United States?: present in 3 file(s) -> Learner+Enrollment+ENGLISH.csv, translated_haitian_creole.xlsm, translated_spanish.xlsm
# What are your child's pronouns?: present in 3 file(s) -> Learner+Enrollment+ENGLISH.csv, translated_haitian_creole.xlsm, translated_spanish.xlsm
# What is your child's gender?: present in 3 file(s) -> Learner+Enrollment+ENGLISH.csv, translated_haitian_creole.xlsm, translated_spanish.xlsm
# Your child's gender identity:: present in 3 file(s) -> (OLD) TGH Learner Enrollment Form (6.2.2022).csv, Learner+Enrollment+ENGLISH.csv, translated_haitian_creole.xlsm
# How would you describe your child's race/ethnicity? (select all that apply): present in 3 file(s) -> Learner+Enrollment+ENGLISH.csv, translated_haitian_creole.xlsm, translated_spanish.xlsm
# Do you have a smartphone? (e.g. iPhone, Google Pixel, Samsung Galaxy): present in 3 file(s) -> (OLD) TGH Learner Enrollment Form (6.2.2022).csv, Learner+Enrollment+ENGLISH.csv, translated_haitian_creole.xlsm
# Is your internet affordable?: present in 3 file(s) -> Learner+Enrollment+ENGLISH.csv, translated_haitian_creole.xlsm, translated_spanish.xlsm
# Is your internet reliable?: present in 3 file(s) -> Learner+Enrollment+ENGLISH.csv, translated_haitian_creole.xlsm, translated_spanish.xlsm
# Are you currently enrolled in the ACP program?: present in 3 file(s) -> Learner+Enrollment+ENGLISH.csv, translated_haitian_creole.xlsm, translated_spanish.xlsm
# Turning the computer on and off: present in 3 file(s) -> Learner+Enrollment+ENGLISH.csv, translated_haitian_creole.xlsm, translated_spanish.xlsm
# Connecting the computer to wifi: present in 3 file(s) -> (OLD) TGH Learner Enrollment Form (6.2.2022).csv, Learner+Enrollment+ENGLISH.csv, translated_spanish.xlsm
# Using a mouse, headset, and/or other accessories: present in 3 file(s) -> Learner+Enrollment+ENGLISH.csv, translated_haitian_creole.xlsm, translated_spanish.xlsm
# Connecting the tablet to wifi: present in 3 file(s) -> (OLD) TGH Learner Enrollment Form (6.2.2022).csv, Learner+Enrollment+ENGLISH.csv, translated_spanish.xlsm
# I am aware of what my resources are to be employed in a good job (e.g., resources for job searching, child care resources, etc.).: present in 3 file(s) -> Learner+Enrollment+ENGLISH.csv, translated_haitian_creole.xlsm, translated_spanish.xlsm
# I am able to utilize my skills to move toward career goals.: present in 3 file(s) -> Learner+Enrollment+ENGLISH.csv, translated_haitian_creole.xlsm, translated_spanish.xlsm
# I am just getting by financially.: present in 3 file(s) -> Learner+Enrollment+ENGLISH.csv, translated_haitian_creole.xlsm, translated_spanish.xlsm
# If you selected "Other," please explain:: present in 3 file(s) -> Learner+Enrollment+ENGLISH.csv, translated_haitian_creole.xlsm, translated_spanish.xlsm
# Please enter any/all of your social media handles separated by a comma(,) (e.g. @techgoeshome, facebook.com/yourbusinessname): present in 3 file(s) -> (OLD) TGH Learner Enrollment Form (6.2.2022).csv, Learner+Enrollment+ENGLISH.csv, translated_haitian_creole.xlsm
# If you selected "Other", what language?: present in 3 file(s) -> (OLD) TGH Learner Enrollment Form (6.2.2022).csv, (OLD)+TGH+Learner+Enrollment+Form+2025-03-06-11-24-39+457499.csv.csv, translated_spanish.xlsm
# other_language: present in 2 file(s) -> (OLD)+TGH+Learner+Enrollment+Form+2025-03-06-11-24-39+457499.csv.csv, Learner+Enrollment+ENGLISH.csv
# What other Boston neighborhoods are you connected to? For example, do you receive services, visit family or friends, go to school or places of worship, in any of the following neighborhoods? [Select all that apply]: present in 2 file(s) -> Learner+Enrollment+ENGLISH.csv, translated_spanish.xlsm
# Creating and sending emails: present in 2 file(s) -> (OLD) TGH Learner Enrollment Form (6.2.2022).csv, Learner+Enrollment+ENGLISH.csv
# Even if I am not able to achieve my financial goals right away, I will find a way to get there.: present in 2 file(s) -> Learner+Enrollment+ENGLISH.csv, translated_spanish.xlsm
# How would you describe your race/ethnicity?: present in 2 file(s) -> translated_haitian_creole.xlsm, translated_spanish.xlsm
# If you selected "Other," what language?: present in 2 file(s) -> translated_haitian_creole.xlsm, translated_spanish.xlsm
# Have you ever spent time in a jail, prison, or juvenile detention centre?: present in 2 file(s) -> translated_haitian_creole.xlsm, translated_spanish.xlsm
# How do you describe your sexual orientation? Select all that apply.: present in 2 file(s) -> translated_haitian_creole.xlsm, translated_spanish.xlsm
# Creating and Sending emails: present in 2 file(s) -> translated_haitian_creole.xlsm, translated_spanish.xlsm
# I am able to utilize my resources to move toward career goals: present in 2 file(s) -> translated_haitian_creole.xlsm, translated_spanish.xlsm
# To which gender identity do you most identify?: present in 2 file(s) -> (OLD) TGH Learner Enrollment Form (6.2.2022).csv, (OLD)+TGH+Learner+Enrollment+Form+2025-03-06-11-24-39+457499.csv.csv
# Race/Ethnicity: present in 2 file(s) -> (OLD) TGH Learner Enrollment Form (6.2.2022).csv, (OLD)+TGH+Learner+Enrollment+Form+2025-03-06-11-24-39+457499.csv.csv
# Child's Gender: present in 2 file(s) -> (OLD) TGH Learner Enrollment Form (6.2.2022).csv, (OLD)+TGH+Learner+Enrollment+Form+2025-03-06-11-24-39+457499.csv.csv
# Child's Race/Ethnicity: present in 2 file(s) -> (OLD) TGH Learner Enrollment Form (6.2.2022).csv, (OLD)+TGH+Learner+Enrollment+Form+2025-03-06-11-24-39+457499.csv.csv
# If you selected "Other", please explain:: present in 2 file(s) -> (OLD) TGH Learner Enrollment Form (6.2.2022).csv, (OLD)+TGH+Learner+Enrollment+Form+2025-03-06-11-24-39+457499.csv.csv
# 8. How would you describe your race/ethnicity?: present in 1 file(s) -> Learner+Enrollment+ENGLISH.csv
# Are you a veteran?: present in 1 file(s) -> Learner+Enrollment+ENGLISH.csv
# What is the Zip Code where you work?: present in 1 file(s) -> Learner+Enrollment+ENGLISH.csv
# other_neighborhoods: present in 1 file(s) -> Learner+Enrollment+ENGLISH.csv
# Have you ever spent time in a jail, prison, or juvenile detention center?: present in 1 file(s) -> Learner+Enrollment+ENGLISH.csv
# How do you describe your sexual orientation?: present in 1 file(s) -> Learner+Enrollment+ENGLISH.csv
# other_sexual_orientation: present in 1 file(s) -> Learner+Enrollment+ENGLISH.csv
# other_child_language?: present in 1 file(s) -> Learner+Enrollment+ENGLISH.csv
# I am aware of what my skills are to be employed in a goodjob (e.g., digital skills, specific trade skills, etc.).: present in 1 file(s) -> Learner+Enrollment+ENGLISH.csv
# I am able to utilize my resources to move toward career goals.: present in 1 file(s) -> Learner+Enrollment+ENGLISH.csv
# Because of my money situation, I feel like I will never have thethings I want in life.: present in 1 file(s) -> Learner+Enrollment+ENGLISH.csv
# I am concerned that the money I have or will save won’t last.: present in 1 file(s) -> Learner+Enrollment+ENGLISH.csv
# I consent to the use of quotes, and the taking of photos, movies, or videos of my child and me in the Tech Goes Home program. I grant Tech Goes Home the right to edit, use, and reuse said products for nonprofit purposes, including use in print, on the internet, and all other forms of media. I understand that my agreement to these terms is voluntary, and I will receive no financial compensation. I also hereby release Tech Goes Home and its agents and employees from all claims, demands, and liabilities whatsoever in connection with the above. If you do not wish for your photo to be used by Tech Goes Home, please let your TGH instructors know so they will not send us pictures of you.: present in 1 file(s) -> Learner+Enrollment+ENGLISH.csv
# FA List: Learner Enrollment ENGLISH (1.1.23): present in 1 file(s) -> Learner+Enrollment+ENGLISH.csv
# Your gender identity: present in 1 file(s) -> translated_spanish.xlsm
#  Educational Status: present in 1 file(s) -> translated_spanish.xlsm
# What is the zip code of your workplace?: present in 1 file(s) -> translated_spanish.xlsm
# Other: present in 1 file(s) -> translated_spanish.xlsm
# Your child's gender identity: present in 1 file(s) -> translated_spanish.xlsm
# How would you describe your child's race/ethnicity: present in 1 file(s) -> translated_spanish.xlsm
# Do you have a smartphone?: present in 1 file(s) -> translated_spanish.xlsm
# Please enter any/all of your social media handles separated by a comma: present in 1 file(s) -> translated_spanish.xlsm
# Acepto que usen citas, tomen fotos y graben pel√≠culas o videos m√≠os o de mis hijos en el programa de Tech Goes Home. Concedo a Tech Goes Home el derecho de editar, usar y reutilizar los productos mencionados sin √°nimo de lucro, incluido el uso impreso, en Internet y en cualquier formato multimedia. Acepto estos t√©rminos de forma voluntaria y entiendo que no recibir√© ninguna compensaci√≥n financiera. Por el presente documento, libero a Tech Goes Home y sus agentes y empleados de cualquier reclamaci√≥n, demanda y responsabilidad en el marco de lo anterior. Si no desea que Tech Goes Home use su foto, ind√≠quelo a sus instructores de TGH para que no nos env√≠en fotograf√≠as suyas.: present in 1 file(s) -> translated_spanish.xlsm
# I am aware of what my skills are to achieve a good employment (e.g. digital knowledge, job-specific skills, etc.).: present in 1 file(s) -> translated_spanish.xlsm
# Due to my financial situation, I feel that I will never have the things I want in life.: present in 1 file(s) -> translated_spanish.xlsm
# I am concerned that the money I have or will save won‚Äôt last.: present in 1 file(s) -> translated_spanish.xlsm
# FA List: Learner Enrollment SPANISH (3.8.23): present in 1 file(s) -> translated_spanish.xlsm
# Your Race/Ethnicity: present in 1 file(s) -> (OLD) TGH Learner Enrollment Form (6.2.2022).csv
# other_primary_language: present in 1 file(s) -> (OLD) TGH Learner Enrollment Form (6.2.2022).csv
# Your child's Race/Ethnicity:: present in 1 file(s) -> (OLD) TGH Learner Enrollment Form (6.2.2022).csv
# Are you currently enrolled in the ACP Program?: present in 1 file(s) -> (OLD) TGH Learner Enrollment Form (6.2.2022).csv
# Turning the Computer on and off: present in 1 file(s) -> (OLD) TGH Learner Enrollment Form (6.2.2022).csv
# Using a mouse, headset and/or other accessories: present in 1 file(s) -> (OLD) TGH Learner Enrollment Form (6.2.2022).csv
# I hereby give the unqualified right to the TGH program to take pictures and/ or video of me while participating in my course. I give permission for these images as well as materials that we have created in the TGH program to be used in print and web-based publications. The TGH program will put these images to legitimate use without limitation or reservation. If you do not wish for your photo to be used by TGH, please let your TGH instructors know so they will not send us pictures of you.: present in 1 file(s) -> (OLD) TGH Learner Enrollment Form (6.2.2022).csv
# Middle Initial: present in 1 file(s) -> (OLD)+TGH+Learner+Enrollment+Form+2025-03-06-11-24-39+457499.csv.csv
# Do you have school age children in your household?: present in 1 file(s) -> (OLD)+TGH+Learner+Enrollment+Form+2025-03-06-11-24-39+457499.csv.csv
# Is this your first activity/program at the school or site where you are taking TGH?: present in 1 file(s) -> (OLD)+TGH+Learner+Enrollment+Form+2025-03-06-11-24-39+457499.csv.csv
# If you selected "Other", please specify:: present in 1 file(s) -> (OLD)+TGH+Learner+Enrollment+Form+2025-03-06-11-24-39+457499.csv.csv
# other_race/ethnicity: present in 1 file(s) -> (OLD)+TGH+Learner+Enrollment+Form+2025-03-06-11-24-39+457499.csv.csv
# Zip: present in 1 file(s) -> (OLD)+TGH+Learner+Enrollment+Form+2025-03-06-11-24-39+457499.csv.csv
# Number of Members in Household: present in 1 file(s) -> (OLD)+TGH+Learner+Enrollment+Form+2025-03-06-11-24-39+457499.csv.csv
# Occupation: present in 1 file(s) -> (OLD)+TGH+Learner+Enrollment+Form+2025-03-06-11-24-39+457499.csv.csv
# Place of Work: present in 1 file(s) -> (OLD)+TGH+Learner+Enrollment+Form+2025-03-06-11-24-39+457499.csv.csv
# Child's Grade: present in 1 file(s) -> (OLD)+TGH+Learner+Enrollment+Form+2025-03-06-11-24-39+457499.csv.csv
# If you selected Other, please specify:: present in 1 file(s) -> (OLD)+TGH+Learner+Enrollment+Form+2025-03-06-11-24-39+457499.csv.csv
# If you selected "Other", what race/ethnicity?: present in 1 file(s) -> (OLD)+TGH+Learner+Enrollment+Form+2025-03-06-11-24-39+457499.csv.csv
# What is the main reason you decided to participate in TGH?: present in 1 file(s) -> (OLD)+TGH+Learner+Enrollment+Form+2025-03-06-11-24-39+457499.csv.csv
# Which devices do you use at home?: present in 1 file(s) -> (OLD)+TGH+Learner+Enrollment+Form+2025-03-06-11-24-39+457499.csv.csv
# If you selected "Other", what type of device?: present in 1 file(s) -> (OLD)+TGH+Learner+Enrollment+Form+2025-03-06-11-24-39+457499.csv.csv
# Number of Working Computers at Home: present in 1 file(s) -> (OLD)+TGH+Learner+Enrollment+Form+2025-03-06-11-24-39+457499.csv.csv
# Do you have home Internet access (i.e. wifi)?: present in 1 file(s) -> (OLD)+TGH+Learner+Enrollment+Form+2025-03-06-11-24-39+457499.csv.csv
# How do you (or anyone living in your household) access the Internet in your home?: present in 1 file(s) -> (OLD)+TGH+Learner+Enrollment+Form+2025-03-06-11-24-39+457499.csv.csv
# If you selected "Other", what type?: present in 1 file(s) -> (OLD)+TGH+Learner+Enrollment+Form+2025-03-06-11-24-39+457499.csv.csv
# Which devices do you (or anyone living in your household) use to access the Internet in your home?: present in 1 file(s) -> (OLD)+TGH+Learner+Enrollment+Form+2025-03-06-11-24-39+457499.csv.csv
# Is your Internet access through a discounted program? (Eg. Internet Essentials, PCs for People): present in 1 file(s) -> (OLD)+TGH+Learner+Enrollment+Form+2025-03-06-11-24-39+457499.csv.csv
# How satisfied are you with your Internet service at home?: present in 1 file(s) -> (OLD)+TGH+Learner+Enrollment+Form+2025-03-06-11-24-39+457499.csv.csv
# Why don't you have Internet access at home?: present in 1 file(s) -> (OLD)+TGH+Learner+Enrollment+Form+2025-03-06-11-24-39+457499.csv.csv
# other_internet_cause: present in 1 file(s) -> (OLD)+TGH+Learner+Enrollment+Form+2025-03-06-11-24-39+457499.csv.csv
# Have you ever had to change or cancel your Internet subscription because it is too expensive?: present in 1 file(s) -> (OLD)+TGH+Learner+Enrollment+Form+2025-03-06-11-24-39+457499.csv.csv
# What do you and other household members use the Internet for?: present in 1 file(s) -> (OLD)+TGH+Learner+Enrollment+Form+2025-03-06-11-24-39+457499.csv.csv
# What financial resources do you use?: present in 1 file(s) -> (OLD)+TGH+Learner+Enrollment+Form+2025-03-06-11-24-39+457499.csv.csv
# financial_other: present in 1 file(s) -> (OLD)+TGH+Learner+Enrollment+Form+2025-03-06-11-24-39+457499.csv.csv
# What best describes the organization you are starting or running?: present in 1 file(s) -> (OLD)+TGH+Learner+Enrollment+Form+2025-03-06-11-24-39+457499.csv.csv
# What are the biggest challenges you are currently facing in running your business? If you have not yet started your business, what are the biggest obstacles?: present in 1 file(s) -> (OLD)+TGH+Learner+Enrollment+Form+2025-03-06-11-24-39+457499.csv.csv
# How old is your business?: present in 1 file(s) -> (OLD)+TGH+Learner+Enrollment+Form+2025-03-06-11-24-39+457499.csv.csv
# Annual Revenue of Business: present in 1 file(s) -> (OLD)+TGH+Learner+Enrollment+Form+2025-03-06-11-24-39+457499.csv.csv
# Number of Employees: present in 1 file(s) -> (OLD)+TGH+Learner+Enrollment+Form+2025-03-06-11-24-39+457499.csv.csv
# other_business_industry: present in 1 file(s) -> (OLD)+TGH+Learner+Enrollment+Form+2025-03-06-11-24-39+457499.csv.csv
# Do you accept credit/debit cards?: present in 1 file(s) -> (OLD)+TGH+Learner+Enrollment+Form+2025-03-06-11-24-39+457499.csv.csv
# What does your business use the Internet for?: present in 1 file(s) -> (OLD)+TGH+Learner+Enrollment+Form+2025-03-06-11-24-39+457499.csv.csv
# other_internet_use_for_business: present in 1 file(s) -> (OLD)+TGH+Learner+Enrollment+Form+2025-03-06-11-24-39+457499.csv.csv
# Do you know of organizations that help small business owners navigate licensing and permitting, taxes, law, marketing, access to funding, and other business issues?: present in 1 file(s) -> (OLD)+TGH+Learner+Enrollment+Form+2025-03-06-11-24-39+457499.csv.csv
# How often are your business social media pages updated?: present in 1 file(s) -> (OLD)+TGH+Learner+Enrollment+Form+2025-03-06-11-24-39+457499.csv.csv
# I hereby give the unqualified right to the TGH program to take pictures and/ or video of me while participating in my course. I give permission for these images as well as materials that we have created in the TGH program to be used in print and web-based publications. The TGH program will put these images to legitimate use without limitation or reservation. If you do not wish for your photo to be used by TGH, please let your TGH trainers know so they will not send us pictures of you.: present in 1 file(s) -> (OLD)+TGH+Learner+Enrollment+Form+2025-03-06-11-24-39+457499.csv.csv
# course name: present in 1 file(s) -> Cleaned_ES_translated_chinese.csv
# name of siteschool: present in 1 file(s) -> Cleaned_ES_translated_chinese.csv
# course type: present in 1 file(s) -> Cleaned_ES_translated_chinese.csv
# first name: present in 1 file(s) -> Cleaned_ES_translated_chinese.csv
# last name: present in 1 file(s) -> Cleaned_ES_translated_chinese.csv
# what are your pronouns: present in 1 file(s) -> Cleaned_ES_translated_chinese.csv
# have you received a tgh device chromebook or ipad in the last two years: present in 1 file(s) -> Cleaned_ES_translated_chinese.csv
# date of birth: present in 1 file(s) -> Cleaned_ES_translated_chinese.csv
# what is your gender: present in 1 file(s) -> Cleaned_ES_translated_chinese.csv
# your gender identity: present in 1 file(s) -> Cleaned_ES_translated_chinese.csv
# how would you describe your raceethnicity select all that apply: present in 1 file(s) -> Cleaned_ES_translated_chinese.csv
# primary language: present in 1 file(s) -> Cleaned_ES_translated_chinese.csv
# if you selected other what language: present in 1 file(s) -> Cleaned_ES_translated_chinese.csv
# home street address including apartment number: present in 1 file(s) -> Cleaned_ES_translated_chinese.csv
# city: present in 1 file(s) -> Cleaned_ES_translated_chinese.csv
# state: present in 1 file(s) -> Cleaned_ES_translated_chinese.csv
# zip code: present in 1 file(s) -> Cleaned_ES_translated_chinese.csv
# phone number: present in 1 file(s) -> Cleaned_ES_translated_chinese.csv
# email address: present in 1 file(s) -> Cleaned_ES_translated_chinese.csv
# number of people in household: present in 1 file(s) -> Cleaned_ES_translated_chinese.csv
# educational status: present in 1 file(s) -> Cleaned_ES_translated_chinese.csv
# employment status: present in 1 file(s) -> Cleaned_ES_translated_chinese.csv
# are you self employed: present in 1 file(s) -> Cleaned_ES_translated_chinese.csv
# household income level: present in 1 file(s) -> Cleaned_ES_translated_chinese.csv
# do you receive housing assistance: present in 1 file(s) -> Cleaned_ES_translated_chinese.csv
# childs first name: present in 1 file(s) -> Cleaned_ES_translated_chinese.csv
# childs last name: present in 1 file(s) -> Cleaned_ES_translated_chinese.csv
# what are your childs pronouns: present in 1 file(s) -> Cleaned_ES_translated_chinese.csv
# childs date of birth: present in 1 file(s) -> Cleaned_ES_translated_chinese.csv
# what is your child's gender: present in 1 file(s) -> Cleaned_ES_translated_chinese.csv
# your child's gender identity: present in 1 file(s) -> Cleaned_ES_translated_chinese.csv
# how would you describe your childs raceethnicity: present in 1 file(s) -> Cleaned_ES_translated_chinese.csv
# childs primary language: present in 1 file(s) -> Cleaned_ES_translated_chinese.csv
# Unnamed: 33: present in 1 file(s) -> Cleaned_ES_translated_chinese.csv
# what is your goal for taking this course: present in 1 file(s) -> Cleaned_ES_translated_chinese.csv
# is this the first activity youve participated in at your program site: present in 1 file(s) -> Cleaned_ES_translated_chinese.csv
# how many working computers do you have at home: present in 1 file(s) -> Cleaned_ES_translated_chinese.csv
# how many tablets do you have at home e g ipad kindle fire samsung galaxy tab: present in 1 file(s) -> Cleaned_ES_translated_chinese.csv
# do you have a smartphone e g iphone google pixel samsung galaxy: present in 1 file(s) -> Cleaned_ES_translated_chinese.csv
# do you have home internet access i e wifi: present in 1 file(s) -> Cleaned_ES_translated_chinese.csv
# is your internet affordable: present in 1 file(s) -> Cleaned_ES_translated_chinese.csv
# is your internet reliable: present in 1 file(s) -> Cleaned_ES_translated_chinese.csv
# are you aware of the affordable connectivity program acp an fcc federal communications commission program to help families and households afford internet service more info here httpswww fcc govacp: present in 1 file(s) -> Cleaned_ES_translated_chinese.csv
# are you currently enrolled in the acp program: present in 1 file(s) -> Cleaned_ES_translated_chinese.csv
# please describe your confidence level using the internet to find information you need: present in 1 file(s) -> Cleaned_ES_translated_chinese.csv
# creating and sending emails: present in 1 file(s) -> Cleaned_ES_translated_chinese.csv
# opening and replying to emails: present in 1 file(s) -> Cleaned_ES_translated_chinese.csv
# downloading attachments i receive in an email documents or pictures: present in 1 file(s) -> Cleaned_ES_translated_chinese.csv
# adding an attachment to an email i am sending like documents or pictures: present in 1 file(s) -> Cleaned_ES_translated_chinese.csv
# turning the tablet on and off: present in 1 file(s) -> Cleaned_ES_translated_chinese.csv
# adjusting the tablets settings like the size of the text or the background picture: present in 1 file(s) -> Cleaned_ES_translated_chinese.csv
# connecting the tablet to wifi: present in 1 file(s) -> Cleaned_ES_translated_chinese.csv
# installing applications from the chromebook store: present in 1 file(s) -> Cleaned_ES_translated_chinese.csv
# saving files to the tablet and finding them later: present in 1 file(s) -> Cleaned_ES_translated_chinese.csv
# using a mouse headset andor other accessories: present in 1 file(s) -> Cleaned_ES_translated_chinese.csv
# do you have an existing business: present in 1 file(s) -> Cleaned_ES_translated_chinese.csv
# name of business: present in 1 file(s) -> Cleaned_ES_translated_chinese.csv
# what industry is your business in: present in 1 file(s) -> Cleaned_ES_translated_chinese.csv
# if you selected other please explain: present in 1 file(s) -> Cleaned_ES_translated_chinese.csv
# do you have a website for your business: present in 1 file(s) -> Cleaned_ES_translated_chinese.csv
# what is your website address url: present in 1 file(s) -> Cleaned_ES_translated_chinese.csv
# which if any social media tools do you use for your business: present in 1 file(s) -> Cleaned_ES_translated_chinese.csv
# please enter any all of your social media handles separated by a comma e g techgoeshome facebook com yourbusinessname: present in 1 file(s) -> Cleaned_ES_translated_chinese.csv
# tech goes home tech goes home tech goes home tech goes home tgh: present in 1 file(s) -> Cleaned_ES_translated_chinese.csv
# i agree to the learner agreement as listed above: present in 1 file(s) -> Cleaned_ES_translated_chinese.csv
# course id: present in 1 file(s) -> Cleaned_ES_translated_chinese.csv
# fa list learner enrollment english 1: present in 1 file(s) -> Cleaned_ES_translated_chinese.csv
# form name: present in 1 file(s) -> Cleaned_ES_translated_chinese.csv
# creation date: present in 1 file(s) -> Cleaned_ES_translated_chinese.csv
# modified date: present in 1 file(s) -> Cleaned_ES_translated_chinese.csv
# submitted date: present in 1 file(s) -> Cleaned_ES_translated_chinese.csv
# completion time: present in 1 file(s) -> Cleaned_ES_translated_chinese.csv
# response text: present in 1 file(s) -> Cleaned_ES_translated_chinese.csv
# response_html: present in 1 file(s) -> Cleaned_ES_translated_chinese.csv
# resume email: present in 1 file(s) -> Cleaned_ES_translated_chinese.csv
# file list: present in 1 file(s) -> Cleaned_ES_translated_chinese.csv
# unprotected file list: present in 1 file(s) -> Cleaned_ES_translated_chinese.csv
# response: present in 1 file(s) -> Cleaned_ES_translated_chinese.csv
# referrer: present in 1 file(s) -> Cleaned_ES_translated_chinese.csv
# ip address: present in 1 file(s) -> Cleaned_ES_translated_chinese.csv
# What is the zip code where you work?: present in 1 file(s) -> translated_haitian_creole.xlsm
# What other Boston neighbourhoods are you connected to? For example, do you receive services, visit family or friends, go to school or places of worship, in any of the folloYesng neighbourhoods? [Select all that apply]: present in 1 file(s) -> translated_haitian_creole.xlsm
# Other_neighboorhood: present in 1 file(s) -> translated_haitian_creole.xlsm
#  Child's Date of Birth: present in 1 file(s) -> translated_haitian_creole.xlsm
# How would you describe your child's race/ethnicity:: present in 1 file(s) -> translated_haitian_creole.xlsm
# child's other language: present in 1 file(s) -> translated_haitian_creole.xlsm
#  Do you have home internet access (i.e. Yesfi)?: present in 1 file(s) -> translated_haitian_creole.xlsm
# Connecting the computer to Yesfi: present in 1 file(s) -> translated_haitian_creole.xlsm
# Connecting the tablet to Yesfi: present in 1 file(s) -> translated_haitian_creole.xlsm
# I am aware of what my skills are to be employed in a good job (e.g., digital skills, specific trade skills, etc.).: present in 1 file(s) -> translated_haitian_creole.xlsm
# Even if I am not able to achieve my financial goals right away, I Yesll find a way to get there.: present in 1 file(s) -> translated_haitian_creole.xlsm
# Because of my money situation, I feel like I Yesll never have the things I want in life.: present in 1 file(s) -> translated_haitian_creole.xlsm
# I am concerned that the money I have or Yesll save won‚Äôt last.: present in 1 file(s) -> translated_haitian_creole.xlsm
# FA List: Learner Enrollment HAITIAN CREOLE (3.8.23): present in 1 file(s) -> translated_haitian_creole.xlsm
#
# === Number of Fields per File ===
# Learner+Enrollment+ENGLISH.csv: 105 fields
# translated_spanish.xlsm: 104 fields
# (OLD) TGH Learner Enrollment Form (6.2.2022).csv: 84 fields
# (OLD)+TGH+Learner+Enrollment+Form+2025-03-06-11-24-39+457499.csv.csv: 91 fields
# Cleaned_ES_translated_chinese.csv: 80 fields
# translated_haitian_creole.xlsm: 103 fields
#                                                Column  FileCount
# 0                                      Submitted Date          5
# 1                                         Course Name          5
# 2                                 Name of Site/School          5
# 3                                         Course Type          5
# 4                                          First Name          5
# 5                                           Last Name          5
# 6   Have you received a TGH device (Chromebook or ...          5
# 7                                       Date of Birth          5
# 8                                    Primary Language          5
# 9    Home Street Address (including apartment number)          5
# 10                                               City          5
# 11                                              State          5
# 12                                       Phone Number          5
# 13                                      Email Address          5
# 14                                  Employment Status          5
# 15                             Household Income Level          5
# 16                 Do you receive housing assistance?          5
# 17                                 Child's First Name          5
# 18                                  Child's Last Name          5
# 19                           Child's Primary Language          5

# %%
import pandas as pd
import re
import unicodedata

def standardize_column(col):
    """
    Standardizes a column name by:
      - Removing leading/trailing whitespace
      - Converting to lowercase
      - Normalizing accented characters
      - Removing special characters (punctuation, etc.)
      - Replacing internal spaces with a single underscore
      - Removing any underscores at the beginning or end
    """
    # Trim extra spaces and convert to lowercase
    col = col.strip().lower()
    # Normalize accented characters (e.g., é -> e)
    col = unicodedata.normalize('NFKD', col).encode('ascii', 'ignore').decode('utf-8')
    # Remove punctuation and special characters (keeping alphanumerics and whitespace)
    col = re.sub(r'[^\w\s]', '', col)
    # Replace one or more whitespace with a single underscore
    col = re.sub(r'\s+', '_', col)
    # Ensure no leading or trailing underscores remain
    col = col.strip('_')
    return col

# Update the file path with your file to standardize
file_path = '/Users/sreeharsha/Documents/TGH Data Management Cleaning/Merge testing/Enrollment Survey/Learner+Enrollment+ENGLISH.csv'  # <-- Update this path

# Load the file (assuming CSV; use pd.read_excel for xlsm files)
df = pd.read_csv(file_path)

# Display original columns
print("Original columns:")
print(df.columns.tolist())

# Apply standardization to each column name
new_columns = [standardize_column(col) for col in df.columns]
df.columns = new_columns

# Display standardized columns
print("Standardized columns:")
print(df.columns.tolist())

# Save the updated DataFrame to a new file (update the output path as needed)
output_path = "/Users/sreeharsha/Documents/TGH Data Management Cleaning/Merge testing/Enrollment Survey/ES_English_standardized.csv"  # <-- Update this path
df.to_csv(output_path, index=False)
print("Standardized file saved to:", output_path)
# Out:
# Original columns:
# ['Submitted Date', 'Course Name', 'Name of Site/School', 'Course Type', 'First Name', 'Last Name', 'Do you have home internet access (i.e. wifi)?', 'What are your pronouns?', 'Have you received a TGH device (Chromebook or iPad) in the last two years?', 'Date of Birth', 'What is your gender?', 'Your gender identity:', '8. How would you describe your race/ethnicity?', 'How would you describe your race/ethnicity? (select all that apply)', 'Primary Language', 'other_language', 'Are you a veteran?', 'Home Street Address (including apartment number)', 'City', 'State', 'Zip Code', 'Phone Number', 'Email Address', 'Number of people in Household', 'Educational Status', 'Employment Status', 'Are you self-employed?', 'What is the Zip Code where you work?', 'Household Income Level', 'Do you receive housing assistance?', 'What other Boston neighborhoods are you connected to? For example, do you receive services, visit family or friends, go to school or places of worship, in any of the following neighborhoods? [Select all that apply]', 'other_neighborhoods', 'Were you born in the United States?', 'Have you ever spent time in a jail, prison, or juvenile detention center?', 'How do you describe your sexual orientation?', 'other_sexual_orientation', "Child's First Name", "Child's Last Name", "What are your child's pronouns?", "Child's Date of Birth", "What is your child's gender?", "Your child's gender identity:", "How would you describe your child's race/ethnicity? (select all that apply)", "Child's Primary Language", 'other_child_language?', 'What is your goal for taking this course?', "Is this the first activity you've participated in at your program site?", 'How many working computers do you have at home?', 'How many tablets do you have at home? (e.g. iPad, Kindle Fire, Samsung Galaxy Tab)', 'Do you have a smartphone? (e.g. iPhone, Google Pixel, Samsung Galaxy)', 'Is your internet affordable?', 'Is your internet reliable?', 'Are you aware of the Affordable Connectivity Program (ACP), an FCC (Federal Communications Commission) program to help families and households afford internet service? (More info here: https://www.fcc.gov/acp)', 'Are you currently enrolled in the ACP program?', 'Please describe your confidence level using the internet to find information you need:', 'Creating and sending emails', 'Opening and replying to emails', 'Downloading attachments I receive in an email (documents or pictures)', 'Adding an attachment to an email I am sending (like documents or pictures)', 'Turning the computer on and off', "Adjusting the computer's settings (like the size of the text or the background picture)", 'Connecting the computer to wifi', 'Installing applications from the Chromebook store', 'Saving files to the computer and finding them later', 'Using a mouse, headset, and/or other accessories', 'Turning the tablet on and off', "Adjusting the tablet's settings (like the size of the text or the background picture)", 'Connecting the tablet to wifi', 'Installing applications (Apps)', 'Saving files to the tablet and finding them later', 'I am aware of what my skills are to be employed in a goodjob (e.g., digital skills, specific trade skills, etc.).', 'I am aware of what my resources are to be employed in a good job (e.g., resources for job searching, child care resources, etc.).', 'I am able to utilize my skills to move toward career goals.', 'I am able to utilize my resources to move toward career goals.', 'Even if I am not able to achieve my financial goals right away, I will find a way to get there.', 'Because of my money situation, I feel like I will never have thethings I want in life.', 'I am just getting by financially.', 'I am concerned that the money I have or will save won’t last.', 'Do you have an existing business?', 'Name of Business', 'What industry is your business in?', 'If you selected "Other," please explain:', 'Do you have a website for your business?', 'What is your website address (URL)?', 'Which, if any, social media to ...
# Standardized columns:
# ['submitted_date', 'course_name', 'name_of_siteschool', 'course_type', 'first_name', 'last_name', 'do_you_have_home_internet_access_ie_wifi', 'what_are_your_pronouns', 'have_you_received_a_tgh_device_chromebook_or_ipad_in_the_last_two_years', 'date_of_birth', 'what_is_your_gender', 'your_gender_identity', '8_how_would_you_describe_your_raceethnicity', 'how_would_you_describe_your_raceethnicity_select_all_that_apply', 'primary_language', 'other_language', 'are_you_a_veteran', 'home_street_address_including_apartment_number', 'city', 'state', 'zip_code', 'phone_number', 'email_address', 'number_of_people_in_household', 'educational_status', 'employment_status', 'are_you_selfemployed', 'what_is_the_zip_code_where_you_work', 'household_income_level', 'do_you_receive_housing_assistance', 'what_other_boston_neighborhoods_are_you_connected_to_for_example_do_you_receive_services_visit_family_or_friends_go_to_school_or_places_of_worship_in_any_of_the_following_neighborhoods_select_all_that_apply', 'other_neighborhoods', 'were_you_born_in_the_united_states', 'have_you_ever_spent_time_in_a_jail_prison_or_juvenile_detention_center', 'how_do_you_describe_your_sexual_orientation', 'other_sexual_orientation', 'childs_first_name', 'childs_last_name', 'what_are_your_childs_pronouns', 'childs_date_of_birth', 'what_is_your_childs_gender', 'your_childs_gender_identity', 'how_would_you_describe_your_childs_raceethnicity_select_all_that_apply', 'childs_primary_language', 'other_child_language', 'what_is_your_goal_for_taking_this_course', 'is_this_the_first_activity_youve_participated_in_at_your_program_site', 'how_many_working_computers_do_you_have_at_home', 'how_many_tablets_do_you_have_at_home_eg_ipad_kindle_fire_samsung_galaxy_tab', 'do_you_have_a_smartphone_eg_iphone_google_pixel_samsung_galaxy', 'is_your_internet_affordable', 'is_your_internet_reliable', 'are_you_aware_of_the_affordable_connectivity_program_acp_an_fcc_federal_communications_commission_program_to_help_families_and_households_afford_internet_service_more_info_here_httpswwwfccgovacp', 'are_you_currently_enrolled_in_the_acp_program', 'please_describe_your_confidence_level_using_the_internet_to_find_information_you_need', 'creating_and_sending_emails', 'opening_and_replying_to_emails', 'downloading_attachments_i_receive_in_an_email_documents_or_pictures', 'adding_an_attachment_to_an_email_i_am_sending_like_documents_or_pictures', 'turning_the_computer_on_and_off', 'adjusting_the_computers_settings_like_the_size_of_the_text_or_the_background_picture', 'connecting_the_computer_to_wifi', 'installing_applications_from_the_chromebook_store', 'saving_files_to_the_computer_and_finding_them_later', 'using_a_mouse_headset_andor_other_accessories', 'turning_the_tablet_on_and_off', 'adjusting_the_tablets_settings_like_the_size_of_the_text_or_the_background_picture', 'connecting_the_tablet_to_wifi', 'installing_applications_apps', 'saving_files_to_the_tablet_and_finding_them_later', 'i_am_aware_of_what_my_skills_are_to_be_employed_in_a_goodjob_eg_digital_skills_specific_trade_skills_etc', 'i_am_aware_of_what_my_resources_are_to_be_employed_in_a_good_job_eg_resources_for_job_searching_child_care_resources_etc', 'i_am_able_to_utilize_my_skills_to_move_toward_career_goals', 'i_am_able_to_utilize_my_resources_to_move_toward_career_goals', 'even_if_i_am_not_able_to_achieve_my_financial_goals_right_away_i_will_find_a_way_to_get_there', 'because_of_my_money_situation_i_feel_like_i_will_never_have_thethings_i_want_in_life', 'i_am_just_getting_by_financially', 'i_am_concerned_that_the_money_i_have_or_will_save_wont_last', 'do_you_have_an_existing_business', 'name_of_business', 'what_industry_is_your_business_in', 'if_you_selected_other_please_explain', 'do_you_have_a_website_for_your_business', 'what_is_your_website_address_url', 'which_if_any_social_media_tools_do_you_use_for_your_business', 'please_enter_anyall_of_your_social_media_handles_separated_by_a_comma_eg_techgoeshome_facebookcomyourbusinessn ...
# Standardized file saved to: /Users/sreeharsha/Documents/TGH Data Management Cleaning/Merge testing/Enrollment Survey/ES_English_standardized.csv
# /var/folders/q6/v__5dqvn4fsgnld9cp_x0v1m0000gn/T/ipykernel_23866/1691511722.py:31: DtypeWarning: Columns (16,27,30,31,32,33,34,35,48,75,76,77,81,99) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
